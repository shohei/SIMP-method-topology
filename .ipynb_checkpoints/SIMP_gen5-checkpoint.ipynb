# %%
BASE_FILENAME = 'gen5'

# %%
import xmltodict, json
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.interpolate import griddata

# %%
# 与えられたnode idから対応するX,Yの点を返す関数
def findXY(node_id):
    for node in nodes:
        if node['@nid'] == str(node_id):
            return (node['@x'], node['@y'])
            
# 4点から面積を計算する方法（靴紐の公式））
def shoelace_area(points):
    """
    計算順に並んだ4点の(x, y)座標リスト [(x1, y1), (x2, y2), (x3, y3), (x4, y4)] から面積を求める
    """
    n = len(points)
    area = 0
    for i in range(n):
        j = (i + 1) % n  # 次の点（最後の点は最初の点につなげる）
        area += points[i][0] * points[j][1] - points[i][1] * points[j][0]
    return abs(area) / 2

# ✅ 例: 4点を指定して計算
points = [(1, 1), (4, 1), (4, 5), (1, 5)]  # 長方形
# print(shoelace_area(points))  # 出力: 12.0

# %%
data = 'input/'+BASE_FILENAME+'.liml'

# %%
import xmltodict
import pprint

# Open the file and read the contents
with open(data,  'r', encoding='utf-8') as file:
    my_xml = file.read()

# Use xmltodict to parse and convert 
# the XML document
my_dict = xmltodict.parse(my_xml).copy()

# Print the dictionary
pprint.pprint(my_dict, indent=2)
# Out:
# { 'liml8': { 'analysis': {'@type': 'S20'},
#              'displacement': [ { '@axis': '1',
#                                  '@selection': 'Unnamed',
#                                  'value': '0'},
#                                { '@axis': '2',
#                                  '@selection': 'Unnamed(2)',
#                                  'value': '0'}],
#              'elset': { '@color': '-6710887',
#                         '@material': 'Material',
#                         '@name': 'Default',
#                         'elem': [ { '@eid': '1',
#                                     '@nodes': '1243 1269 3 1244',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '2',
#                                     '@nodes': '1 30 31 5',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '3',
#                                     '@nodes': '5 31 32 6',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '4',
#                                     '@nodes': '6 32 33 7',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '5',
#                                     '@nodes': '7 33 34 8',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '6',
#                                     '@nodes': '8 34 35 9',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '7',
#                                     '@nodes': '9 35 36 10',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '8',
#                                     '@nodes': '10 36 37 11',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '9',
#                                     '@nodes': '11 37 38 12',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '10',
#                                     '@nodes': '12 38 39 13',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '11',
#                                     '@nodes': '13 39 40 14',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '12',
#                                     '@nodes': '14 40 41 15',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '13',
#                                     '@nodes': '15 41 42 16',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '14',
#                                     '@nodes': '16 42 43 17',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '15',
#                                     '@nodes': '17 43 44 18',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '16',
#                                     '@nodes': '18 44 45 19',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '17',
#                                     '@nodes': '19 45 46 20',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '18',
#                                     '@nodes': '20 46 47 21',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '19',
#                                     '@nodes': '21 47 48 22',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '20',
#                                     '@nodes': '22 48 49 23',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '21',
#                                     '@nodes': '23 49 50 24',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '22',
#                                     '@nodes': '24 50 51 25',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '23',
#                                     '@nodes': '25 51 52 26',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '24',
#                                     '@nodes': '26 52 53 27',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '25',
#                                     '@nodes': '27 53 54 28',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '26',
#                                     '@nodes': '28 54 55 29',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '27',
#                                     '@nodes': '29 55 56 4',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '28',
#                                     '@nodes': '30 57 58 31',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '29',
#                                     '@nodes': '31 58 59 32',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '30',
#                                     '@nodes': '32 59 60 33',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '31',
#                                     '@nodes': '33 60 61 34',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '32',
#                                     '@nodes': '34 61 62 35',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '33',
#                                     '@nodes': '35 62 63 36',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '34',
#                                     '@nodes': '36 63 64 37',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '35',
#                                     '@nodes': '37 64 65 38',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '36',
#                                     '@nodes': '38 65 66 39',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '37',
#                                     '@nodes': '39 66 67 40',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '38',
#                                     '@nodes': '40 67 68 41',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '39',
#                                     '@nodes': '41 68 69 42',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '40',
#                                     '@nodes': '42 69 70 43',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '41',
#                                     '@nodes': '43 70 71 44',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '42',
#                                     '@nodes': '44 71 72 45',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '43',
#                                     '@nodes': '45 72 73 46',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '44',
#                                     '@nodes': '46 73 74 47',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '45',
#                                     '@nodes': '47 74 75 48',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '46',
#                                     '@nodes': '48 75 76 49',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '47',
#                                     '@nodes': '49 76 77 50',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '48',
#                                     '@nodes': '50 77 78 51',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '49',
#                                     '@nodes': '51 78 79 52',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '50',
#                                     '@nodes': '52 79 80 53',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '51',
#                                     '@nodes': '53 80 81 54',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '52',
#                                     '@nodes': '54 81 82 55',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '53',
#                                     '@nodes': '55 82 83 56',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '54',
#                                     '@nodes': '57 84 85 58',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '55',
#                                     '@nodes': '58 85 86 59',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '56',
#                                     '@nodes': '59 86 87 60',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '57',
#                                     '@nodes': '60 87 88 61',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '58',
#                                     '@nodes': '61 88 89 62',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '59',
#                                     '@nodes': '62 89 90 63',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '60',
#                                     '@nodes': '63 90 91 64',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '61',
#                                     '@nodes': '64 91 92 65',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '62',
#                                     '@nodes': '65 92 93 66',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '63',
#                                     '@nodes': '66 93 94 67',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '64',
#                                     '@nodes': '67 94 95 68',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '65',
#                                     '@nodes': '68 95 96 69',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '66',
#                                     '@nodes': '69 96 97 70',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '67',
#                                     '@nodes': '70 97 98 71',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '68',
#                                     '@nodes': '71 98 99 72',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '69',
#                                     '@nodes': '72 99 100 73',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '70',
#                                     '@nodes': '73 100 101 74',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '71',
#                                     '@nodes': '74 101 102 75',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '72',
#                                     '@nodes': '75 102 103 76',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '73',
#                                     '@nodes': '76 103 104 77',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '74',
#                                     '@nodes': '77 104 105 78',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '75',
#                                     '@nodes': '78 105 106 79',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '76',
#                                     '@nodes': '79 106 107 80',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '77',
#                                     '@nodes': '80 107 108 81',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '78',
#                                     '@nodes': '81 108 109 82',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '79',
#                                     '@nodes': '82 109 110 83',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '80',
#                                     '@nodes': '84 111 112 85',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '81',
#                                     '@nodes': '85 112 113 86',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '82',
#                                     '@nodes': '86 113 114 87',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '83',
#                                     '@nodes': '87 114 115 88',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '84',
#                                     '@nodes': '88 115 116 89',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '85',
#                                     '@nodes': '89 116 117 90',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '86',
#                                     '@nodes': '90 117 118 91',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '87',
#                                     '@nodes': '91 118 119 92',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '88',
#                                     '@nodes': '92 119 120 93',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '89',
#                                     '@nodes': '93 120 121 94',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '90',
#                                     '@nodes': '94 121 122 95',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '91',
#                                     '@nodes': '95 122 123 96',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '92',
#                                     '@nodes': '96 123 124 97',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '93',
#                                     '@nodes': '97 124 125 98',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '94',
#                                     '@nodes': '98 125 126 99',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '95',
#                                     '@nodes': '99 126 127 100',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '96',
#                                     '@nodes': '100 127 128 101',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '97',
#                                     '@nodes': '101 128 129 102',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '98',
#                                     '@nodes': '102 129 130 103',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '99',
#                                     '@nodes': '103 130 131 104',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '100',
#                                     '@nodes': '104 131 132 105',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '101',
#                                     '@nodes': '105 132 133 106',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '102',
#                                     '@nodes': '106 133 134 107',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '103',
#                                     '@nodes': '107 134 135 108',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '104',
#                                     '@nodes': '108 135 136 109',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '105',
#                                     '@nodes': '109 136 137 110',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '106',
#                                     '@nodes': '111 138 139 112',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '107',
#                                     '@nodes': '112 139 140 113',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '108',
#                                     '@nodes': '113 140 141 114',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '109',
#                                     '@nodes': '114 141 142 115',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '110',
#                                     '@nodes': '115 142 143 116',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '111',
#                                     '@nodes': '116 143 144 117',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '112',
#                                     '@nodes': '117 144 145 118',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '113',
#                                     '@nodes': '118 145 146 119',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '114',
#                                     '@nodes': '119 146 147 120',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '115',
#                                     '@nodes': '120 147 148 121',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '116',
#                                     '@nodes': '121 148 149 122',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '117',
#                                     '@nodes': '122 149 150 123',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '118',
#                                     '@nodes': '123 150 151 124',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '119',
#                                     '@nodes': '124 151 152 125',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '120',
#                                     '@nodes': '125 152 153 126',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '121',
#                                     '@nodes': '126 153 154 127',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '122',
#                                     '@nodes': '127 154 155 128',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '123',
#                                     '@nodes': '128 155 156 129',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '124',
#                                     '@nodes': '129 156 157 130',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '125',
#                                     '@nodes': '130 157 158 131',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '126',
#                                     '@nodes': '131 158 159 132',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '127',
#                                     '@nodes': '132 159 160 133',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '128',
#                                     '@nodes': '133 160 161 134',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '129',
#                                     '@nodes': '134 161 162 135',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '130',
#                                     '@nodes': '135 162 163 136',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '131',
#                                     '@nodes': '136 163 164 137',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '132',
#                                     '@nodes': '138 165 166 139',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '133',
#                                     '@nodes': '139 166 167 140',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '134',
#                                     '@nodes': '140 167 168 141',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '135',
#                                     '@nodes': '141 168 169 142',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '136',
#                                     '@nodes': '142 169 170 143',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '137',
#                                     '@nodes': '143 170 171 144',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '138',
#                                     '@nodes': '144 171 172 145',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '139',
#                                     '@nodes': '145 172 173 146',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '140',
#                                     '@nodes': '146 173 174 147',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '141',
#                                     '@nodes': '147 174 175 148',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '142',
#                                     '@nodes': '148 175 176 149',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '143',
#                                     '@nodes': '149 176 177 150',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '144',
#                                     '@nodes': '150 177 178 151',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '145',
#                                     '@nodes': '151 178 179 152',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '146',
#                                     '@nodes': '152 179 180 153',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '147',
#                                     '@nodes': '153 180 181 154',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '148',
#                                     '@nodes': '154 181 182 155',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '149',
#                                     '@nodes': '155 182 183 156',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '150',
#                                     '@nodes': '156 183 184 157',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '151',
#                                     '@nodes': '157 184 185 158',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '152',
#                                     '@nodes': '158 185 186 159',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '153',
#                                     '@nodes': '159 186 187 160',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '154',
#                                     '@nodes': '160 187 188 161',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '155',
#                                     '@nodes': '161 188 189 162',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '156',
#                                     '@nodes': '162 189 190 163',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '157',
#                                     '@nodes': '163 190 191 164',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '158',
#                                     '@nodes': '165 192 193 166',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '159',
#                                     '@nodes': '166 193 194 167',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '160',
#                                     '@nodes': '167 194 195 168',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '161',
#                                     '@nodes': '168 195 196 169',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '162',
#                                     '@nodes': '169 196 197 170',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '163',
#                                     '@nodes': '170 197 198 171',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '164',
#                                     '@nodes': '171 198 199 172',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '165',
#                                     '@nodes': '172 199 200 173',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '166',
#                                     '@nodes': '173 200 201 174',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '167',
#                                     '@nodes': '174 201 202 175',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '168',
#                                     '@nodes': '175 202 203 176',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '169',
#                                     '@nodes': '176 203 204 177',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '170',
#                                     '@nodes': '177 204 205 178',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '171',
#                                     '@nodes': '178 205 206 179',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '172',
#                                     '@nodes': '179 206 207 180',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '173',
#                                     '@nodes': '180 207 208 181',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '174',
#                                     '@nodes': '181 208 209 182',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '175',
#                                     '@nodes': '182 209 210 183',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '176',
#                                     '@nodes': '183 210 211 184',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '177',
#                                     '@nodes': '184 211 212 185',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '178',
#                                     '@nodes': '185 212 213 186',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '179',
#                                     '@nodes': '186 213 214 187',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '180',
#                                     '@nodes': '187 214 215 188',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '181',
#                                     '@nodes': '188 215 216 189',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '182',
#                                     '@nodes': '189 216 217 190',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '183',
#                                     '@nodes': '190 217 218 191',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '184',
#                                     '@nodes': '192 219 220 193',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '185',
#                                     '@nodes': '193 220 221 194',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '186',
#                                     '@nodes': '194 221 222 195',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '187',
#                                     '@nodes': '195 222 223 196',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '188',
#                                     '@nodes': '196 223 224 197',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '189',
#                                     '@nodes': '197 224 225 198',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '190',
#                                     '@nodes': '198 225 226 199',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '191',
#                                     '@nodes': '199 226 227 200',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '192',
#                                     '@nodes': '200 227 228 201',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '193',
#                                     '@nodes': '201 228 229 202',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '194',
#                                     '@nodes': '202 229 230 203',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '195',
#                                     '@nodes': '203 230 231 204',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '196',
#                                     '@nodes': '204 231 232 205',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '197',
#                                     '@nodes': '205 232 233 206',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '198',
#                                     '@nodes': '206 233 234 207',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '199',
#                                     '@nodes': '207 234 235 208',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '200',
#                                     '@nodes': '208 235 236 209',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '201',
#                                     '@nodes': '209 236 237 210',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '202',
#                                     '@nodes': '210 237 238 211',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '203',
#                                     '@nodes': '211 238 239 212',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '204',
#                                     '@nodes': '212 239 240 213',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '205',
#                                     '@nodes': '213 240 241 214',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '206',
#                                     '@nodes': '214 241 242 215',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '207',
#                                     '@nodes': '215 242 243 216',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '208',
#                                     '@nodes': '216 243 244 217',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '209',
#                                     '@nodes': '217 244 245 218',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '210',
#                                     '@nodes': '219 246 247 220',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '211',
#                                     '@nodes': '220 247 248 221',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '212',
#                                     '@nodes': '221 248 249 222',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '213',
#                                     '@nodes': '222 249 250 223',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '214',
#                                     '@nodes': '223 250 251 224',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '215',
#                                     '@nodes': '224 251 252 225',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '216',
#                                     '@nodes': '225 252 253 226',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '217',
#                                     '@nodes': '226 253 254 227',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '218',
#                                     '@nodes': '227 254 255 228',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '219',
#                                     '@nodes': '228 255 256 229',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '220',
#                                     '@nodes': '229 256 257 230',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '221',
#                                     '@nodes': '230 257 258 231',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '222',
#                                     '@nodes': '231 258 259 232',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '223',
#                                     '@nodes': '232 259 260 233',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '224',
#                                     '@nodes': '233 260 261 234',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '225',
#                                     '@nodes': '234 261 262 235',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '226',
#                                     '@nodes': '235 262 263 236',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '227',
#                                     '@nodes': '236 263 264 237',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '228',
#                                     '@nodes': '237 264 265 238',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '229',
#                                     '@nodes': '238 265 266 239',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '230',
#                                     '@nodes': '239 266 267 240',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '231',
#                                     '@nodes': '240 267 268 241',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '232',
#                                     '@nodes': '241 268 269 242',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '233',
#                                     '@nodes': '242 269 270 243',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '234',
#                                     '@nodes': '243 270 271 244',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '235',
#                                     '@nodes': '244 271 272 245',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '236',
#                                     '@nodes': '246 273 274 247',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '237',
#                                     '@nodes': '247 274 275 248',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '238',
#                                     '@nodes': '248 275 276 249',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '239',
#                                     '@nodes': '249 276 277 250',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '240',
#                                     '@nodes': '250 277 278 251',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '241',
#                                     '@nodes': '251 278 279 252',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '242',
#                                     '@nodes': '252 279 280 253',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '243',
#                                     '@nodes': '253 280 281 254',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '244',
#                                     '@nodes': '254 281 282 255',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '245',
#                                     '@nodes': '255 282 283 256',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '246',
#                                     '@nodes': '256 283 284 257',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '247',
#                                     '@nodes': '257 284 285 258',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '248',
#                                     '@nodes': '258 285 286 259',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '249',
#                                     '@nodes': '259 286 287 260',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '250',
#                                     '@nodes': '260 287 288 261',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '251',
#                                     '@nodes': '261 288 289 262',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '252',
#                                     '@nodes': '262 289 290 263',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '253',
#                                     '@nodes': '263 290 291 264',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '254',
#                                     '@nodes': '264 291 292 265',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '255',
#                                     '@nodes': '265 292 293 266',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '256',
#                                     '@nodes': '266 293 294 267',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '257',
#                                     '@nodes': '267 294 295 268',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '258',
#                                     '@nodes': '268 295 296 269',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '259',
#                                     '@nodes': '269 296 297 270',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '260',
#                                     '@nodes': '270 297 298 271',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '261',
#                                     '@nodes': '271 298 299 272',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '262',
#                                     '@nodes': '273 300 301 274',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '263',
#                                     '@nodes': '274 301 302 275',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '264',
#                                     '@nodes': '275 302 303 276',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '265',
#                                     '@nodes': '276 303 304 277',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '266',
#                                     '@nodes': '277 304 305 278',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '267',
#                                     '@nodes': '278 305 306 279',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '268',
#                                     '@nodes': '279 306 307 280',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '269',
#                                     '@nodes': '280 307 308 281',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '270',
#                                     '@nodes': '281 308 309 282',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '271',
#                                     '@nodes': '282 309 310 283',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '272',
#                                     '@nodes': '283 310 311 284',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '273',
#                                     '@nodes': '284 311 312 285',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '274',
#                                     '@nodes': '285 312 313 286',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '275',
#                                     '@nodes': '286 313 314 287',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '276',
#                                     '@nodes': '287 314 315 288',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '277',
#                                     '@nodes': '288 315 316 289',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '278',
#                                     '@nodes': '289 316 317 290',
#                                     '@shape': 'quad4'},
#                                   { '@eid': '279',
#                                     '@nodes': '290 317 318 291',
# ...
#                                                                      '@stressyy': '0.190656375176944',
#                                                                      '@tresca': '8.60520428637713',
#                                                                      '@vonmises': '7.73667908577433'}]},
#                                                   { '@eid': '434',
#                                                     'localnode': [ { '@id': '1',
#                                                                      '@principal1': '6.05776666881084',
#                                                                      '@principal2': '-2.47143532408347',
#                                                                      '@stressxx': '3.83423833685715',
#                                                                      '@stressxy': '-3.74444175240524',
#                                                                      '@stressyy': '-0.247906992129778',
#                                                                      '@tresca': '8.52920199289431',
#                                                                      '@vonmises': '7.60104651381885'},
#                                                                    { '@id': '2',
#                                                                      '@principal1': '5.65338528962483',
#                                                                      '@principal2': '-2.00407075556036',
#                                                                      '@stressxx': '3.84877291901187',
#                                                                      '@stressxy': '-3.24994062998031',
#                                                                      '@stressyy': '-0.199458384947401',
#                                                                      '@tresca': '7.65745604518518',
#                                                                      '@vonmises': '6.87799745239055'},
#                                                                    { '@id': '3',
#                                                                      '@principal1': '6.85454845952413',
#                                                                      '@principal2': '-1.34833175145577',
#                                                                      '@stressxx': '5.27715920670713',
#                                                                      '@stressxy': '-3.23279727666959',
#                                                                      '@stressyy': '0.229057501361231',
#                                                                      '@tresca': '8.20288021097989',
#                                                                      '@vonmises': '7.61872944957471'},
#                                                                    { '@id': '4',
#                                                                      '@principal1': '7.23265592200138',
#                                                                      '@principal2': '-1.78942240327019',
#                                                                      '@stressxx': '5.2626246245524',
#                                                                      '@stressxy': '-3.72729839909452',
#                                                                      '@stressyy': '0.180608894178795',
#                                                                      '@tresca': '9.02207832527156',
#                                                                      '@vonmises': '8.2737911966257'}]},
#                                                   { '@eid': '435',
#                                                     'localnode': [ { '@id': '1',
#                                                                      '@principal1': '6.90553265543037',
#                                                                      '@principal2': '-2.03132967137376',
#                                                                      '@stressxx': '5.13130988578134',
#                                                                      '@stressxy': '-3.56484476423496',
#                                                                      '@stressyy': '-0.257106901724726',
#                                                                      '@tresca': '8.93686232680413',
#                                                                      '@vonmises': '8.11419095588924'},
#                                                                    { '@id': '2',
#                                                                      '@principal1': '6.54922918487194',
#                                                                      '@principal2': '-1.59282857810502',
#                                                                      '@stressxx': '5.15027856794526',
#                                                                      '@stressxy': '-3.07136352488106',
#                                                                      '@stressyy': '-0.193877961178339',
#                                                                      '@tresca': '8.14205776297697',
#                                                                      '@vonmises': '7.47404209283236'},
#                                                                    { '@id': '3',
#                                                                      '@principal1': '7.80376714038608',
#                                                                      '@principal2': '-0.994294124616749',
#                                                                      '@stressxx': '6.5757188825625',
#                                                                      '@stressxy': '-3.04899020745694',
#                                                                      '@stressyy': '0.233754133206834',
#                                                                      '@tresca': '8.79806126500283',
#                                                                      '@vonmises': '8.34545638088056'},
#                                                                    { '@id': '4',
#                                                                      '@principal1': '8.13281701941466',
#                                                                      '@principal2': '-1.40554162635562',
#                                                                      '@stressxx': '6.55675020039858',
#                                                                      '@stressxy': '-3.54247144681085',
#                                                                      '@stressyy': '0.170525192660446',
#                                                                      '@tresca': '9.53835864577028',
#                                                                      '@vonmises': '8.91903990320819'}]},
#                                                   { '@eid': '436',
#                                                     'localnode': [ { '@id': '1',
#                                                                      '@principal1': '7.80751755484005',
#                                                                      '@principal2': '-1.64750034839466',
#                                                                      '@stressxx': '6.42584446502621',
#                                                                      '@stressxy': '-3.33986875093794',
#                                                                      '@stressyy': '-0.265827258580813',
#                                                                      '@tresca': '9.45501790323471',
#                                                                      '@vonmises': '8.74839846250686'},
#                                                                    { '@id': '2',
#                                                                      '@principal1': '7.50371450771624',
#                                                                      '@principal2': '-1.24177756065848',
#                                                                      '@stressxx': '6.44936440516752',
#                                                                      '@stressxy': '-2.84765804133596',
#                                                                      '@stressyy': '-0.187427458109763',
#                                                                      '@tresca': '8.74549206837471',
#                                                                      '@vonmises': '8.19546748030492'},
#                                                                    { '@id': '3',
#                                                                      '@principal1': '8.80000108467379',
#                                                                      '@principal2': '-0.689762697478018',
#                                                                      '@stressxx': '7.87113474373523',
#                                                                      '@stressxy': '-2.81991657347697',
#                                                                      '@stressyy': '0.239103643460548',
#                                                                      '@tresca': '9.48976378215181',
#                                                                      '@vonmises': '9.16437145444608'},
#                                                                    { '@id': '4',
#                                                                      '@principal1': '9.07785000842231',
#                                                                      '@principal2': '-1.0695313618389',
#                                                                      '@stressxx': '7.84761480359391',
#                                                                      '@stressxy': '-3.31212728307896',
#                                                                      '@stressyy': '0.160703842989498',
#                                                                      '@tresca': '10.1473813702612',
#                                                                      '@vonmises': '9.65713743256495'}]},
#                                                   { '@eid': '437',
#                                                     'localnode': [ { '@id': '1',
#                                                                      '@principal1': '8.76043851228164',
#                                                                      '@principal2': '-1.31685584396466',
#                                                                      '@stressxx': '7.71729111630167',
#                                                                      '@stressxy': '-3.06984476423518',
#                                                                      '@stressyy': '-0.273708447984691',
#                                                                      '@tresca': '10.0772943562463',
#                                                                      '@vonmises': '9.48765655427315'},
#                                                                    { '@id': '2',
#                                                                      '@principal1': '8.51080148178661',
#                                                                      '@principal2': '-0.945325048403188',
#                                                                      '@stressxx': '7.74542044670162',
#                                                                      '@stressxy': '-2.57909514805164',
#                                                                      '@stressyy': '-0.1799440133182',
#                                                                      '@tresca': '9.4561265301898',
#                                                                      '@vonmises': '9.02069039110862'},
#                                                                    { '@id': '3',
#                                                                      '@principal1': '9.83861845430212',
#                                                                      '@principal2': '-0.430327135658177',
#                                                                      '@stressxx': '9.16297035844051',
#                                                                      '@stressxy': '-2.54591696347734',
#                                                                      '@stressyy': '0.245320960203429',
#                                                                      '@tresca': '10.2689455899603',
#                                                                      '@vonmises': '10.0606868071366'},
#                                                                    { '@id': '4',
#                                                                      '@principal1': '10.0650244867558',
#                                                                      '@principal2': '-0.778626933178318',
#                                                                      '@stressxx': '9.13484102804054',
#                                                                      '@stressxy': '-3.03666657966088',
#                                                                      '@stressyy': '0.151556525536928',
#                                                                      '@tresca': '10.8436514199341',
#                                                                      '@vonmises': '10.4760620926258'}]},
#                                                   { '@eid': '438',
#                                                     'localnode': [ { '@id': '1',
#                                                                      '@principal1': '9.7613068095375',
#                                                                      '@principal2': '-1.03645853901867',
#                                                                      '@stressxx': '9.0052527319501',
#                                                                      '@stressxy': '-2.75537234368991',
#                                                                      '@stressyy': '-0.280404461431275',
#                                                                      '@tresca': '10.7977653485562',
#                                                                      '@vonmises': '10.3186504315125'},
#                                                                    { '@id': '2',
#                                                                      '@principal1': '9.56539732547381',
#                                                                      '@principal2': '-0.698790751641184',
#                                                                      '@stressxx': '9.03796618656099',
#                                                                      '@stressxy': '-2.26615727636748',
#                                                                      '@stressyy': '-0.171359612728365',
#                                                                      '@tresca': '10.264188077115',
#                                                                      '@vonmises': '9.93324446973773'},
#                                                                    { '@id': '3',
#                                                                      '@principal1': '10.9164021801525',
#                                                                      '@principal2': '-0.21274310861923',
#                                                                      '@stressxx': '10.4510834924846',
#                                                                      '@stressxy': '-2.22757217605717',
#                                                                      '@stressyy': '0.252575579048708',
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)

# %%
def calc_g(rhos):
    g = np.dot(rhos, vs.transpose()) - a*V0
    return g

# %%
def calc_rho_i(lmbda, sigma_i):
    rho_i = (-(n-1)/E0 * np.dot(nu*sigma_i, sigma_i.transpose())  / lmbda ) ** (1/n)
    if rho_i > 1:
        rho_i = 1 
    elif rho_i < 0.01:
        rho_i = 0.01
    return rho_i

# %%
def calc_D(rho_i, lmbda, sigma_i):
    D = -lmbda * E0 * rho_i**n / ((n-1) * np.dot(nu*sigma_i, sigma_i.transpose()))
    return D

# %%
def update_rho_i(rho_i, lmbda, sigma_i):
    D = calc_D(rho_i, lmbda, sigma_i)
    while abs(D-1) > 1e-3:
        if D > 1:
            rho_i = rho_i - drho 
        else:
            rho_i = rho_i + drho
        if rho_i > 1:
            rho_i = 1 
            break 
        elif rho_i < 0.01:
            rho_i = 0.01
            break 
        D = calc_D(rho_i,lmbda, sigma_i)
    return rho_i

# %%
def update_lambda(g, lmbda):
    if g<0:
        lmbda = lmbda - dlambda #ラムダを右にシフト
        if lmbda > 0:
            lmbda = lmbda + dlambda #λは正にならないので、もし正になったら負に戻す
    else:
        lmbda = lmbda + dlambda #ラムダを左にシフト
    return lmbda

# %%
def check_if_all_rhos_are_settled(rhos):
    for i in range(ne):
        if (rhos[i] == 1) or (rhos[i] == 0.01):
            continue
        else:
            return False
    return True

# %%
# グローバルなパラメータ
a = 0.375
E0 = 200e9
n = 2 #3が適当??
nu = 0.3

# %%
#要素リストの抽出
elset = my_dict['liml8']['elset'].copy()
if type(elset)==dict:
    elem_list = elset['elem']
elif type(elset)==list:
    elem_list = []
    for e in elset:
        if "elem" in e:
            elem_list.append(e['elem'])
# FEMの結果を変数に格納
nodes = my_dict['liml8']['node'].copy() #nodes
result_elems = my_dict['liml8']['solution']['results']['elem'].copy()
ne = len(elem_list)
sigmas = np.zeros((ne,3))
# ρの初期化。初回か２回目以降かで異なる。
if type(elset)==dict: #初回
    rhos = np.ones(ne) * a #初回はすべて平均値のaで代替する。
elif type(elset)==list: #２回目以降
    mat_list = my_dict['liml8']['mat'].copy()
    E = np.array([x['mechanical']['@youngsmodulus'] for x in mat_list[1:]], dtype=np.double)
    rhos = (E/E0) ** (1/n)
Es = np.zeros(ne)
vs = np.zeros(ne)
cxs = np.zeros(ne)
cys = np.zeros(ne)
# Load stress from each element
lambda_tmp = 0
for i in range(ne):
    Es[i] = rhos[i]**n * E0
    sigma_x = np.array(list(map(lambda x: x['@stressxx'], result_elems[i]['localnode'])),dtype=np.double).sum()
    sigma_y = np.array(list(map(lambda x: x['@stressyy'], result_elems[i]['localnode'])),dtype=np.double).sum()
    tau_xy = np.array(list(map(lambda x: x['@stressxy'], result_elems[i]['localnode'])),dtype=np.double).sum()
    sigmas[i] = np.array([sigma_x,sigma_y,tau_xy])
    lambda_tmp += np.dot(nu*sigmas[i], sigmas[i].transpose())/(rhos[i]**n)
    node_ids = elem_list[i]['@nodes'].split(' ')
    vertices = np.zeros((4, 2))
    n_nodes_in_elems = len(node_ids)
    for j in range(n_nodes_in_elems):
        (x,y) = findXY(node_ids[j])
        vertices[j, :] = (x,y)
    vs[i] = shoelace_area(vertices)
    cxs[i] = vertices[:,0].sum() / n_nodes_in_elems 
    cys[i] = vertices[:,1].sum() / n_nodes_in_elems 

# トータルの体積V0
V0 = vs.sum()  
# lambda_barはlmbdaの初期値
lambda_bar = -1/ne*(n-1)/E0 * lambda_tmp     
lmbda = lambda_bar
dlambda = 0.1 * lambda_bar
drho = 0.05

tolerance = 0.01 
g_prev = 0
g_res = []
l_res = []
is_dump_enabled = True
for i in range(ne):
    if is_dump_enabled: print(str(i)+'th element')
    lmbda = lambda_bar
    # λを更新するアウターループ
    while True:
        # λにしたがってρiを計算する
        rhos[i] = calc_rho_i(lmbda, sigmas[i])
        # ρを更新するインナーループ
        rhos[i] = update_rho_i(rhos[i], lmbda, sigmas[i])
        if check_if_all_rhos_are_settled(rhos): 
            if is_dump_enabled: print("***All rhos are settled.***") 
            break 
        g = calc_g(rhos)
        lmbda = update_lambda(g, lmbda)
        if g==g_prev: #gに変化が見られない場合、λの最適解と判定、
            if is_dump_enabled: print("  No change in g.") 
            break
        if abs(g/V0) < tolerance: #gが0に近づいたらλの最適解と判定
            if is_dump_enabled: print("  g is almost zero") 
            break
        if g*g_prev< 0: #gの符号が変わったらラムダの最適解と判定
            if is_dump_enabled: print("  Sign of g changed.") 
            break
        g_prev = g
    # if is_dump_enabled: print(f"  g/V0: {g/V0}, λ:{lmbda}") 
    g_res.append(g)
    l_res.append(lmbda)
    if(rhos[i]>1):
        print('warning: rho > 1')
plt.rcParams['figure.figsize'] = [8, 2]
plt.subplot(1,2,1)    
plt.plot(range(ne), g_res)
plt.title('g')
plt.xlabel('i-th element')
plt.ylabel('g')
plt.subplot(1,2,2)    
plt.plot(range(ne), l_res)
plt.title('lambda')
plt.xlabel('i-th element')
plt.ylabel('lambda')
# Out:
# 0th element
#   g is almost zero
# 1th element
#   g is almost zero
# 2th element
#   g is almost zero
# 3th element
#   g is almost zero
# 4th element
#   g is almost zero
# 5th element
#   g is almost zero
# 6th element
#   g is almost zero
# 7th element
#   g is almost zero
# 8th element
#   g is almost zero
# 9th element
#   g is almost zero
# 10th element
#   g is almost zero
# 11th element
#   g is almost zero
# 12th element
#   g is almost zero
# 13th element
#   g is almost zero
# 14th element
#   g is almost zero
# 15th element
#   g is almost zero
# 16th element
#   g is almost zero
# 17th element
#   g is almost zero
# 18th element
#   g is almost zero
# 19th element
#   g is almost zero
# 20th element
#   g is almost zero
# 21th element
#   g is almost zero
# 22th element
#   g is almost zero
# 23th element
#   g is almost zero
# 24th element
#   g is almost zero
# 25th element
#   g is almost zero
# 26th element
#   g is almost zero
# 27th element
#   g is almost zero
# 28th element
#   g is almost zero
# 29th element
#   g is almost zero
# 30th element
#   g is almost zero
# 31th element
#   g is almost zero
# 32th element
#   g is almost zero
# 33th element
#   g is almost zero
# 34th element
#   g is almost zero
# 35th element
#   g is almost zero
# 36th element
#   g is almost zero
# 37th element
#   g is almost zero
# 38th element
#   g is almost zero
# 39th element
#   g is almost zero
# 40th element
#   g is almost zero
# 41th element
#   g is almost zero
# 42th element
#   g is almost zero
# 43th element
#   g is almost zero
# 44th element
#   g is almost zero
# 45th element
#   g is almost zero
# 46th element
#   g is almost zero
# 47th element
#   g is almost zero
# 48th element
#   g is almost zero
# 49th element
#   g is almost zero
# 50th element
#   g is almost zero
# 51th element
#   g is almost zero
# 52th element
#   g is almost zero
# 53th element
#   g is almost zero
# 54th element
#   g is almost zero
# 55th element
#   g is almost zero
# 56th element
#   g is almost zero
# 57th element
#   g is almost zero
# 58th element
#   g is almost zero
# 59th element
#   g is almost zero
# 60th element
#   g is almost zero
# 61th element
#   g is almost zero
# 62th element
#   g is almost zero
# 63th element
#   g is almost zero
# 64th element
#   g is almost zero
# 65th element
#   g is almost zero
# 66th element
#   g is almost zero
# 67th element
#   g is almost zero
# 68th element
#   g is almost zero
# 69th element
#   g is almost zero
# 70th element
#   g is almost zero
# 71th element
#   g is almost zero
# 72th element
#   g is almost zero
# 73th element
#   g is almost zero
# 74th element
#   g is almost zero
# 75th element
#   g is almost zero
# 76th element
#   g is almost zero
# 77th element
#   g is almost zero
# 78th element
#   g is almost zero
# 79th element
#   g is almost zero
# 80th element
#   g is almost zero
# 81th element
#   g is almost zero
# 82th element
#   g is almost zero
# 83th element
#   g is almost zero
# 84th element
#   g is almost zero
# 85th element
#   g is almost zero
# 86th element
#   g is almost zero
# 87th element
#   g is almost zero
# 88th element
#   g is almost zero
# 89th element
#   g is almost zero
# 90th element
#   g is almost zero
# 91th element
#   g is almost zero
# 92th element
#   g is almost zero
# 93th element
#   g is almost zero
# 94th element
#   g is almost zero
# 95th element
#   g is almost zero
# 96th element
#   g is almost zero
# 97th element
#   g is almost zero
# 98th element
#   g is almost zero
# 99th element
#   g is almost zero
# 100th element
#   g is almost zero
# 101th element
#   g is almost zero
# 102th element
#   g is almost zero
# 103th element
#   g is almost zero
# 104th element
#   g is almost zero
# 105th element
#   g is almost zero
# 106th element
#   g is almost zero
# 107th element
#   g is almost zero
# 108th element
#   g is almost zero
# 109th element
#   g is almost zero
# 110th element
#   g is almost zero
# 111th element
#   g is almost zero
# 112th element
#   g is almost zero
# 113th element
#   g is almost zero
# 114th element
#   g is almost zero
# 115th element
#   g is almost zero
# 116th element
#   g is almost zero
# 117th element
#   g is almost zero
# 118th element
#   g is almost zero
# 119th element
#   g is almost zero
# 120th element
#   g is almost zero
# 121th element
#   g is almost zero
# 122th element
#   g is almost zero
# 123th element
#   g is almost zero
# 124th element
#   g is almost zero
# 125th element
#   g is almost zero
# 126th element
#   g is almost zero
# 127th element
#   g is almost zero
# 128th element
#   g is almost zero
# 129th element
#   g is almost zero
# 130th element
#   g is almost zero
# 131th element
#   g is almost zero
# 132th element
#   g is almost zero
# 133th element
#   g is almost zero
# 134th element
#   g is almost zero
# 135th element
#   g is almost zero
# 136th element
#   g is almost zero
# 137th element
#   g is almost zero
# 138th element
#   g is almost zero
# 139th element
#   g is almost zero
# 140th element
#   g is almost zero
# 141th element
#   g is almost zero
# 142th element
#   g is almost zero
# 143th element
#   g is almost zero
# 144th element
#   g is almost zero
# 145th element
#   g is almost zero
# 146th element
#   g is almost zero
# 147th element
#   g is almost zero
# 148th element
#   g is almost zero
# 149th element
#   g is almost zero
# 150th element
#   g is almost zero
# 151th element
#   g is almost zero
# 152th element
#   g is almost zero
# 153th element
#   g is almost zero
# 154th element
#   g is almost zero
# 155th element
#   g is almost zero
# 156th element
#   g is almost zero
# 157th element
#   g is almost zero
# 158th element
#   g is almost zero
# 159th element
#   g is almost zero
# 160th element
#   g is almost zero
# 161th element
#   g is almost zero
# 162th element
#   g is almost zero
# 163th element
#   g is almost zero
# 164th element
#   g is almost zero
# 165th element
#   g is almost zero
# 166th element
#   g is almost zero
# 167th element
#   g is almost zero
# 168th element
#   g is almost zero
# 169th element
#   g is almost zero
# 170th element
#   g is almost zero
# 171th element
#   g is almost zero
# 172th element
#   g is almost zero
# 173th element
#   g is almost zero
# 174th element
#   g is almost zero
# 175th element
#   g is almost zero
# 176th element
#   g is almost zero
# 177th element
#   g is almost zero
# 178th element
#   g is almost zero
# 179th element
#   g is almost zero
# 180th element
#   g is almost zero
# 181th element
#   g is almost zero
# 182th element
#   g is almost zero
# 183th element
#   g is almost zero
# 184th element
#   g is almost zero
# 185th element
#   g is almost zero
# 186th element
#   g is almost zero
# 187th element
#   g is almost zero
# 188th element
#   g is almost zero
# 189th element
#   g is almost zero
# 190th element
#   g is almost zero
# 191th element
#   g is almost zero
# 192th element
#   g is almost zero
# 193th element
#   g is almost zero
# 194th element
#   g is almost zero
# 195th element
#   g is almost zero
# 196th element
#   g is almost zero
# 197th element
#   g is almost zero
# 198th element
#   g is almost zero
# 199th element
#   g is almost zero
# 200th element
#   g is almost zero
# 201th element
#   g is almost zero
# 202th element
#   g is almost zero
# 203th element
#   g is almost zero
# 204th element
#   g is almost zero
# 205th element
#   g is almost zero
# 206th element
#   g is almost zero
# 207th element
#   g is almost zero
# 208th element
#   g is almost zero
# 209th element
#   g is almost zero
# 210th element
#   g is almost zero
# 211th element
#   g is almost zero
# 212th element
#   g is almost zero
# 213th element
#   g is almost zero
# 214th element
#   g is almost zero
# 215th element
#   g is almost zero
# 216th element
#   g is almost zero
# 217th element
#   g is almost zero
# 218th element
#   g is almost zero
# 219th element
#   g is almost zero
# 220th element
#   g is almost zero
# 221th element
#   g is almost zero
# 222th element
#   g is almost zero
# 223th element
#   g is almost zero
# 224th element
#   g is almost zero
# 225th element
#   g is almost zero
# 226th element
#   g is almost zero
# 227th element
#   g is almost zero
# 228th element
#   g is almost zero
# 229th element
#   g is almost zero
# 230th element
#   g is almost zero
# 231th element
#   g is almost zero
# 232th element
#   g is almost zero
# 233th element
#   g is almost zero
# 234th element
#   g is almost zero
# 235th element
#   g is almost zero
# 236th element
#   g is almost zero
# 237th element
#   g is almost zero
# 238th element
#   g is almost zero
# 239th element
#   g is almost zero
# 240th element
#   g is almost zero
# 241th element
#   g is almost zero
# 242th element
#   g is almost zero
# 243th element
#   g is almost zero
# 244th element
#   g is almost zero
# 245th element
#   g is almost zero
# 246th element
#   g is almost zero
# 247th element
#   g is almost zero
# 248th element
#   g is almost zero
# 249th element
#   g is almost zero
# 250th element
#   g is almost zero
# 251th element
#   g is almost zero
# 252th element
#   g is almost zero
# 253th element
#   g is almost zero
# 254th element
#   g is almost zero
# 255th element
#   g is almost zero
# 256th element
#   g is almost zero
# 257th element
#   g is almost zero
# 258th element
#   g is almost zero
# 259th element
#   g is almost zero
# 260th element
#   g is almost zero
# 261th element
#   g is almost zero
# 262th element
#   g is almost zero
# 263th element
#   g is almost zero
# 264th element
#   g is almost zero
# 265th element
#   g is almost zero
# 266th element
#   g is almost zero
# 267th element
#   g is almost zero
# 268th element
#   g is almost zero
# 269th element
#   g is almost zero
# 270th element
#   g is almost zero
# 271th element
#   g is almost zero
# 272th element
#   g is almost zero
# 273th element
#   g is almost zero
# 274th element
#   g is almost zero
# 275th element
#   g is almost zero
# 276th element
#   g is almost zero
# 277th element
#   g is almost zero
# 278th element
#   g is almost zero
# 279th element
#   g is almost zero
# 280th element
#   g is almost zero
# 281th element
#   g is almost zero
# 282th element
#   g is almost zero
# 283th element
#   g is almost zero
# 284th element
#   g is almost zero
# 285th element
#   g is almost zero
# 286th element
#   g is almost zero
# 287th element
#   g is almost zero
# 288th element
#   g is almost zero
# 289th element
#   g is almost zero
# 290th element
#   g is almost zero
# 291th element
#   g is almost zero
# 292th element
#   g is almost zero
# 293th element
#   g is almost zero
# 294th element
#   g is almost zero
# 295th element
#   g is almost zero
# 296th element
#   g is almost zero
# 297th element
#   g is almost zero
# 298th element
#   g is almost zero
# 299th element
#   g is almost zero
# 300th element
#   g is almost zero
# 301th element
#   g is almost zero
# 302th element
#   g is almost zero
# 303th element
#   g is almost zero
# 304th element
#   g is almost zero
# 305th element
#   g is almost zero
# 306th element
#   g is almost zero
# 307th element
#   g is almost zero
# 308th element
#   g is almost zero
# 309th element
#   g is almost zero
# 310th element
#   g is almost zero
# 311th element
#   g is almost zero
# 312th element
#   g is almost zero
# 313th element
#   g is almost zero
# 314th element
#   g is almost zero
# 315th element
#   g is almost zero
# 316th element
#   g is almost zero
# 317th element
#   g is almost zero
# 318th element
#   g is almost zero
# 319th element
#   g is almost zero
# 320th element
#   g is almost zero
# 321th element
#   g is almost zero
# 322th element
#   g is almost zero
# 323th element
#   g is almost zero
# 324th element
#   g is almost zero
# 325th element
#   g is almost zero
# 326th element
#   g is almost zero
# 327th element
#   g is almost zero
# 328th element
#   g is almost zero
# 329th element
#   g is almost zero
# 330th element
#   g is almost zero
# 331th element
#   g is almost zero
# 332th element
#   g is almost zero
# 333th element
#   g is almost zero
# 334th element
#   g is almost zero
# 335th element
#   g is almost zero
# 336th element
#   g is almost zero
# 337th element
#   g is almost zero
# 338th element
#   g is almost zero
# 339th element
#   g is almost zero
# 340th element
#   g is almost zero
# 341th element
#   g is almost zero
# 342th element
#   g is almost zero
# 343th element
#   g is almost zero
# 344th element
#   g is almost zero
# 345th element
#   g is almost zero
# 346th element
#   g is almost zero
# 347th element
#   g is almost zero
# 348th element
#   g is almost zero
# 349th element
#   g is almost zero
# 350th element
#   g is almost zero
# 351th element
#   g is almost zero
# 352th element
#   g is almost zero
# 353th element
#   g is almost zero
# 354th element
#   g is almost zero
# 355th element
#   g is almost zero
# 356th element
#   g is almost zero
# 357th element
#   g is almost zero
# 358th element
#   g is almost zero
# 359th element
#   g is almost zero
# 360th element
#   g is almost zero
# 361th element
#   g is almost zero
# 362th element
#   g is almost zero
# 363th element
#   g is almost zero
# 364th element
#   g is almost zero
# 365th element
#   g is almost zero
# 366th element
#   g is almost zero
# 367th element
#   g is almost zero
# 368th element
#   g is almost zero
# 369th element
#   g is almost zero
# 370th element
#   g is almost zero
# 371th element
#   g is almost zero
# 372th element
#   g is almost zero
# 373th element
#   g is almost zero
# 374th element
#   g is almost zero
# 375th element
#   g is almost zero
# 376th element
#   g is almost zero
# 377th element
#   g is almost zero
# 378th element
#   g is almost zero
# 379th element
#   g is almost zero
# 380th element
#   g is almost zero
# 381th element
#   g is almost zero
# 382th element
#   g is almost zero
# 383th element
#   g is almost zero
# 384th element
#   g is almost zero
# 385th element
#   g is almost zero
# 386th element
#   g is almost zero
# 387th element
#   g is almost zero
# 388th element
#   g is almost zero
# 389th element
#   g is almost zero
# 390th element
#   g is almost zero
# 391th element
#   g is almost zero
# 392th element
#   g is almost zero
# 393th element
#   g is almost zero
# 394th element
#   g is almost zero
# 395th element
#   g is almost zero
# 396th element
#   g is almost zero
# 397th element
#   g is almost zero
# 398th element
#   g is almost zero
# 399th element
#   g is almost zero
# 400th element
#   g is almost zero
# 401th element
#   g is almost zero
# 402th element
#   g is almost zero
# 403th element
#   g is almost zero
# 404th element
#   g is almost zero
# 405th element
#   g is almost zero
# 406th element
#   g is almost zero
# 407th element
#   g is almost zero
# 408th element
#   g is almost zero
# 409th element
#   g is almost zero
# 410th element
#   g is almost zero
# 411th element
#   g is almost zero
# 412th element
#   g is almost zero
# 413th element
#   g is almost zero
# 414th element
#   g is almost zero
# 415th element
#   g is almost zero
# 416th element
#   g is almost zero
# 417th element
#   g is almost zero
# 418th element
#   g is almost zero
# 419th element
#   g is almost zero
# 420th element
#   g is almost zero
# 421th element
#   g is almost zero
# 422th element
#   g is almost zero
# 423th element
#   g is almost zero
# 424th element
#   g is almost zero
# 425th element
#   g is almost zero
# 426th element
#   g is almost zero
# 427th element
#   g is almost zero
# 428th element
#   g is almost zero
# 429th element
#   g is almost zero
# 430th element
#   g is almost zero
# 431th element
#   g is almost zero
# 432th element
#   g is almost zero
# 433th element
#   g is almost zero
# 434th element
#   g is almost zero
# 435th element
#   g is almost zero
# 436th element
#   g is almost zero
# 437th element
#   g is almost zero
# 438th element
#   g is almost zero
# 439th element
#   g is almost zero
# 440th element
#   g is almost zero
# 441th element
#   g is almost zero
# 442th element
#   g is almost zero
# 443th element
#   g is almost zero
# 444th element
#   g is almost zero
# 445th element
#   g is almost zero
# 446th element
#   g is almost zero
# 447th element
#   g is almost zero
# 448th element
#   g is almost zero
# 449th element
#   g is almost zero
# 450th element
#   g is almost zero
# 451th element
#   g is almost zero
# 452th element
#   g is almost zero
# 453th element
#   g is almost zero
# 454th element
#   g is almost zero
# 455th element
#   g is almost zero
# 456th element
#   g is almost zero
# 457th element
#   g is almost zero
# 458th element
#   g is almost zero
# 459th element
#   g is almost zero
# 460th element
#   g is almost zero
# 461th element
#   g is almost zero
# 462th element
#   g is almost zero
# 463th element
#   g is almost zero
# 464th element
#   g is almost zero
# 465th element
#   g is almost zero
# 466th element
#   g is almost zero
# 467th element
#   g is almost zero
# 468th element
#   g is almost zero
# 469th element
#   g is almost zero
# 470th element
#   g is almost zero
# 471th element
#   g is almost zero
# 472th element
#   g is almost zero
# 473th element
#   g is almost zero
# 474th element
#   g is almost zero
# 475th element
#   g is almost zero
# 476th element
#   g is almost zero
# 477th element
#   g is almost zero
# 478th element
#   g is almost zero
# 479th element
#   g is almost zero
# 480th element
#   g is almost zero
# 481th element
#   g is almost zero
# 482th element
#   g is almost zero
# 483th element
#   g is almost zero
# 484th element
#   g is almost zero
# 485th element
#   g is almost zero
# 486th element
#   g is almost zero
# 487th element
#   g is almost zero
# 488th element
#   g is almost zero
# 489th element
#   g is almost zero
# 490th element
#   g is almost zero
# 491th element
#   g is almost zero
# 492th element
#   g is almost zero
# 493th element
#   g is almost zero
# 494th element
#   g is almost zero
# 495th element
#   g is almost zero
# 496th element
#   g is almost zero
# 497th element
#   g is almost zero
# 498th element
#   g is almost zero
# 499th element
#   g is almost zero
# 500th element
#   g is almost zero
# 501th element
#   g is almost zero
# 502th element
#   g is almost zero
# 503th element
#   g is almost zero
# 504th element
#   g is almost zero
# 505th element
#   g is almost zero
# 506th element
#   g is almost zero
# 507th element
#   g is almost zero
# 508th element
#   g is almost zero
# 509th element
#   g is almost zero
# 510th element
#   g is almost zero
# 511th element
#   g is almost zero
# 512th element
#   g is almost zero
# 513th element
#   g is almost zero
# 514th element
#   g is almost zero
# 515th element
#   g is almost zero
# 516th element
#   g is almost zero
# 517th element
#   g is almost zero
# 518th element
#   g is almost zero
# 519th element
#   g is almost zero
# 520th element
#   g is almost zero
# 521th element
#   g is almost zero
# 522th element
#   g is almost zero
# 523th element
#   g is almost zero
# 524th element
#   g is almost zero
# 525th element
#   g is almost zero
# 526th element
#   g is almost zero
# 527th element
#   g is almost zero
# 528th element
#   g is almost zero
# 529th element
#   g is almost zero
# 530th element
#   g is almost zero
# 531th element
#   g is almost zero
# 532th element
#   g is almost zero
# 533th element
#   g is almost zero
# 534th element
#   g is almost zero
# 535th element
#   g is almost zero
# 536th element
#   g is almost zero
# 537th element
#   g is almost zero
# 538th element
#   g is almost zero
# 539th element
#   g is almost zero
# 540th element
#   g is almost zero
# 541th element
#   g is almost zero
# 542th element
#   g is almost zero
# 543th element
#   g is almost zero
# 544th element
#   g is almost zero
# 545th element
#   g is almost zero
# 546th element
#   g is almost zero
# 547th element
#   g is almost zero
# 548th element
#   g is almost zero
# 549th element
#   g is almost zero
# 550th element
#   g is almost zero
# 551th element
#   g is almost zero
# 552th element
#   g is almost zero
# 553th element
#   g is almost zero
# 554th element
#   g is almost zero
# 555th element
#   g is almost zero
# 556th element
#   g is almost zero
# 557th element
#   g is almost zero
# 558th element
#   g is almost zero
# 559th element
#   g is almost zero
# 560th element
#   g is almost zero
# 561th element
#   g is almost zero
# 562th element
#   g is almost zero
# 563th element
#   g is almost zero
# 564th element
#   g is almost zero
# 565th element
#   g is almost zero
# 566th element
#   g is almost zero
# 567th element
#   g is almost zero
# 568th element
#   g is almost zero
# 569th element
#   g is almost zero
# 570th element
#   g is almost zero
# 571th element
#   g is almost zero
# 572th element
#   g is almost zero
# 573th element
#   g is almost zero
# 574th element
#   g is almost zero
# 575th element
#   g is almost zero
# 576th element
#   g is almost zero
# 577th element
#   g is almost zero
# 578th element
#   g is almost zero
# 579th element
#   g is almost zero
# 580th element
#   g is almost zero
# 581th element
#   g is almost zero
# 582th element
#   g is almost zero
# 583th element
#   g is almost zero
# 584th element
#   g is almost zero
# 585th element
#   g is almost zero
# 586th element
#   g is almost zero
# 587th element
#   g is almost zero
# 588th element
#   g is almost zero
# 589th element
#   g is almost zero
# 590th element
#   g is almost zero
# 591th element
#   g is almost zero
# 592th element
#   g is almost zero
# 593th element
#   g is almost zero
# 594th element
#   g is almost zero
# 595th element
#   g is almost zero
# 596th element
#   g is almost zero
# 597th element
#   g is almost zero
# 598th element
#   g is almost zero
# 599th element
#   g is almost zero
# 600th element
#   g is almost zero
# 601th element
#   g is almost zero
# 602th element
#   g is almost zero
# 603th element
#   g is almost zero
# 604th element
#   g is almost zero
# 605th element
#   g is almost zero
# 606th element
#   g is almost zero
# 607th element
#   g is almost zero
# 608th element
#   g is almost zero
# 609th element
#   g is almost zero
# 610th element
#   g is almost zero
# 611th element
#   g is almost zero
# 612th element
#   g is almost zero
# 613th element
#   g is almost zero
# 614th element
#   g is almost zero
# 615th element
#   g is almost zero
# 616th element
#   g is almost zero
# 617th element
#   g is almost zero
# 618th element
#   g is almost zero
# 619th element
#   g is almost zero
# 620th element
#   g is almost zero
# 621th element
#   g is almost zero
# 622th element
#   g is almost zero
# 623th element
#   g is almost zero
# 624th element
#   g is almost zero
# 625th element
#   g is almost zero
# 626th element
#   g is almost zero
# 627th element
#   g is almost zero
# 628th element
#   g is almost zero
# 629th element
#   g is almost zero
# 630th element
#   g is almost zero
# 631th element
#   g is almost zero
# 632th element
#   g is almost zero
# 633th element
#   g is almost zero
# 634th element
#   g is almost zero
# 635th element
#   g is almost zero
# 636th element
#   g is almost zero
# 637th element
#   g is almost zero
# 638th element
#   g is almost zero
# 639th element
#   g is almost zero
# 640th element
#   g is almost zero
# 641th element
#   g is almost zero
# 642th element
#   g is almost zero
# 643th element
#   g is almost zero
# 644th element
#   g is almost zero
# 645th element
#   g is almost zero
# 646th element
#   g is almost zero
# 647th element
#   g is almost zero
# 648th element
#   g is almost zero
# 649th element
#   g is almost zero
# 650th element
#   g is almost zero
# 651th element
#   g is almost zero
# 652th element
#   g is almost zero
# 653th element
#   g is almost zero
# 654th element
#   g is almost zero
# 655th element
#   g is almost zero
# 656th element
#   g is almost zero
# 657th element
#   g is almost zero
# 658th element
#   g is almost zero
# 659th element
#   g is almost zero
# 660th element
#   g is almost zero
# 661th element
#   g is almost zero
# 662th element
#   g is almost zero
# 663th element
#   g is almost zero
# 664th element
#   g is almost zero
# 665th element
#   g is almost zero
# 666th element
#   g is almost zero
# 667th element
#   g is almost zero
# 668th element
#   g is almost zero
# 669th element
#   g is almost zero
# 670th element
#   g is almost zero
# 671th element
#   g is almost zero
# 672th element
#   g is almost zero
# 673th element
#   g is almost zero
# 674th element
#   g is almost zero
# 675th element
#   g is almost zero
# 676th element
#   g is almost zero
# 677th element
#   g is almost zero
# 678th element
#   g is almost zero
# 679th element
#   g is almost zero
# 680th element
#   g is almost zero
# 681th element
#   g is almost zero
# 682th element
#   g is almost zero
# 683th element
#   g is almost zero
# 684th element
#   g is almost zero
# 685th element
#   g is almost zero
# 686th element
#   g is almost zero
# 687th element
#   g is almost zero
# 688th element
#   g is almost zero
# 689th element
#   g is almost zero
# 690th element
#   g is almost zero
# 691th element
#   g is almost zero
# 692th element
#   g is almost zero
# 693th element
#   g is almost zero
# 694th element
#   g is almost zero
# 695th element
#   g is almost zero
# 696th element
#   g is almost zero
# 697th element
#   g is almost zero
# 698th element
#   g is almost zero
# 699th element
#   g is almost zero
# 700th element
#   g is almost zero
# 701th element
#   g is almost zero
# 702th element
#   g is almost zero
# 703th element
#   g is almost zero
# 704th element
#   g is almost zero
# 705th element
#   g is almost zero
# 706th element
#   g is almost zero
# 707th element
#   g is almost zero
# 708th element
#   g is almost zero
# 709th element
#   g is almost zero
# 710th element
#   g is almost zero
# 711th element
#   g is almost zero
# 712th element
#   g is almost zero
# 713th element
#   g is almost zero
# 714th element
#   g is almost zero
# 715th element
#   g is almost zero
# 716th element
#   g is almost zero
# 717th element
#   g is almost zero
# 718th element
#   g is almost zero
# 719th element
#   g is almost zero
# 720th element
#   g is almost zero
# 721th element
#   g is almost zero
# 722th element
#   g is almost zero
# 723th element
#   g is almost zero
# 724th element
#   g is almost zero
# 725th element
#   g is almost zero
# 726th element
#   g is almost zero
# 727th element
#   g is almost zero
# 728th element
#   g is almost zero
# 729th element
#   g is almost zero
# 730th element
#   g is almost zero
# 731th element
#   g is almost zero
# 732th element
#   g is almost zero
# 733th element
#   g is almost zero
# 734th element
#   g is almost zero
# 735th element
#   g is almost zero
# 736th element
#   g is almost zero
# 737th element
#   g is almost zero
# 738th element
#   g is almost zero
# 739th element
#   g is almost zero
# 740th element
#   g is almost zero
# 741th element
#   g is almost zero
# 742th element
#   g is almost zero
# 743th element
#   g is almost zero
# 744th element
#   g is almost zero
# 745th element
#   g is almost zero
# 746th element
#   Sign of g changed.
# 747th element
#   Sign of g changed.
# 748th element
#   Sign of g changed.
# 749th element
#   Sign of g changed.
# 750th element
#   Sign of g changed.
# 751th element
#   Sign of g changed.
# 752th element
#   Sign of g changed.
# 753th element
#   Sign of g changed.
# 754th element
#   Sign of g changed.
# 755th element
#   Sign of g changed.
# 756th element
#   Sign of g changed.
# 757th element
#   Sign of g changed.
# 758th element
#   Sign of g changed.
# 759th element
#   Sign of g changed.
# 760th element
#   Sign of g changed.
# 761th element
#   Sign of g changed.
# 762th element
#   Sign of g changed.
# 763th element
#   Sign of g changed.
# 764th element
#   Sign of g changed.
# 765th element
#   Sign of g changed.
# 766th element
#   Sign of g changed.
# 767th element
#   Sign of g changed.
# 768th element
#   Sign of g changed.
# 769th element
#   Sign of g changed.
# 770th element
#   Sign of g changed.
# 771th element
#   Sign of g changed.
# 772th element
#   Sign of g changed.
# 773th element
#   Sign of g changed.
# 774th element
#   Sign of g changed.
# 775th element
#   Sign of g changed.
# 776th element
#   Sign of g changed.
# 777th element
#   Sign of g changed.
# 778th element
#   Sign of g changed.
# 779th element
#   Sign of g changed.
# 780th element
#   Sign of g changed.
# 781th element
#   Sign of g changed.
# 782th element
#   Sign of g changed.
# 783th element
#   Sign of g changed.
# 784th element
#   Sign of g changed.
# 785th element
#   Sign of g changed.
# 786th element
#   Sign of g changed.
# 787th element
#   Sign of g changed.
# 788th element
#   Sign of g changed.
# 789th element
#   Sign of g changed.
# 790th element
#   Sign of g changed.
# 791th element
#   Sign of g changed.
# 792th element
#   Sign of g changed.
# 793th element
#   Sign of g changed.
# 794th element
#   Sign of g changed.
# 795th element
#   Sign of g changed.
# 796th element
#   Sign of g changed.
# 797th element
#   Sign of g changed.
# 798th element
#   Sign of g changed.
# 799th element
#   Sign of g changed.
# 800th element
#   Sign of g changed.
# 801th element
#   Sign of g changed.
# 802th element
#   Sign of g changed.
# 803th element
#   Sign of g changed.
# 804th element
#   Sign of g changed.
# 805th element
#   Sign of g changed.
# 806th element
#   Sign of g changed.
# 807th element
#   Sign of g changed.
# 808th element
#   Sign of g changed.
# 809th element
#   Sign of g changed.
# 810th element
#   Sign of g changed.
# 811th element
#   Sign of g changed.
# 812th element
#   Sign of g changed.
# 813th element
#   Sign of g changed.
# 814th element
#   Sign of g changed.
# 815th element
#   Sign of g changed.
# 816th element
#   Sign of g changed.
# 817th element
#   Sign of g changed.
# 818th element
#   Sign of g changed.
# 819th element
#   Sign of g changed.
# 820th element
#   Sign of g changed.
# 821th element
#   Sign of g changed.
# 822th element
#   Sign of g changed.
# 823th element
#   Sign of g changed.
# 824th element
#   Sign of g changed.
# 825th element
#   Sign of g changed.
# 826th element
#   Sign of g changed.
# 827th element
#   Sign of g changed.
# 828th element
#   Sign of g changed.
# 829th element
#   Sign of g changed.
# 830th element
#   Sign of g changed.
# 831th element
#   Sign of g changed.
# 832th element
#   Sign of g changed.
# 833th element
#   Sign of g changed.
# 834th element
#   Sign of g changed.
# 835th element
#   Sign of g changed.
# 836th element
#   Sign of g changed.
# 837th element
#   Sign of g changed.
# 838th element
#   Sign of g changed.
# 839th element
#   Sign of g changed.
# 840th element
#   Sign of g changed.
# 841th element
#   Sign of g changed.
# 842th element
#   Sign of g changed.
# 843th element
#   Sign of g changed.
# 844th element
#   Sign of g changed.
# 845th element
#   Sign of g changed.
# 846th element
#   Sign of g changed.
# 847th element
#   Sign of g changed.
# 848th element
#   Sign of g changed.
# 849th element
#   Sign of g changed.
# 850th element
#   Sign of g changed.
# 851th element
#   Sign of g changed.
# 852th element
#   Sign of g changed.
# 853th element
#   Sign of g changed.
# 854th element
#   Sign of g changed.
# 855th element
#   Sign of g changed.
# 856th element
#   Sign of g changed.
# 857th element
#   Sign of g changed.
# 858th element
#   Sign of g changed.
# 859th element
#   Sign of g changed.
# 860th element
#   Sign of g changed.
# 861th element
#   Sign of g changed.
# 862th element
#   Sign of g changed.
# 863th element
#   Sign of g changed.
# 864th element
#   Sign of g changed.
# 865th element
#   Sign of g changed.
# 866th element
#   Sign of g changed.
# 867th element
#   Sign of g changed.
# 868th element
#   Sign of g changed.
# 869th element
#   Sign of g changed.
# 870th element
#   Sign of g changed.
# 871th element
#   Sign of g changed.
# 872th element
#   Sign of g changed.
# 873th element
#   Sign of g changed.
# 874th element
#   Sign of g changed.
# 875th element
#   Sign of g changed.
# 876th element
#   Sign of g changed.
# 877th element
#   Sign of g changed.
# 878th element
#   Sign of g changed.
# 879th element
#   Sign of g changed.
# 880th element
#   Sign of g changed.
# 881th element
#   Sign of g changed.
# 882th element
#   Sign of g changed.
# 883th element
#   Sign of g changed.
# 884th element
#   Sign of g changed.
# 885th element
#   Sign of g changed.
# 886th element
#   Sign of g changed.
# 887th element
#   Sign of g changed.
# 888th element
#   Sign of g changed.
# 889th element
#   Sign of g changed.
# 890th element
#   Sign of g changed.
# 891th element
#   Sign of g changed.
# 892th element
#   Sign of g changed.
# 893th element
#   Sign of g changed.
# 894th element
#   Sign of g changed.
# 895th element
#   Sign of g changed.
# 896th element
#   Sign of g changed.
# 897th element
#   Sign of g changed.
# 898th element
#   Sign of g changed.
# 899th element
#   Sign of g changed.
# 900th element
#   Sign of g changed.
# 901th element
#   Sign of g changed.
# 902th element
#   Sign of g changed.
# 903th element
#   Sign of g changed.
# 904th element
#   Sign of g changed.
# 905th element
#   Sign of g changed.
# 906th element
#   Sign of g changed.
# 907th element
#   Sign of g changed.
# 908th element
#   Sign of g changed.
# 909th element
#   Sign of g changed.
# 910th element
#   Sign of g changed.
# 911th element
#   Sign of g changed.
# 912th element
#   Sign of g changed.
# 913th element
#   Sign of g changed.
# 914th element
#   Sign of g changed.
# 915th element
#   Sign of g changed.
# 916th element
#   Sign of g changed.
# 917th element
#   Sign of g changed.
# 918th element
#   Sign of g changed.
# 919th element
#   Sign of g changed.
# 920th element
#   Sign of g changed.
# 921th element
#   Sign of g changed.
# 922th element
#   Sign of g changed.
# 923th element
#   Sign of g changed.
# 924th element
#   Sign of g changed.
# 925th element
#   Sign of g changed.
# 926th element
#   Sign of g changed.
# 927th element
#   Sign of g changed.
# 928th element
#   Sign of g changed.
# 929th element
#   Sign of g changed.
# 930th element
#   Sign of g changed.
# 931th element
#   Sign of g changed.
# 932th element
#   Sign of g changed.
# 933th element
#   Sign of g changed.
# 934th element
#   Sign of g changed.
# 935th element
#   Sign of g changed.
# 936th element
#   Sign of g changed.
# 937th element
#   Sign of g changed.
# 938th element
#   Sign of g changed.
# 939th element
#   Sign of g changed.
# 940th element
#   Sign of g changed.
# 941th element
#   Sign of g changed.
# 942th element
#   Sign of g changed.
# 943th element
#   Sign of g changed.
# 944th element
#   Sign of g changed.
# 945th element
#   Sign of g changed.
# 946th element
#   Sign of g changed.
# 947th element
#   Sign of g changed.
# 948th element
#   Sign of g changed.
# 949th element
#   Sign of g changed.
# 950th element
#   Sign of g changed.
# 951th element
#   Sign of g changed.
# 952th element
#   Sign of g changed.
# 953th element
#   Sign of g changed.
# 954th element
#   Sign of g changed.
# 955th element
#   Sign of g changed.
# 956th element
#   Sign of g changed.
# 957th element
#   Sign of g changed.
# 958th element
#   Sign of g changed.
# 959th element
#   Sign of g changed.
# 960th element
#   Sign of g changed.
# 961th element
#   Sign of g changed.
# 962th element
#   Sign of g changed.
# 963th element
#   Sign of g changed.
# 964th element
#   Sign of g changed.
# 965th element
#   Sign of g changed.
# 966th element
#   Sign of g changed.
# 967th element
#   Sign of g changed.
# 968th element
#   Sign of g changed.
# 969th element
#   Sign of g changed.
# 970th element
#   Sign of g changed.
# 971th element
#   Sign of g changed.
# 972th element
#   Sign of g changed.
# 973th element
#   Sign of g changed.
# 974th element
#   Sign of g changed.
# 975th element
#   Sign of g changed.
# 976th element
#   Sign of g changed.
# 977th element
#   Sign of g changed.
# 978th element
#   Sign of g changed.
# 979th element
#   Sign of g changed.
# 980th element
#   Sign of g changed.
# 981th element
#   Sign of g changed.
# 982th element
#   Sign of g changed.
# 983th element
#   Sign of g changed.
# 984th element
#   Sign of g changed.
# 985th element
#   Sign of g changed.
# 986th element
#   Sign of g changed.
# 987th element
#   Sign of g changed.
# 988th element
#   Sign of g changed.
# 989th element
#   Sign of g changed.
# 990th element
#   Sign of g changed.
# 991th element
#   Sign of g changed.
# 992th element
#   Sign of g changed.
# 993th element
#   Sign of g changed.
# 994th element
#   Sign of g changed.
# 995th element
#   Sign of g changed.
# 996th element
#   Sign of g changed.
# 997th element
#   Sign of g changed.
# 998th element
#   Sign of g changed.
# 999th element
#   Sign of g changed.
# 1000th element
#   Sign of g changed.
# 1001th element
#   Sign of g changed.
# 1002th element
#   Sign of g changed.
# 1003th element
#   Sign of g changed.
# 1004th element
#   Sign of g changed.
# 1005th element
#   Sign of g changed.
# 1006th element
#   Sign of g changed.
# 1007th element
#   Sign of g changed.
# 1008th element
#   Sign of g changed.
# 1009th element
#   Sign of g changed.
# 1010th element
#   Sign of g changed.
# 1011th element
#   Sign of g changed.
# 1012th element
#   Sign of g changed.
# 1013th element
#   Sign of g changed.
# 1014th element
#   Sign of g changed.
# 1015th element
#   Sign of g changed.
# 1016th element
#   Sign of g changed.
# 1017th element
#   Sign of g changed.
# 1018th element
#   Sign of g changed.
# 1019th element
#   Sign of g changed.
# 1020th element
#   Sign of g changed.
# 1021th element
#   Sign of g changed.
# 1022th element
#   Sign of g changed.
# 1023th element
#   Sign of g changed.
# 1024th element
#   Sign of g changed.
# 1025th element
#   Sign of g changed.
# 1026th element
#   Sign of g changed.
# 1027th element
#   Sign of g changed.
# 1028th element
#   Sign of g changed.
# 1029th element
#   Sign of g changed.
# 1030th element
#   Sign of g changed.
# 1031th element
#   Sign of g changed.
# 1032th element
#   Sign of g changed.
# 1033th element
#   Sign of g changed.
# 1034th element
#   Sign of g changed.
# 1035th element
#   Sign of g changed.
# 1036th element
#   Sign of g changed.
# 1037th element
#   Sign of g changed.
# 1038th element
#   Sign of g changed.
# 1039th element
#   Sign of g changed.
# 1040th element
#   Sign of g changed.
# 1041th element
#   Sign of g changed.
# 1042th element
#   Sign of g changed.
# 1043th element
#   Sign of g changed.
# 1044th element
#   Sign of g changed.
# 1045th element
#   Sign of g changed.
# 1046th element
#   Sign of g changed.
# 1047th element
#   Sign of g changed.
# 1048th element
#   Sign of g changed.
# 1049th element
#   Sign of g changed.
# 1050th element
#   Sign of g changed.
# 1051th element
#   Sign of g changed.
# 1052th element
#   Sign of g changed.
# 1053th element
#   Sign of g changed.
# 1054th element
#   Sign of g changed.
# 1055th element
#   Sign of g changed.
# 1056th element
#   Sign of g changed.
# 1057th element
#   Sign of g changed.
# 1058th element
#   Sign of g changed.
# 1059th element
#   Sign of g changed.
# 1060th element
#   Sign of g changed.
# 1061th element
#   Sign of g changed.
# 1062th element
#   Sign of g changed.
# 1063th element
#   Sign of g changed.
# 1064th element
#   Sign of g changed.
# 1065th element
#   Sign of g changed.
# 1066th element
#   Sign of g changed.
# 1067th element
#   Sign of g changed.
# 1068th element
#   Sign of g changed.
# 1069th element
#   Sign of g changed.
# 1070th element
#   Sign of g changed.
# 1071th element
#   Sign of g changed.
# 1072th element
#   Sign of g changed.
# 1073th element
#   Sign of g changed.
# 1074th element
#   Sign of g changed.
# 1075th element
#   Sign of g changed.
# 1076th element
#   Sign of g changed.
# 1077th element
#   Sign of g changed.
# 1078th element
#   Sign of g changed.
# 1079th element
#   Sign of g changed.
# 1080th element
#   Sign of g changed.
# 1081th element
#   Sign of g changed.
# 1082th element
#   Sign of g changed.
# 1083th element
#   Sign of g changed.
# 1084th element
#   Sign of g changed.
# 1085th element
#   Sign of g changed.
# 1086th element
#   Sign of g changed.
# 1087th element
#   Sign of g changed.
# 1088th element
#   Sign of g changed.
# 1089th element
#   Sign of g changed.
# 1090th element
#   Sign of g changed.
# 1091th element
#   Sign of g changed.
# 1092th element
#   Sign of g changed.
# 1093th element
#   Sign of g changed.
# 1094th element
#   Sign of g changed.
# 1095th element
#   Sign of g changed.
# 1096th element
#   Sign of g changed.
# 1097th element
#   Sign of g changed.
# 1098th element
#   Sign of g changed.
# 1099th element
#   Sign of g changed.
# 1100th element
#   Sign of g changed.
# 1101th element
#   Sign of g changed.
# 1102th element
#   Sign of g changed.
# 1103th element
#   Sign of g changed.
# 1104th element
#   Sign of g changed.
# 1105th element
#   Sign of g changed.
# 1106th element
#   Sign of g changed.
# 1107th element
#   Sign of g changed.
# 1108th element
#   Sign of g changed.
# 1109th element
#   Sign of g changed.
# 1110th element
#   Sign of g changed.
# 1111th element
#   Sign of g changed.
# 1112th element
#   Sign of g changed.
# 1113th element
#   Sign of g changed.
# 1114th element
#   Sign of g changed.
# 1115th element
#   Sign of g changed.
# 1116th element
#   Sign of g changed.
# 1117th element
#   Sign of g changed.
# 1118th element
#   Sign of g changed.
# 1119th element
#   Sign of g changed.
# 1120th element
#   Sign of g changed.
# 1121th element
#   Sign of g changed.
# 1122th element
#   Sign of g changed.
# 1123th element
#   Sign of g changed.
# 1124th element
#   Sign of g changed.
# 1125th element
#   Sign of g changed.
# 1126th element
#   Sign of g changed.
# 1127th element
#   Sign of g changed.
# 1128th element
#   Sign of g changed.
# 1129th element
#   Sign of g changed.
# 1130th element
#   Sign of g changed.
# 1131th element
#   Sign of g changed.
# 1132th element
#   Sign of g changed.
# 1133th element
#   Sign of g changed.
# 1134th element
#   Sign of g changed.
# 1135th element
#   Sign of g changed.
# 1136th element
#   Sign of g changed.
# 1137th element
#   Sign of g changed.
# 1138th element
#   Sign of g changed.
# 1139th element
#   Sign of g changed.
# 1140th element
#   Sign of g changed.
# 1141th element
#   Sign of g changed.
# 1142th element
#   Sign of g changed.
# 1143th element
#   Sign of g changed.
# 1144th element
#   Sign of g changed.
# 1145th element
#   Sign of g changed.
# 1146th element
#   Sign of g changed.
# 1147th element
#   Sign of g changed.
# 1148th element
#   Sign of g changed.
# 1149th element
#   Sign of g changed.
# 1150th element
#   Sign of g changed.
# 1151th element
#   Sign of g changed.
# 1152th element
#   Sign of g changed.
# 1153th element
#   Sign of g changed.
# 1154th element
#   Sign of g changed.
# 1155th element
#   Sign of g changed.
# 1156th element
#   Sign of g changed.
# 1157th element
#   Sign of g changed.
# 1158th element
#   Sign of g changed.
# 1159th element
#   Sign of g changed.
# 1160th element
#   Sign of g changed.
# 1161th element
#   Sign of g changed.
# 1162th element
#   Sign of g changed.
# 1163th element
#   Sign of g changed.
# 1164th element
#   Sign of g changed.
# 1165th element
#   Sign of g changed.
# 1166th element
#   Sign of g changed.
# 1167th element
#   Sign of g changed.
# 1168th element
#   Sign of g changed.
# 1169th element
#   Sign of g changed.
# 1170th element
#   Sign of g changed.
# 1171th element
#   Sign of g changed.
# 1172th element
#   Sign of g changed.
# 1173th element
#   Sign of g changed.
# 1174th element
#   Sign of g changed.
# 1175th element
#   Sign of g changed.
# 1176th element
#   Sign of g changed.
# 1177th element
#   Sign of g changed.
# 1178th element
#   Sign of g changed.
# 1179th element
#   Sign of g changed.
# 1180th element
#   Sign of g changed.
# 1181th element
#   Sign of g changed.
# 1182th element
#   Sign of g changed.
# 1183th element
#   Sign of g changed.
# 1184th element
#   Sign of g changed.
# 1185th element
#   Sign of g changed.
# 1186th element
#   Sign of g changed.
# 1187th element
#   Sign of g changed.
# 1188th element
#   Sign of g changed.
# 1189th element
#   Sign of g changed.
# 1190th element
#   Sign of g changed.
# 1191th element
#   Sign of g changed.
# 1192th element
#   Sign of g changed.
# 1193th element
#   Sign of g changed.
# 1194th element
#   Sign of g changed.
# 1195th element
#   Sign of g changed.
# Text(0, 0.5, 'lambda')

# %%
Ei = (rhos**n) * E0
[X,Y] = np.meshgrid(np.linspace(min(cxs),max(cxs),100),np.linspace(min(cys),max(cys),100))
points = np.concatenate((cxs[:, np.newaxis] , cys[:, np.newaxis]), axis=1)
Z = griddata(points,Ei,(X,Y))
plt.rcParams['figure.figsize'] = [5, 5]
fig, ax = plt.subplots() 
plt.axis('off')
img = ax.imshow(Z, extent=[min(cxs), max(cxs), min(cys), max(cys)])
img.set_cmap('gray')

# %%
# マテリアルの情報を更新する
mat_base = my_dict['liml8']['mat'].copy()
if type(mat_base)==list:
    mat_base = mat_base[0]
id_base = mat_base['@mid']
name_base = mat_base['@name']
geo_base = mat_base['geometric']
mech_base = mat_base['mechanical'] 
mat_new = [mat_base.copy()]
for i in range(ne):
    mat_dict = {}
    mat_dict['@mid'] = str(int(id_base) + i + 1)
    mat_dict['@name'] = name_base + str(int(id_base) + i)
    mat_dict['geometric'] = geo_base.copy()
    mat_dict['mechanical'] = mech_base.copy()
    # Update Young's modulus
    mat_dict['mechanical']['@youngsmodulus'] = "{:.0f}".format(Ei[i])
    mat_new.append(mat_dict)

# %%
# 要素のマテリアル情報を更新する
elem_base = my_dict['liml8']['elset'].copy()
if type(elem_base)==list:
    elem_base = elem_base[0]
elem_base.pop('elem', None) # Remove "elem" key
elset_new = [elem_base]
for i in range(ne):
    elem = elem_list[i]
    elem_dict = elem_base.copy() 
    elem_dict['elem'] = elem
    elem_dict['@name'] = 'Component'  + str (i + 1)
    elem_dict['@material'] = elem_base['@material'] + str(i + 1)
    elset_new.append(elem_dict)

# %%
#結果の更新
my_dict_new = my_dict.copy()
my_dict_new['liml8']['elset'] = elset_new
my_dict_new['liml8']['mat'] = mat_new

liml = xmltodict.unparse(my_dict_new, pretty=True, full_document=False)
output_filename = 'output/'+BASE_FILENAME+'_out.liml'
fout = open(output_filename, 'w')
fout.write(liml)
fout.close()

# %%
# 第２世代のサンプル確認用
# data2 = 'liml/beam1_opti_2.liml'
# with open(data2,  'r', encoding='utf-8') as file:
#     my_xml2 = file.read()
# my_dict2 = xmltodict.parse(my_xml2)
# len(my_dict2['liml8']['mat'])
