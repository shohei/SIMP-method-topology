# %%
import xmltodict, json
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.interpolate import griddata

# %%
# 与えられたnode idから対応するX,Yの点を返す関数
def findXY(node_id):
    for node in nodes:
        if node['@nid'] == str(node_id):
            return (node['@x'], node['@y'])
            
# 4点から面積を計算する方法（靴紐の公式））
def shoelace_area(points):
    """
    計算順に並んだ4点の(x, y)座標リスト [(x1, y1), (x2, y2), (x3, y3), (x4, y4)] から面積を求める
    """
    n = len(points)
    area = 0
    for i in range(n):
        j = (i + 1) % n  # 次の点（最後の点は最初の点につなげる）
        area += points[i][0] * points[j][1] - points[i][1] * points[j][0]
    return abs(area) / 2

# ✅ 例: 4点を指定して計算
points = [(1, 1), (4, 1), (4, 5), (1, 5)]  # 長方形
# print(shoelace_area(points))  # 出力: 12.0

# %%
data = 'input/gen2.liml'

# %%
import xmltodict
import pprint

# Open the file and read the contents
with open(data,  'r', encoding='utf-8') as file:
    my_xml = file.read()

# Use xmltodict to parse and convert 
# the XML document
my_dict = xmltodict.parse(my_xml).copy()

# Print the dictionary
pprint.pprint(my_dict, indent=2)
# Out:
# { 'liml8': { 'analysis': {'@type': 'S20'},
#              'displacement': [ { '@axis': '1',
#                                  '@selection': 'Unnamed',
#                                  'value': '0'},
#                                { '@axis': '2',
#                                  '@selection': 'Unnamed(2)',
#                                  'value': '0'}],
#              'elset': [ { '@color': '-6710887',
#                           '@material': 'Material',
#                           '@name': 'Default'},
#                         { '@color': '-6710887',
#                           '@material': 'Material1',
#                           '@name': 'Component1',
#                           'elem': { '@eid': '1',
#                                     '@nodes': '1243 1269 3 1244',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material2',
#                           '@name': 'Component2',
#                           'elem': { '@eid': '2',
#                                     '@nodes': '1 30 31 5',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material3',
#                           '@name': 'Component3',
#                           'elem': { '@eid': '3',
#                                     '@nodes': '5 31 32 6',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material4',
#                           '@name': 'Component4',
#                           'elem': { '@eid': '4',
#                                     '@nodes': '6 32 33 7',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material5',
#                           '@name': 'Component5',
#                           'elem': { '@eid': '5',
#                                     '@nodes': '7 33 34 8',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material6',
#                           '@name': 'Component6',
#                           'elem': { '@eid': '6',
#                                     '@nodes': '8 34 35 9',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material7',
#                           '@name': 'Component7',
#                           'elem': { '@eid': '7',
#                                     '@nodes': '9 35 36 10',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material8',
#                           '@name': 'Component8',
#                           'elem': { '@eid': '8',
#                                     '@nodes': '10 36 37 11',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material9',
#                           '@name': 'Component9',
#                           'elem': { '@eid': '9',
#                                     '@nodes': '11 37 38 12',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material10',
#                           '@name': 'Component10',
#                           'elem': { '@eid': '10',
#                                     '@nodes': '12 38 39 13',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material11',
#                           '@name': 'Component11',
#                           'elem': { '@eid': '11',
#                                     '@nodes': '13 39 40 14',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material12',
#                           '@name': 'Component12',
#                           'elem': { '@eid': '12',
#                                     '@nodes': '14 40 41 15',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material13',
#                           '@name': 'Component13',
#                           'elem': { '@eid': '13',
#                                     '@nodes': '15 41 42 16',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material14',
#                           '@name': 'Component14',
#                           'elem': { '@eid': '14',
#                                     '@nodes': '16 42 43 17',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material15',
#                           '@name': 'Component15',
#                           'elem': { '@eid': '15',
#                                     '@nodes': '17 43 44 18',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material16',
#                           '@name': 'Component16',
#                           'elem': { '@eid': '16',
#                                     '@nodes': '18 44 45 19',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material17',
#                           '@name': 'Component17',
#                           'elem': { '@eid': '17',
#                                     '@nodes': '19 45 46 20',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material18',
#                           '@name': 'Component18',
#                           'elem': { '@eid': '18',
#                                     '@nodes': '20 46 47 21',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material19',
#                           '@name': 'Component19',
#                           'elem': { '@eid': '19',
#                                     '@nodes': '21 47 48 22',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material20',
#                           '@name': 'Component20',
#                           'elem': { '@eid': '20',
#                                     '@nodes': '22 48 49 23',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material21',
#                           '@name': 'Component21',
#                           'elem': { '@eid': '21',
#                                     '@nodes': '23 49 50 24',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material22',
#                           '@name': 'Component22',
#                           'elem': { '@eid': '22',
#                                     '@nodes': '24 50 51 25',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material23',
#                           '@name': 'Component23',
#                           'elem': { '@eid': '23',
#                                     '@nodes': '25 51 52 26',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material24',
#                           '@name': 'Component24',
#                           'elem': { '@eid': '24',
#                                     '@nodes': '26 52 53 27',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material25',
#                           '@name': 'Component25',
#                           'elem': { '@eid': '25',
#                                     '@nodes': '27 53 54 28',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material26',
#                           '@name': 'Component26',
#                           'elem': { '@eid': '26',
#                                     '@nodes': '28 54 55 29',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material27',
#                           '@name': 'Component27',
#                           'elem': { '@eid': '27',
#                                     '@nodes': '29 55 56 4',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material28',
#                           '@name': 'Component28',
#                           'elem': { '@eid': '28',
#                                     '@nodes': '30 57 58 31',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material29',
#                           '@name': 'Component29',
#                           'elem': { '@eid': '29',
#                                     '@nodes': '31 58 59 32',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material30',
#                           '@name': 'Component30',
#                           'elem': { '@eid': '30',
#                                     '@nodes': '32 59 60 33',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material31',
#                           '@name': 'Component31',
#                           'elem': { '@eid': '31',
#                                     '@nodes': '33 60 61 34',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material32',
#                           '@name': 'Component32',
#                           'elem': { '@eid': '32',
#                                     '@nodes': '34 61 62 35',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material33',
#                           '@name': 'Component33',
#                           'elem': { '@eid': '33',
#                                     '@nodes': '35 62 63 36',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material34',
#                           '@name': 'Component34',
#                           'elem': { '@eid': '34',
#                                     '@nodes': '36 63 64 37',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material35',
#                           '@name': 'Component35',
#                           'elem': { '@eid': '35',
#                                     '@nodes': '37 64 65 38',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material36',
#                           '@name': 'Component36',
#                           'elem': { '@eid': '36',
#                                     '@nodes': '38 65 66 39',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material37',
#                           '@name': 'Component37',
#                           'elem': { '@eid': '37',
#                                     '@nodes': '39 66 67 40',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material38',
#                           '@name': 'Component38',
#                           'elem': { '@eid': '38',
#                                     '@nodes': '40 67 68 41',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material39',
#                           '@name': 'Component39',
#                           'elem': { '@eid': '39',
#                                     '@nodes': '41 68 69 42',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material40',
#                           '@name': 'Component40',
#                           'elem': { '@eid': '40',
#                                     '@nodes': '42 69 70 43',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material41',
#                           '@name': 'Component41',
#                           'elem': { '@eid': '41',
#                                     '@nodes': '43 70 71 44',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material42',
#                           '@name': 'Component42',
#                           'elem': { '@eid': '42',
#                                     '@nodes': '44 71 72 45',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material43',
#                           '@name': 'Component43',
#                           'elem': { '@eid': '43',
#                                     '@nodes': '45 72 73 46',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material44',
#                           '@name': 'Component44',
#                           'elem': { '@eid': '44',
#                                     '@nodes': '46 73 74 47',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material45',
#                           '@name': 'Component45',
#                           'elem': { '@eid': '45',
#                                     '@nodes': '47 74 75 48',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material46',
#                           '@name': 'Component46',
#                           'elem': { '@eid': '46',
#                                     '@nodes': '48 75 76 49',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material47',
#                           '@name': 'Component47',
#                           'elem': { '@eid': '47',
#                                     '@nodes': '49 76 77 50',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material48',
#                           '@name': 'Component48',
#                           'elem': { '@eid': '48',
#                                     '@nodes': '50 77 78 51',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material49',
#                           '@name': 'Component49',
#                           'elem': { '@eid': '49',
#                                     '@nodes': '51 78 79 52',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material50',
#                           '@name': 'Component50',
#                           'elem': { '@eid': '50',
#                                     '@nodes': '52 79 80 53',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material51',
#                           '@name': 'Component51',
#                           'elem': { '@eid': '51',
#                                     '@nodes': '53 80 81 54',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material52',
#                           '@name': 'Component52',
#                           'elem': { '@eid': '52',
#                                     '@nodes': '54 81 82 55',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material53',
#                           '@name': 'Component53',
#                           'elem': { '@eid': '53',
#                                     '@nodes': '55 82 83 56',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material54',
#                           '@name': 'Component54',
#                           'elem': { '@eid': '54',
#                                     '@nodes': '57 84 85 58',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material55',
#                           '@name': 'Component55',
#                           'elem': { '@eid': '55',
#                                     '@nodes': '58 85 86 59',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material56',
#                           '@name': 'Component56',
#                           'elem': { '@eid': '56',
#                                     '@nodes': '59 86 87 60',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material57',
#                           '@name': 'Component57',
#                           'elem': { '@eid': '57',
#                                     '@nodes': '60 87 88 61',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material58',
#                           '@name': 'Component58',
#                           'elem': { '@eid': '58',
#                                     '@nodes': '61 88 89 62',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material59',
#                           '@name': 'Component59',
#                           'elem': { '@eid': '59',
#                                     '@nodes': '62 89 90 63',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material60',
#                           '@name': 'Component60',
#                           'elem': { '@eid': '60',
#                                     '@nodes': '63 90 91 64',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material61',
#                           '@name': 'Component61',
#                           'elem': { '@eid': '61',
#                                     '@nodes': '64 91 92 65',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material62',
#                           '@name': 'Component62',
#                           'elem': { '@eid': '62',
#                                     '@nodes': '65 92 93 66',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material63',
#                           '@name': 'Component63',
#                           'elem': { '@eid': '63',
#                                     '@nodes': '66 93 94 67',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material64',
#                           '@name': 'Component64',
#                           'elem': { '@eid': '64',
#                                     '@nodes': '67 94 95 68',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material65',
#                           '@name': 'Component65',
#                           'elem': { '@eid': '65',
#                                     '@nodes': '68 95 96 69',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material66',
#                           '@name': 'Component66',
#                           'elem': { '@eid': '66',
#                                     '@nodes': '69 96 97 70',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material67',
#                           '@name': 'Component67',
#                           'elem': { '@eid': '67',
#                                     '@nodes': '70 97 98 71',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material68',
#                           '@name': 'Component68',
#                           'elem': { '@eid': '68',
#                                     '@nodes': '71 98 99 72',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material69',
#                           '@name': 'Component69',
#                           'elem': { '@eid': '69',
#                                     '@nodes': '72 99 100 73',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material70',
#                           '@name': 'Component70',
#                           'elem': { '@eid': '70',
#                                     '@nodes': '73 100 101 74',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material71',
#                           '@name': 'Component71',
#                           'elem': { '@eid': '71',
#                                     '@nodes': '74 101 102 75',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material72',
#                           '@name': 'Component72',
#                           'elem': { '@eid': '72',
#                                     '@nodes': '75 102 103 76',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material73',
#                           '@name': 'Component73',
#                           'elem': { '@eid': '73',
#                                     '@nodes': '76 103 104 77',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material74',
#                           '@name': 'Component74',
#                           'elem': { '@eid': '74',
#                                     '@nodes': '77 104 105 78',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material75',
#                           '@name': 'Component75',
#                           'elem': { '@eid': '75',
#                                     '@nodes': '78 105 106 79',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material76',
#                           '@name': 'Component76',
#                           'elem': { '@eid': '76',
#                                     '@nodes': '79 106 107 80',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material77',
#                           '@name': 'Component77',
#                           'elem': { '@eid': '77',
#                                     '@nodes': '80 107 108 81',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material78',
#                           '@name': 'Component78',
#                           'elem': { '@eid': '78',
#                                     '@nodes': '81 108 109 82',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material79',
#                           '@name': 'Component79',
#                           'elem': { '@eid': '79',
#                                     '@nodes': '82 109 110 83',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material80',
#                           '@name': 'Component80',
#                           'elem': { '@eid': '80',
#                                     '@nodes': '84 111 112 85',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material81',
#                           '@name': 'Component81',
#                           'elem': { '@eid': '81',
#                                     '@nodes': '85 112 113 86',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material82',
#                           '@name': 'Component82',
#                           'elem': { '@eid': '82',
#                                     '@nodes': '86 113 114 87',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material83',
#                           '@name': 'Component83',
#                           'elem': { '@eid': '83',
#                                     '@nodes': '87 114 115 88',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material84',
#                           '@name': 'Component84',
#                           'elem': { '@eid': '84',
#                                     '@nodes': '88 115 116 89',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material85',
#                           '@name': 'Component85',
#                           'elem': { '@eid': '85',
#                                     '@nodes': '89 116 117 90',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material86',
#                           '@name': 'Component86',
#                           'elem': { '@eid': '86',
#                                     '@nodes': '90 117 118 91',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material87',
#                           '@name': 'Component87',
#                           'elem': { '@eid': '87',
#                                     '@nodes': '91 118 119 92',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material88',
#                           '@name': 'Component88',
#                           'elem': { '@eid': '88',
#                                     '@nodes': '92 119 120 93',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material89',
#                           '@name': 'Component89',
#                           'elem': { '@eid': '89',
#                                     '@nodes': '93 120 121 94',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material90',
#                           '@name': 'Component90',
#                           'elem': { '@eid': '90',
#                                     '@nodes': '94 121 122 95',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material91',
#                           '@name': 'Component91',
#                           'elem': { '@eid': '91',
#                                     '@nodes': '95 122 123 96',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material92',
#                           '@name': 'Component92',
#                           'elem': { '@eid': '92',
#                                     '@nodes': '96 123 124 97',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material93',
#                           '@name': 'Component93',
#                           'elem': { '@eid': '93',
#                                     '@nodes': '97 124 125 98',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material94',
#                           '@name': 'Component94',
#                           'elem': { '@eid': '94',
#                                     '@nodes': '98 125 126 99',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material95',
#                           '@name': 'Component95',
#                           'elem': { '@eid': '95',
#                                     '@nodes': '99 126 127 100',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material96',
#                           '@name': 'Component96',
#                           'elem': { '@eid': '96',
#                                     '@nodes': '100 127 128 101',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material97',
#                           '@name': 'Component97',
#                           'elem': { '@eid': '97',
#                                     '@nodes': '101 128 129 102',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material98',
#                           '@name': 'Component98',
#                           'elem': { '@eid': '98',
#                                     '@nodes': '102 129 130 103',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material99',
#                           '@name': 'Component99',
#                           'elem': { '@eid': '99',
#                                     '@nodes': '103 130 131 104',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material100',
#                           '@name': 'Component100',
#                           'elem': { '@eid': '100',
#                                     '@nodes': '104 131 132 105',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material101',
#                           '@name': 'Component101',
#                           'elem': { '@eid': '101',
#                                     '@nodes': '105 132 133 106',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material102',
#                           '@name': 'Component102',
#                           'elem': { '@eid': '102',
#                                     '@nodes': '106 133 134 107',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material103',
#                           '@name': 'Component103',
#                           'elem': { '@eid': '103',
#                                     '@nodes': '107 134 135 108',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material104',
#                           '@name': 'Component104',
#                           'elem': { '@eid': '104',
#                                     '@nodes': '108 135 136 109',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material105',
#                           '@name': 'Component105',
#                           'elem': { '@eid': '105',
#                                     '@nodes': '109 136 137 110',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material106',
#                           '@name': 'Component106',
#                           'elem': { '@eid': '106',
#                                     '@nodes': '111 138 139 112',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material107',
#                           '@name': 'Component107',
#                           'elem': { '@eid': '107',
#                                     '@nodes': '112 139 140 113',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material108',
#                           '@name': 'Component108',
#                           'elem': { '@eid': '108',
#                                     '@nodes': '113 140 141 114',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material109',
#                           '@name': 'Component109',
#                           'elem': { '@eid': '109',
#                                     '@nodes': '114 141 142 115',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material110',
#                           '@name': 'Component110',
#                           'elem': { '@eid': '110',
#                                     '@nodes': '115 142 143 116',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material111',
#                           '@name': 'Component111',
#                           'elem': { '@eid': '111',
#                                     '@nodes': '116 143 144 117',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material112',
#                           '@name': 'Component112',
#                           'elem': { '@eid': '112',
#                                     '@nodes': '117 144 145 118',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material113',
#                           '@name': 'Component113',
#                           'elem': { '@eid': '113',
#                                     '@nodes': '118 145 146 119',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material114',
#                           '@name': 'Component114',
#                           'elem': { '@eid': '114',
#                                     '@nodes': '119 146 147 120',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material115',
#                           '@name': 'Component115',
#                           'elem': { '@eid': '115',
#                                     '@nodes': '120 147 148 121',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material116',
#                           '@name': 'Component116',
#                           'elem': { '@eid': '116',
#                                     '@nodes': '121 148 149 122',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material117',
#                           '@name': 'Component117',
#                           'elem': { '@eid': '117',
#                                     '@nodes': '122 149 150 123',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material118',
#                           '@name': 'Component118',
#                           'elem': { '@eid': '118',
#                                     '@nodes': '123 150 151 124',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material119',
#                           '@name': 'Component119',
#                           'elem': { '@eid': '119',
#                                     '@nodes': '124 151 152 125',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material120',
#                           '@name': 'Component120',
#                           'elem': { '@eid': '120',
#                                     '@nodes': '125 152 153 126',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material121',
#                           '@name': 'Component121',
#                           'elem': { '@eid': '121',
#                                     '@nodes': '126 153 154 127',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material122',
#                           '@name': 'Component122',
#                           'elem': { '@eid': '122',
#                                     '@nodes': '127 154 155 128',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material123',
#                           '@name': 'Component123',
#                           'elem': { '@eid': '123',
#                                     '@nodes': '128 155 156 129',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material124',
#                           '@name': 'Component124',
#                           'elem': { '@eid': '124',
#                                     '@nodes': '129 156 157 130',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material125',
#                           '@name': 'Component125',
#                           'elem': { '@eid': '125',
#                                     '@nodes': '130 157 158 131',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material126',
#                           '@name': 'Component126',
#                           'elem': { '@eid': '126',
#                                     '@nodes': '131 158 159 132',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material127',
#                           '@name': 'Component127',
#                           'elem': { '@eid': '127',
#                                     '@nodes': '132 159 160 133',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material128',
#                           '@name': 'Component128',
#                           'elem': { '@eid': '128',
#                                     '@nodes': '133 160 161 134',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material129',
#                           '@name': 'Component129',
#                           'elem': { '@eid': '129',
#                                     '@nodes': '134 161 162 135',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material130',
#                           '@name': 'Component130',
#                           'elem': { '@eid': '130',
#                                     '@nodes': '135 162 163 136',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material131',
#                           '@name': 'Component131',
#                           'elem': { '@eid': '131',
#                                     '@nodes': '136 163 164 137',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material132',
#                           '@name': 'Component132',
#                           'elem': { '@eid': '132',
#                                     '@nodes': '138 165 166 139',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material133',
#                           '@name': 'Component133',
#                           'elem': { '@eid': '133',
#                                     '@nodes': '139 166 167 140',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material134',
#                           '@name': 'Component134',
#                           'elem': { '@eid': '134',
#                                     '@nodes': '140 167 168 141',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material135',
#                           '@name': 'Component135',
#                           'elem': { '@eid': '135',
#                                     '@nodes': '141 168 169 142',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material136',
#                           '@name': 'Component136',
#                           'elem': { '@eid': '136',
#                                     '@nodes': '142 169 170 143',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material137',
#                           '@name': 'Component137',
#                           'elem': { '@eid': '137',
#                                     '@nodes': '143 170 171 144',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material138',
#                           '@name': 'Component138',
#                           'elem': { '@eid': '138',
#                                     '@nodes': '144 171 172 145',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material139',
#                           '@name': 'Component139',
#                           'elem': { '@eid': '139',
#                                     '@nodes': '145 172 173 146',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material140',
#                           '@name': 'Component140',
#                           'elem': { '@eid': '140',
#                                     '@nodes': '146 173 174 147',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material141',
#                           '@name': 'Component141',
#                           'elem': { '@eid': '141',
#                                     '@nodes': '147 174 175 148',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material142',
#                           '@name': 'Component142',
#                           'elem': { '@eid': '142',
#                                     '@nodes': '148 175 176 149',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material143',
#                           '@name': 'Component143',
#                           'elem': { '@eid': '143',
#                                     '@nodes': '149 176 177 150',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material144',
#                           '@name': 'Component144',
#                           'elem': { '@eid': '144',
#                                     '@nodes': '150 177 178 151',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material145',
#                           '@name': 'Component145',
#                           'elem': { '@eid': '145',
#                                     '@nodes': '151 178 179 152',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material146',
#                           '@name': 'Component146',
#                           'elem': { '@eid': '146',
#                                     '@nodes': '152 179 180 153',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material147',
#                           '@name': 'Component147',
#                           'elem': { '@eid': '147',
#                                     '@nodes': '153 180 181 154',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material148',
#                           '@name': 'Component148',
#                           'elem': { '@eid': '148',
# ...
#                                        '@x': '68.4782608695652',
#                                        '@y': '3.07692307692308',
#                                        '@z': '0'},
#                                      { '@nid': '1221',
#                                        '@x': '68.4782608695652',
#                                        '@y': '4.61538461538462',
#                                        '@z': '0'},
#                                      { '@nid': '1222',
#                                        '@x': '68.4782608695652',
#                                        '@y': '6.15384615384615',
#                                        '@z': '0'},
#                                      { '@nid': '1223',
#                                        '@x': '68.4782608695652',
#                                        '@y': '7.69230769230769',
#                                        '@z': '0'},
#                                      { '@nid': '1224',
#                                        '@x': '68.4782608695652',
#                                        '@y': '9.23076923076923',
#                                        '@z': '0'},
#                                      { '@nid': '1225',
#                                        '@x': '68.4782608695652',
#                                        '@y': '10.7692307692308',
#                                        '@z': '0'},
#                                      { '@nid': '1226',
#                                        '@x': '68.4782608695652',
#                                        '@y': '12.3076923076923',
#                                        '@z': '0'},
#                                      { '@nid': '1227',
#                                        '@x': '68.4782608695652',
#                                        '@y': '13.8461538461538',
#                                        '@z': '0'},
#                                      { '@nid': '1228',
#                                        '@x': '68.4782608695652',
#                                        '@y': '15.3846153846154',
#                                        '@z': '0'},
#                                      { '@nid': '1229',
#                                        '@x': '68.4782608695652',
#                                        '@y': '16.9230769230769',
#                                        '@z': '0'},
#                                      { '@nid': '1230',
#                                        '@x': '68.4782608695652',
#                                        '@y': '18.4615384615385',
#                                        '@z': '0'},
#                                      { '@nid': '1231',
#                                        '@x': '68.4782608695652',
#                                        '@y': '20',
#                                        '@z': '0'},
#                                      { '@nid': '1232',
#                                        '@x': '68.4782608695652',
#                                        '@y': '21.5384615384615',
#                                        '@z': '0'},
#                                      { '@nid': '1233',
#                                        '@x': '68.4782608695652',
#                                        '@y': '23.0769230769231',
#                                        '@z': '0'},
#                                      { '@nid': '1234',
#                                        '@x': '68.4782608695652',
#                                        '@y': '24.6153846153846',
#                                        '@z': '0'},
#                                      { '@nid': '1235',
#                                        '@x': '68.4782608695652',
#                                        '@y': '26.1538461538461',
#                                        '@z': '0'},
#                                      { '@nid': '1236',
#                                        '@x': '68.4782608695652',
#                                        '@y': '27.6923076923077',
#                                        '@z': '0'},
#                                      { '@nid': '1237',
#                                        '@x': '68.4782608695652',
#                                        '@y': '29.2307692307692',
#                                        '@z': '0'},
#                                      { '@nid': '1238',
#                                        '@x': '68.4782608695652',
#                                        '@y': '30.7692307692308',
#                                        '@z': '0'},
#                                      { '@nid': '1239',
#                                        '@x': '68.4782608695652',
#                                        '@y': '32.3076923076923',
#                                        '@z': '0'},
#                                      { '@nid': '1240',
#                                        '@x': '68.4782608695652',
#                                        '@y': '33.8461538461538',
#                                        '@z': '0'},
#                                      { '@nid': '1241',
#                                        '@x': '68.4782608695652',
#                                        '@y': '35.3846153846154',
#                                        '@z': '0'},
#                                      { '@nid': '1242',
#                                        '@x': '68.4782608695652',
#                                        '@y': '36.9230769230769',
#                                        '@z': '0'},
#                                      { '@nid': '1243',
#                                        '@x': '68.4782608695652',
#                                        '@y': '38.4615384615385',
#                                        '@z': '0'},
#                                      { '@nid': '1244',
#                                        '@x': '68.4782608695652',
#                                        '@y': '40',
#                                        '@z': '0'},
#                                      { '@nid': '1245',
#                                        '@x': '70',
#                                        '@y': '1.53846153846154',
#                                        '@z': '0'},
#                                      { '@nid': '1246',
#                                        '@x': '70',
#                                        '@y': '3.07692307692308',
#                                        '@z': '0'},
#                                      { '@nid': '1247',
#                                        '@x': '70',
#                                        '@y': '4.61538461538462',
#                                        '@z': '0'},
#                                      { '@nid': '1248',
#                                        '@x': '70',
#                                        '@y': '6.15384615384615',
#                                        '@z': '0'},
#                                      { '@nid': '1249',
#                                        '@x': '70',
#                                        '@y': '7.69230769230769',
#                                        '@z': '0'},
#                                      { '@nid': '1250',
#                                        '@x': '70',
#                                        '@y': '9.23076923076923',
#                                        '@z': '0'},
#                                      { '@nid': '1251',
#                                        '@x': '70',
#                                        '@y': '10.7692307692308',
#                                        '@z': '0'},
#                                      { '@nid': '1252',
#                                        '@x': '70',
#                                        '@y': '12.3076923076923',
#                                        '@z': '0'},
#                                      { '@nid': '1253',
#                                        '@x': '70',
#                                        '@y': '13.8461538461538',
#                                        '@z': '0'},
#                                      { '@nid': '1254',
#                                        '@x': '70',
#                                        '@y': '15.3846153846154',
#                                        '@z': '0'},
#                                      { '@nid': '1255',
#                                        '@x': '70',
#                                        '@y': '16.9230769230769',
#                                        '@z': '0'},
#                                      { '@nid': '1256',
#                                        '@x': '70',
#                                        '@y': '18.4615384615385',
#                                        '@z': '0'},
#                                      { '@nid': '1257',
#                                        '@x': '70',
#                                        '@y': '20',
#                                        '@z': '0'},
#                                      { '@nid': '1258',
#                                        '@x': '70',
#                                        '@y': '21.5384615384615',
#                                        '@z': '0'},
#                                      { '@nid': '1259',
#                                        '@x': '70',
#                                        '@y': '23.0769230769231',
#                                        '@z': '0'},
#                                      { '@nid': '1260',
#                                        '@x': '70',
#                                        '@y': '24.6153846153846',
#                                        '@z': '0'},
#                                      { '@nid': '1261',
#                                        '@x': '70',
#                                        '@y': '26.1538461538462',
#                                        '@z': '0'},
#                                      { '@nid': '1262',
#                                        '@x': '70',
#                                        '@y': '27.6923076923077',
#                                        '@z': '0'},
#                                      { '@nid': '1263',
#                                        '@x': '70',
#                                        '@y': '29.2307692307692',
#                                        '@z': '0'},
#                                      { '@nid': '1264',
#                                        '@x': '70',
#                                        '@y': '30.7692307692308',
#                                        '@z': '0'},
#                                      { '@nid': '1265',
#                                        '@x': '70',
#                                        '@y': '32.3076923076923',
#                                        '@z': '0'},
#                                      { '@nid': '1266',
#                                        '@x': '70',
#                                        '@y': '33.8461538461538',
#                                        '@z': '0'},
#                                      { '@nid': '1267',
#                                        '@x': '70',
#                                        '@y': '35.3846153846154',
#                                        '@z': '0'},
#                                      { '@nid': '1268',
#                                        '@x': '70',
#                                        '@y': '36.9230769230769',
#                                        '@z': '0'},
#                                      { '@nid': '1269',
#                                        '@x': '70',
#                                        '@y': '38.4615384615385',
#                                        '@z': '0'}],
#                            'nodeselection': [ { '@name': 'Unnamed',
#                                                 'node': [ {'@nid': '1'},
#                                                           {'@nid': '4'},
#                                                           {'@nid': '5'},
#                                                           {'@nid': '6'},
#                                                           {'@nid': '7'},
#                                                           {'@nid': '8'},
#                                                           {'@nid': '9'},
#                                                           {'@nid': '10'},
#                                                           {'@nid': '11'},
#                                                           {'@nid': '12'},
#                                                           {'@nid': '13'},
#                                                           {'@nid': '14'},
#                                                           {'@nid': '15'},
#                                                           {'@nid': '16'},
#                                                           {'@nid': '17'},
#                                                           {'@nid': '18'},
#                                                           {'@nid': '19'},
#                                                           {'@nid': '20'},
#                                                           {'@nid': '21'},
#                                                           {'@nid': '22'},
#                                                           {'@nid': '23'},
#                                                           {'@nid': '24'},
#                                                           {'@nid': '25'},
#                                                           {'@nid': '26'},
#                                                           {'@nid': '27'},
#                                                           {'@nid': '28'},
#                                                           {'@nid': '29'}]},
#                                               { '@name': 'Unnamed(2)',
#                                                 'node': [ {'@nid': '1'},
#                                                           {'@nid': '4'},
#                                                           {'@nid': '5'},
#                                                           {'@nid': '6'},
#                                                           {'@nid': '7'},
#                                                           {'@nid': '8'},
#                                                           {'@nid': '9'},
#                                                           {'@nid': '10'},
#                                                           {'@nid': '11'},
#                                                           {'@nid': '12'},
#                                                           {'@nid': '13'},
#                                                           {'@nid': '14'},
#                                                           {'@nid': '15'},
#                                                           {'@nid': '16'},
#                                                           {'@nid': '17'},
#                                                           {'@nid': '18'},
#                                                           {'@nid': '19'},
#                                                           {'@nid': '20'},
#                                                           {'@nid': '21'},
#                                                           {'@nid': '22'},
#                                                           {'@nid': '23'},
#                                                           {'@nid': '24'},
#                                                           {'@nid': '25'},
#                                                           {'@nid': '26'},
#                                                           {'@nid': '27'},
#                                                           {'@nid': '28'},
#                                                           {'@nid': '29'}]},
#                                               { '@name': 'Unnamed(3)',
#                                                 'node': {'@nid': '1257'}}],
#                            'results': { 'elem':
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)

# %%
def calc_g(rhos):
    tmp_sum = 0
    for i in range(ne):
        tmp_sum += rhos[i] * vs[i]
    g = tmp_sum - a*V0
    return g

# %%
def calc_rho_i(lmbda, sigma_i):
    rho_i = (-(n-1)/E0 * np.dot(nu*sigma_i, sigma_i.transpose())  / lmbda ) ** (1/n)
    return rho_i

# %%
def calc_D(rho_i, lmbda, sigma_i):
    D = -lmbda * E0 * rho_i**n / ((n-1) * np.dot(nu*sigma_i, sigma_i.transpose()))
    return D

# %%
def update_D_and_rho_i(rho_i, lmbda, sigma_i):
    D = calc_D(rho_i, lmbda, sigma_i)
    while abs(D-1) > 1e-3:
        if D > 1:
            rho_i = rho_i - drho 
        else:
            rho_i = rho_i + drho
        if rho_i > 1:
            rho_i = 1 
            break 
        elif rho_i < 0.01:
            rho_i = 0.01
            break 
        D = calc_D(rho_i,lmbda, sigma_i)
    return (D, rho_i)

# %%
def update_lambda(g, lmbda):
    if g<0:
        lmbda = lmbda - dlambda #ラムダを右にシフト
        if lmbda > 0:
            lmbda = lmbda + dlambda #λは正にならないので、もし正になったら負に戻す
    else:
        lmbda = lmbda + dlambda #ラムダを左にシフト
    return lmbda

# %%
def check_if_all_rhos_are_settled(rhos):
    for i in range(ne):
        if (rhos[i] == 1) or (rhos[i] == 0.01):
            continue
        else:
            return False
    return True

# %%
# グローバルなパラメータ
a = 0.5
E0 = 200e9
n = 2 #3が適当??
nu = 0.3

# %%
# elems = my_dict['liml8']['elset']['elem']
my_dict['liml8']['elset']
# Out:
# [{'@name': 'Default', '@color': '-6710887', '@material': 'Material'},
#  {'@name': 'Component1',
#   '@color': '-6710887',
#   '@material': 'Material1',
#   'elem': {'@eid': '1', '@shape': 'quad4', '@nodes': '1243 1269 3 1244'}},
#  {'@name': 'Component2',
#   '@color': '-6710887',
#   '@material': 'Material2',
#   'elem': {'@eid': '2', '@shape': 'quad4', '@nodes': '1 30 31 5'}},
#  {'@name': 'Component3',
#   '@color': '-6710887',
#   '@material': 'Material3',
#   'elem': {'@eid': '3', '@shape': 'quad4', '@nodes': '5 31 32 6'}},
#  {'@name': 'Component4',
#   '@color': '-6710887',
#   '@material': 'Material4',
#   'elem': {'@eid': '4', '@shape': 'quad4', '@nodes': '6 32 33 7'}},
#  {'@name': 'Component5',
#   '@color': '-6710887',
#   '@material': 'Material5',
#   'elem': {'@eid': '5', '@shape': 'quad4', '@nodes': '7 33 34 8'}},
#  {'@name': 'Component6',
#   '@color': '-6710887',
#   '@material': 'Material6',
#   'elem': {'@eid': '6', '@shape': 'quad4', '@nodes': '8 34 35 9'}},
#  {'@name': 'Component7',
#   '@color': '-6710887',
#   '@material': 'Material7',
#   'elem': {'@eid': '7', '@shape': 'quad4', '@nodes': '9 35 36 10'}},
#  {'@name': 'Component8',
#   '@color': '-6710887',
#   '@material': 'Material8',
#   'elem': {'@eid': '8', '@shape': 'quad4', '@nodes': '10 36 37 11'}},
#  {'@name': 'Component9',
#   '@color': '-6710887',
#   '@material': 'Material9',
#   'elem': {'@eid': '9', '@shape': 'quad4', '@nodes': '11 37 38 12'}},
#  {'@name': 'Component10',
#   '@color': '-6710887',
#   '@material': 'Material10',
#   'elem': {'@eid': '10', '@shape': 'quad4', '@nodes': '12 38 39 13'}},
#  {'@name': 'Component11',
#   '@color': '-6710887',
#   '@material': 'Material11',
#   'elem': {'@eid': '11', '@shape': 'quad4', '@nodes': '13 39 40 14'}},
#  {'@name': 'Component12',
#   '@color': '-6710887',
#   '@material': 'Material12',
#   'elem': {'@eid': '12', '@shape': 'quad4', '@nodes': '14 40 41 15'}},
#  {'@name': 'Component13',
#   '@color': '-6710887',
#   '@material': 'Material13',
#   'elem': {'@eid': '13', '@shape': 'quad4', '@nodes': '15 41 42 16'}},
#  {'@name': 'Component14',
#   '@color': '-6710887',
#   '@material': 'Material14',
#   'elem': {'@eid': '14', '@shape': 'quad4', '@nodes': '16 42 43 17'}},
#  {'@name': 'Component15',
#   '@color': '-6710887',
#   '@material': 'Material15',
#   'elem': {'@eid': '15', '@shape': 'quad4', '@nodes': '17 43 44 18'}},
#  {'@name': 'Component16',
#   '@color': '-6710887',
#   '@material': 'Material16',
#   'elem': {'@eid': '16', '@shape': 'quad4', '@nodes': '18 44 45 19'}},
#  {'@name': 'Component17',
#   '@color': '-6710887',
#   '@material': 'Material17',
#   'elem': {'@eid': '17', '@shape': 'quad4', '@nodes': '19 45 46 20'}},
#  {'@name': 'Component18',
#   '@color': '-6710887',
#   '@material': 'Material18',
#   'elem': {'@eid': '18', '@shape': 'quad4', '@nodes': '20 46 47 21'}},
#  {'@name': 'Component19',
#   '@color': '-6710887',
#   '@material': 'Material19',
#   'elem': {'@eid': '19', '@shape': 'quad4', '@nodes': '21 47 48 22'}},
#  {'@name': 'Component20',
#   '@color': '-6710887',
#   '@material': 'Material20',
#   'elem': {'@eid': '20', '@shape': 'quad4', '@nodes': '22 48 49 23'}},
#  {'@name': 'Component21',
#   '@color': '-6710887',
#   '@material': 'Material21',
#   'elem': {'@eid': '21', '@shape': 'quad4', '@nodes': '23 49 50 24'}},
#  {'@name': 'Component22',
#   '@color': '-6710887',
#   '@material': 'Material22',
#   'elem': {'@eid': '22', '@shape': 'quad4', '@nodes': '24 50 51 25'}},
#  {'@name': 'Component23',
#   '@color': '-6710887',
#   '@material': 'Material23',
#   'elem': {'@eid': '23', '@shape': 'quad4', '@nodes': '25 51 52 26'}},
#  {'@name': 'Component24',
#   '@color': '-6710887',
#   '@material': 'Material24',
#   'elem': {'@eid': '24', '@shape': 'quad4', '@nodes': '26 52 53 27'}},
#  {'@name': 'Component25',
#   '@color': '-6710887',
#   '@material': 'Material25',
#   'elem': {'@eid': '25', '@shape': 'quad4', '@nodes': '27 53 54 28'}},
#  {'@name': 'Component26',
#   '@color': '-6710887',
#   '@material': 'Material26',
#   'elem': {'@eid': '26', '@shape': 'quad4', '@nodes': '28 54 55 29'}},
#  {'@name': 'Component27',
#   '@color': '-6710887',
#   '@material': 'Material27',
#   'elem': {'@eid': '27', '@shape': 'quad4', '@nodes': '29 55 56 4'}},
#  {'@name': 'Component28',
#   '@color': '-6710887',
#   '@material': 'Material28',
#   'elem': {'@eid': '28', '@shape': 'quad4', '@nodes': '30 57 58 31'}},
#  {'@name': 'Component29',
#   '@color': '-6710887',
#   '@material': 'Material29',
#   'elem': {'@eid': '29', '@shape': 'quad4', '@nodes': '31 58 59 32'}},
#  {'@name': 'Component30',
#   '@color': '-6710887',
#   '@material': 'Material30',
#   'elem': {'@eid': '30', '@shape': 'quad4', '@nodes': '32 59 60 33'}},
#  {'@name': 'Component31',
#   '@color': '-6710887',
#   '@material': 'Material31',
#   'elem': {'@eid': '31', '@shape': 'quad4', '@nodes': '33 60 61 34'}},
#  {'@name': 'Component32',
#   '@color': '-6710887',
#   '@material': 'Material32',
#   'elem': {'@eid': '32', '@shape': 'quad4', '@nodes': '34 61 62 35'}},
#  {'@name': 'Component33',
#   '@color': '-6710887',
#   '@material': 'Material33',
#   'elem': {'@eid': '33', '@shape': 'quad4', '@nodes': '35 62 63 36'}},
#  {'@name': 'Component34',
#   '@color': '-6710887',
#   '@material': 'Material34',
#   'elem': {'@eid': '34', '@shape': 'quad4', '@nodes': '36 63 64 37'}},
#  {'@name': 'Component35',
#   '@color': '-6710887',
#   '@material': 'Material35',
#   'elem': {'@eid': '35', '@shape': 'quad4', '@nodes': '37 64 65 38'}},
#  {'@name': 'Component36',
#   '@color': '-6710887',
#   '@material': 'Material36',
#   'elem': {'@eid': '36', '@shape': 'quad4', '@nodes': '38 65 66 39'}},
#  {'@name': 'Component37',
#   '@color': '-6710887',
#   '@material': 'Material37',
#   'elem': {'@eid': '37', '@shape': 'quad4', '@nodes': '39 66 67 40'}},
#  {'@name': 'Component38',
#   '@color': '-6710887',
#   '@material': 'Material38',
#   'elem': {'@eid': '38', '@shape': 'quad4', '@nodes': '40 67 68 41'}},
#  {'@name': 'Component39',
#   '@color': '-6710887',
#   '@material': 'Material39',
#   'elem': {'@eid': '39', '@shape': 'quad4', '@nodes': '41 68 69 42'}},
#  {'@name': 'Component40',
#   '@color': '-6710887',
#   '@material': 'Material40',
#   'elem': {'@eid': '40', '@shape': 'quad4', '@nodes': '42 69 70 43'}},
#  {'@name': 'Component41',
#   '@color': '-6710887',
#   '@material': 'Material41',
#   'elem': {'@eid': '41', '@shape': 'quad4', '@nodes': '43 70 71 44'}},
#  {'@name': 'Component42',
#   '@color': '-6710887',
#   '@material': 'Material42',
#   'elem': {'@eid': '42', '@shape': 'quad4', '@nodes': '44 71 72 45'}},
#  {'@name': 'Component43',
#   '@color': '-6710887',
#   '@material': 'Material43',
#   'elem': {'@eid': '43', '@shape': 'quad4', '@nodes': '45 72 73 46'}},
#  {'@name': 'Component44',
#   '@color': '-6710887',
#   '@material': 'Material44',
#   'elem': {'@eid': '44', '@shape': 'quad4', '@nodes': '46 73 74 47'}},
#  {'@name': 'Component45',
#   '@color': '-6710887',
#   '@material': 'Material45',
#   'elem': {'@eid': '45', '@shape': 'quad4', '@nodes': '47 74 75 48'}},
#  {'@name': 'Component46',
#   '@color': '-6710887',
#   '@material': 'Material46',
#   'elem': {'@eid': '46', '@shape': 'quad4', '@nodes': '48 75 76 49'}},
#  {'@name': 'Component47',
#   '@color': '-6710887',
#   '@material': 'Material47',
#   'elem': {'@eid': '47', '@shape': 'quad4', '@nodes': '49 76 77 50'}},
#  {'@name': 'Component48',
#   '@color': '-6710887',
#   '@material': 'Material48',
#   'elem': {'@eid': '48', '@shape': 'quad4', '@nodes': '50 77 78 51'}},
#  {'@name': 'Component49',
#   '@color': '-6710887',
#   '@material': 'Material49',
#   'elem': {'@eid': '49', '@shape': 'quad4', '@nodes': '51 78 79 52'}},
#  {'@name': 'Component50',
#   '@color': '-6710887',
#   '@material': 'Material50',
#   'elem': {'@eid': '50', '@shape': 'quad4', '@nodes': '52 79 80 53'}},
#  {'@name': 'Component51',
#   '@color': '-6710887',
#   '@material': 'Material51',
#   'elem': {'@eid': '51', '@shape': 'quad4', '@nodes': '53 80 81 54'}},
#  {'@name': 'Component52',
#   '@color': '-6710887',
#   '@material': 'Material52',
#   'elem': {'@eid': '52', '@shape': 'quad4', '@nodes': '54 81 82 55'}},
#  {'@name': 'Component53',
#   '@color': '-6710887',
#   '@material': 'Material53',
#   'elem': {'@eid': '53', '@shape': 'quad4', '@nodes': '55 82 83 56'}},
#  {'@name': 'Component54',
#   '@color': '-6710887',
#   '@material': 'Material54',
#   'elem': {'@eid': '54', '@shape': 'quad4', '@nodes': '57 84 85 58'}},
#  {'@name': 'Component55',
#   '@color': '-6710887',
#   '@material': 'Material55',
#   'elem': {'@eid': '55', '@shape': 'quad4', '@nodes': '58 85 86 59'}},
#  {'@name': 'Component56',
#   '@color': '-6710887',
#   '@material': 'Material56',
#   'elem': {'@eid': '56', '@shape': 'quad4', '@nodes': '59 86 87 60'}},
#  {'@name': 'Component57',
#   '@color': '-6710887',
#   '@material': 'Material57',
#   'elem': {'@eid': '57', '@shape': 'quad4', '@nodes': '60 87 88 61'}},
#  {'@name': 'Component58',
#   '@color': '-6710887',
#   '@material': 'Material58',
#   'elem': {'@eid': '58', '@shape': 'quad4', '@nodes': '61 88 89 62'}},
#  {'@name': 'Component59',
#   '@color': '-6710887',
#   '@material': 'Material59',
#   'elem': {'@eid': '59', '@shape': 'quad4', '@nodes': '62 89 90 63'}},
#  {'@name': 'Component60',
#   '@color': '-6710887',
#   '@material': 'Material60',
#   'elem': {'@eid': '60', '@shape': 'quad4', '@nodes': '63 90 91 64'}},
#  {'@name': 'Component61',
#   '@color': '-6710887',
#   '@material': 'Material61',
#   'elem': {'@eid': '61', '@shape': 'quad4', '@nodes': '64 91 92 65'}},
#  {'@name': 'Component62',
#   '@color': '-6710887',
#   '@material': 'Material62',
#   'elem': {'@eid': '62', '@shape': 'quad4', '@nodes': '65 92 93 66'}},
#  {'@name': 'Component63',
#   '@color': '-6710887',
#   '@material': 'Material63',
#   'elem': {'@eid': '63', '@shape': 'quad4', '@nodes': '66 93 94 67'}},
#  {'@name': 'Component64',
#   '@color': '-6710887',
#   '@material': 'Material64',
#   'elem': {'@eid': '64', '@shape': 'quad4', '@nodes': '67 94 95 68'}},
#  {'@name': 'Component65',
#   '@color': '-6710887',
#   '@material': 'Material65',
#   'elem': {'@eid': '65', '@shape': 'quad4', '@nodes': '68 95 96 69'}},
#  {'@name': 'Component66',
#   '@color': '-6710887',
#   '@material': 'Material66',
#   'elem': {'@eid': '66', '@shape': 'quad4', '@nodes': '69 96 97 70'}},
#  {'@name': 'Component67',
#   '@color': '-6710887',
#   '@material': 'Material67',
#   'elem': {'@eid': '67', '@shape': 'quad4', '@nodes': '70 97 98 71'}},
#  {'@name': 'Component68',
#   '@color': '-6710887',
#   '@material': 'Material68',
#   'elem': {'@eid': '68', '@shape': 'quad4', '@nodes': '71 98 99 72'}},
#  {'@name': 'Component69',
#   '@color': '-6710887',
#   '@material': 'Material69',
#   'elem': {'@eid': '69', '@shape': 'quad4', '@nodes': '72 99 100 73'}},
#  {'@name': 'Component70',
#   '@color': '-6710887',
#   '@material': 'Material70',
#   'elem': {'@eid': '70', '@shape': 'quad4', '@nodes': '73 100 101 74'}},
#  {'@name': 'Component71',
#   '@color': '-6710887',
#   '@material': 'Material71',
#   'elem': {'@eid': '71', '@shape': 'quad4', '@nodes': '74 101 102 75'}},
#  {'@name': 'Component72',
#   '@color': '-6710887',
#   '@material': 'Material72',
#   'elem': {'@eid': '72', '@shape': 'quad4', '@nodes': '75 102 103 76'}},
#  {'@name': 'Component73',
#   '@color': '-6710887',
#   '@material': 'Material73',
#   'elem': {'@eid': '73', '@shape': 'quad4', '@nodes': '76 103 104 77'}},
#  {'@name': 'Component74',
#   '@color': '-6710887',
#   '@material': 'Material74',
#   'elem': {'@eid': '74', '@shape': 'quad4', '@nodes': '77 104 105 78'}},
#  {'@name': 'Component75',
#   '@color': '-6710887',
#   '@material': 'Material75',
#   'elem': {'@eid': '75', '@shape': 'quad4', '@nodes': '78 105 106 79'}},
#  {'@name': 'Component76',
#   '@color': '-6710887',
#   '@material': 'Material76',
#   'elem': {'@eid': '76', '@shape': 'quad4', '@nodes': '79 106 107 80'}},
#  {'@name': 'Component77',
#   '@color': '-6710887',
#   '@material': 'Material77',
#   'elem': {'@eid': '77', '@shape': 'quad4', '@nodes': '80 107 108 81'}},
#  {'@name': 'Component78',
#   '@color': '-6710887',
#   '@material': 'Material78',
#   'elem': {'@eid': '78', '@shape': 'quad4', '@nodes': '81 108 109 82'}},
#  {'@name': 'Component79',
#   '@color': '-6710887',
#   '@material': 'Material79',
#   'elem': {'@eid': '79', '@shape': 'quad4', '@nodes': '82 109 110 83'}},
#  {'@name': 'Component80',
#   '@color': '-6710887',
#   '@material': 'Material80',
#   'elem': {'@eid': '80', '@shape': 'quad4', '@nodes': '84 111 112 85'}},
#  {'@name': 'Component81',
#   '@color': '-6710887',
#   '@material': 'Material81',
#   'elem': {'@eid': '81', '@shape': 'quad4', '@nodes': '85 112 113 86'}},
#  {'@name': 'Component82',
#   '@color': '-6710887',
#   '@material': 'Material82',
#   'elem': {'@eid': '82', '@shape': 'quad4', '@nodes': '86 113 114 87'}},
#  {'@name': 'Component83',
#   '@color': '-6710887',
#   '@material': 'Material83',
#   'elem': {'@eid': '83', '@shape': 'quad4', '@nodes': '87 114 115 88'}},
#  {'@name': 'Component84',
#   '@color': '-6710887',
#   '@material': 'Material84',
#   'elem': {'@eid': '84', '@shape': 'quad4', '@nodes': '88 115 116 89'}},
#  {'@name': 'Component85',
#   '@color': '-6710887',
#   '@material': 'Material85',
#   'elem': {'@eid': '85', '@shape': 'quad4', '@nodes': '89 116 117 90'}},
#  {'@name': 'Component86',
#   '@color': '-6710887',
#   '@material': 'Material86',
#   'elem': {'@eid': '86', '@shape': 'quad4', '@nodes': '90 117 118 91'}},
#  {'@name': 'Component87',
#   '@color': '-6710887',
#   '@material': 'Material87',
#   'elem': {'@eid': '87', '@shape': 'quad4', '@nodes': '91 118 119 92'}},
#  {'@name': 'Component88',
#   '@color': '-6710887',
#   '@material': 'Material88',
#   'elem': {'@eid': '88', '@shape': 'quad4', '@nodes': '92 119 120 93'}},
#  {'@name': 'Component89',
#   '@color': '-6710887',
#   '@material': 'Material89',
#   'elem': {'@eid': '89', '@shape': 'quad4', '@nodes': '93 120 121 94'}},
#  {'@name': 'Component90',
#   '@color': '-6710887',
#   '@material': 'Material90',
#   'elem': {'@eid': '90', '@shape': 'quad4', '@nodes': '94 121 122 95'}},
#  {'@name': 'Component91',
#   '@color': '-6710887',
#   '@material': 'Material91',
#   'elem': {'@eid': '91', '@shape': 'quad4', '@nodes': '95 122 123 96'}},
#  {'@name': 'Component92',
#   '@color': '-6710887',
#   '@material': 'Material92',
#   'elem': {'@eid': '92', '@shape': 'quad4', '@nodes': '96 123 124 97'}},
#  {'@name': 'Component93',
#   '@color': '-6710887',
#   '@material': 'Material93',
#   'elem': {'@eid': '93', '@shape': 'quad4', '@nodes': '97 124 125 98'}},
#  {'@name': 'Component94',
#   '@color': '-6710887',
#   '@material': 'Material94',
#   'elem': {'@eid': '94', '@shape': 'quad4', '@nodes': '98 125 126 99'}},
#  {'@name': 'Component95',
#   '@color': '-6710887',
#   '@material': 'Material95',
#   'elem': {'@eid': '95', '@shape': 'quad4', '@nodes': '99 126 127 100'}},
#  {'@name': 'Component96',
#   '@color': '-6710887',
#   '@material': 'Material96',
#   'elem': {'@eid': '96', '@shape': 'quad4', '@nodes': '100 127 128 101'}},
#  {'@name': 'Component97',
#   '@color': '-6710887',
#   '@material': 'Material97',
#   'elem': {'@eid': '97', '@shape': 'quad4', '@nodes': '101 128 129 102'}},
#  {'@name': 'Component98',
#   '@color': '-6710887',
#   '@material': 'Material98',
#   'elem': {'@eid': '98', '@shape': 'quad4', '@nodes': '102 129 130 103'}},
#  {'@name': 'Component99',
#   '@color': '-6710887',
#   '@material': 'Material99',
#   'elem': {'@eid': '99', '@shape': 'quad4', '@nodes': '103 130 131 104'}},
#  {'@name': 'Component100',
#   '@color': '-6710887',
#   '@material': 'Material100',
#   'elem': {'@eid': '100', '@shape': 'quad4', '@nodes': '104 131 132 105'}},
#  {'@name': 'Component101',
#   '@color': '-6710887',
#   '@material': 'Material101',
#   'elem': {'@eid': '101', '@shape': 'quad4', '@nodes': '105 132 133 106'}},
#  {'@name': 'Component102',
#   '@color': '-6710887',
#   '@material': 'Material102',
#   'elem': {'@eid': '102', '@shape': 'quad4', '@nodes': '106 133 134 107'}},
#  {'@name': 'Component103',
#   '@color': '-6710887',
#   '@material': 'Material103',
#   'elem': {'@eid': '103', '@shape': 'quad4', '@nodes': '107 134 135 108'}},
#  {'@name': 'Component104',
#   '@color': '-6710887',
#   '@material': 'Material104',
#   'elem': {'@eid': '104', '@shape': 'quad4', '@nodes': '108 135 136 109'}},
#  {'@name': 'Component105',
#   '@color': '-6710887',
#   '@material': 'Material105',
#   'elem': {'@eid': '105', '@shape': 'quad4', '@nodes': '109 136 137 110'}},
#  {'@name': 'Component106',
#   '@color': '-6710887',
#   '@material': 'Material106',
#   'elem': {'@eid': '106', '@shape': 'quad4', '@nodes': '111 138 139 112'}},
#  {'@name': 'Component107',
#   '@color': '-6710887',
#   '@material': 'Material107',
#   'elem': {'@eid': '107', '@shape': 'quad4', '@nodes': '112 139 140 113'}},
#  {'@name': 'Component108',
#   '@color': '-6710887',
#   '@material': 'Material108',
#   'elem': {'@eid': '108', '@shape': 'quad4', '@nodes': '113 140 141 114'}},
#  {'@name': 'Component109',
#   '@color': '-6710887',
#   '@material': 'Material109',
#   'elem': {'@eid': '109', '@shape': 'quad4', '@nodes': '114 141 142 115'}},
#  {'@name': 'Component110',
#   '@color': '-6710887',
#   '@material': 'Material110',
#   'elem': {'@eid': '110', '@shape': 'quad4', '@nodes': '115 142 143 116'}},
#  {'@name': 'Component111',
#   '@color': '-6710887',
#   '@material': 'Material111',
#   'elem': {'@eid': '111', '@shape': 'quad4', '@nodes': '116 143 144 117'}},
#  {'@name': 'Component112',
#   '@color': '-6710887',
#   '@material': 'Material112',
#   'elem': {'@eid': '112', '@shape': 'quad4', '@nodes': '117 144 145 118'}},
#  {'@name': 'Component113',
#   '@color': '-6710887',
#   '@material': 'Material113',
#   'elem': {'@eid': '113', '@shape': 'quad4', '@nodes': '118 145 146 119'}},
#  {'@name': 'Component114',
#   '@color': '-6710887',
#   '@material': 'Material114',
#   'elem': {'@eid': '114', '@shape': 'quad4', '@nodes': '119 146 147 120'}},
#  {'@name': 'Component115',
#   '@color': '-6710887',
#   '@material': 'Material115',
#   'elem': {'@eid': '115', '@shape': 'quad4', '@nodes': '120 147 148 121'}},
#  {'@name': 'Component116',
#   '@color': '-6710887',
#   '@material': 'Material116',
#   'elem': {'@eid': '116', '@shape': 'quad4', '@nodes': '121 148 149 122'}},
#  {'@name': 'Component117',
#   '@color': '-6710887',
#   '@material': 'Material117',
#   'elem': {'@eid': '117', '@shape': 'quad4', '@nodes': '122 149 150 123'}},
#  {'@name': 'Component118',
#   '@color': '-6710887',
#   '@material': 'Material118',
#   'elem': {'@eid': '118', '@shape': 'quad4', '@nodes': '123 150 151 124'}},
#  {'@name': 'Component119',
#   '@color': '-6710887',
#   '@material': 'Material119',
#   'elem': {'@eid': '119', '@shape': 'quad4', '@nodes': '124 151 152 125'}},
#  {'@name': 'Component120',
#   '@color': '-6710887',
#   '@material': 'Material120',
#   'elem': {'@eid': '120', '@shape': 'quad4', '@nodes': '125 152 153 126'}},
#  {'@name': 'Component121',
#   '@color': '-6710887',
#   '@material': 'Material121',
#   'elem': {'@eid': '121', '@shape': 'quad4', '@nodes': '126 153 154 127'}},
#  {'@name': 'Component122',
#   '@color': '-6710887',
#   '@material': 'Material122',
#   'elem': {'@eid': '122', '@shape': 'quad4', '@nodes': '127 154 155 128'}},
#  {'@name': 'Component123',
#   '@color': '-6710887',
#   '@material': 'Material123',
#   'elem': {'@eid': '123', '@shape': 'quad4', '@nodes': '128 155 156 129'}},
#  {'@name': 'Component124',
#   '@color': '-6710887',
#   '@material': 'Material124',
#   'elem': {'@eid': '124', '@shape': 'quad4', '@nodes': '129 156 157 130'}},
#  {'@name': 'Component125',
#   '@color': '-6710887',
#   '@material': 'Material125',
#   'elem': {'@eid': '125', '@shape': 'quad4', '@nodes': '130 157 158 131'}},
#  {'@name': 'Component126',
#   '@color': '-6710887',
#   '@material': 'Material126',
#   'elem': {'@eid': '126', '@shape': 'quad4', '@nodes': '131 158 159 132'}},
#  {'@name': 'Component127',
#   '@color': '-6710887',
#   '@material': 'Material127',
#   'elem': {'@eid': '127', '@shape': 'quad4', '@nodes': '132 159 160 133'}},
#  {'@name': 'Component128',
#   '@color': '-6710887',
#   '@material': 'Material128',
#   'elem': {'@eid': '128', '@shape': 'quad4', '@nodes': '133 160 161 134'}},
#  {'@name': 'Component129',
#   '@color': '-6710887',
#   '@material': 'Material129',
#   'elem': {'@eid': '129', '@shape': 'quad4', '@nodes': '134 161 162 135'}},
#  {'@name': 'Component130',
#   '@color': '-6710887',
#   '@material': 'Material130',
#   'elem': {'@eid': '130', '@shape': 'quad4', '@nodes': '135 162 163 136'}},
#  {'@name': 'Component131',
#   '@color': '-6710887',
#   '@material': 'Material131',
#   'elem': {'@eid': '131', '@shape': 'quad4', '@nodes': '136 163 164 137'}},
#  {'@name': 'Component132',
#   '@color': '-6710887',
#   '@material': 'Material132',
#   'elem': {'@eid': '132', '@shape': 'quad4', '@nodes': '138 165 166 139'}},
#  {'@name': 'Component133',
#   '@color': '-6710887',
#   '@material': 'Material133',
#   'elem': {'@eid': '133', '@shape': 'quad4', '@nodes': '139 166 167 140'}},
#  {'@name': 'Component134',
#   '@color': '-6710887',
#   '@material': 'Material134',
#   'elem': {'@eid': '134', '@shape': 'quad4', '@nodes': '140 167 168 141'}},
#  {'@name': 'Component135',
#   '@color': '-6710887',
#   '@material': 'Material135',
#   'elem': {'@eid': '135', '@shape': 'quad4', '@nodes': '141 168 169 142'}},
#  {'@name': 'Component136',
#   '@color': '-6710887',
#   '@material': 'Material136',
#   'elem': {'@eid': '136', '@shape': 'quad4', '@nodes': '142 169 170 143'}},
#  {'@name': 'Component137',
#   '@color': '-6710887',
#   '@material': 'Material137',
#   'elem': {'@eid': '137', '@shape': 'quad4', '@nodes': '143 170 171 144'}},
#  {'@name': 'Component138',
#   '@color': '-6710887',
#   '@material': 'Material138',
#   'elem': {'@eid': '138', '@shape': 'quad4', '@nodes': '144 171 172 145'}},
#  {'@name': 'Component139',
#   '@color': '-6710887',
#   '@material': 'Material139',
#   'elem': {'@eid': '139', '@shape': 'quad4', '@nodes': '145 172 173 146'}},
#  {'@name': 'Component140',
#   '@color': '-6710887',
#   '@material': 'Material140',
#   'elem': {'@eid': '140', '@shape': 'quad4', '@nodes': '146 173 174 147'}},
#  {'@name': 'Component141',
#   '@color': '-6710887',
#   '@material': 'Material141',
#   'elem': {'@eid': '141', '@shape': 'quad4', '@nodes': '147 174 175 148'}},
#  {'@name': 'Component142',
#   '@color': '-6710887',
#   '@material': 'Material142',
#   'elem': {'@eid': '142', '@shape': 'quad4', '@nodes': '148 175 176 149'}},
#  {'@name': 'Component143',
#   '@color': '-6710887',
#   '@material': 'Material143',
#   'elem': {'@eid': '143', '@shape': 'quad4', '@nodes': '149 176 177 150'}},
#  {'@name': 'Component144',
#   '@color': '-6710887',
#   '@material': 'Material144',
#   'elem': {'@eid': '144', '@shape': 'quad4', '@nodes': '150 177 178 151'}},
#  {'@name': 'Component145',
#   '@color': '-6710887',
#   '@material': 'Material145',
#   'elem': {'@eid': '145', '@shape': 'quad4', '@nodes': '151 178 179 152'}},
#  {'@name': 'Component146',
#   '@color': '-6710887',
#   '@material': 'Material146',
#   'elem': {'@eid': '146', '@shape': 'quad4', '@nodes': '152 179 180 153'}},
#  {'@name': 'Component147',
#   '@color': '-6710887',
#   '@material': 'Material147',
#   'elem': {'@eid': '147', '@shape': 'quad4', '@nodes': '153 180 181 154'}},
#  {'@name': 'Component148',
#   '@color': '-6710887',
#   '@material': 'Material148',
#   'elem': {'@eid': '148', '@shape': 'quad4', '@nodes': '154 181 182 155'}},
#  {'@name': 'Component149',
#   '@color': '-6710887',
#   '@material': 'Material149',
#   'elem': {'@eid': '149', '@shape': 'quad4', '@nodes': '155 182 183 156'}},
#  {'@name': 'Component150',
#   '@color': '-6710887',
#   '@material': 'Material150',
#   'elem': {'@eid': '150', '@shape': 'quad4', '@nodes': '156 183 184 157'}},
#  {'@name': 'Component151',
#   '@color': '-6710887',
#   '@material': 'Material151',
#   'elem': {'@eid': '151', '@shape': 'quad4', '@nodes': '157 184 185 158'}},
#  {'@name': 'Component152',
#   '@color': '-6710887',
#   '@material': 'Material152',
#   'elem': {'@eid': '152', '@shape': 'quad4', '@nodes': '158 185 186 159'}},
#  {'@name': 'Component153',
#   '@color': '-6710887',
#   '@material': 'Material153',
#   'elem': {'@eid': '153', '@shape': 'quad4', '@nodes': '159 186 187 160'}},
#  {'@name': 'Component154',
#   '@color': '-6710887',
#   '@material': 'Material154',
#   'elem': {'@eid': '154', '@shape': 'quad4', '@nodes': '160 187 188 161'}},
#  {'@name': 'Component155',
#   '@color': '-6710887',
#   '@material': 'Material155',
#   'elem': {'@eid': '155', '@shape': 'quad4', '@nodes': '161 188 189 162'}},
#  {'@name': 'Component156',
#   '@color': '-6710887',
#   '@material': 'Material156',
#   'elem': {'@eid': '156', '@shape': 'quad4', '@nodes': '162 189 190 163'}},
#  {'@name': 'Component157',
#   '@color': '-6710887',
#   '@material': 'Material157',
#   'elem': {'@eid': '157', '@shape': 'quad4', '@nodes': '163 190 191 164'}},
#  {'@name': 'Component158',
#   '@color': '-6710887',
#   '@material': 'Material158',
#   'elem': {'@eid': '158', '@shape': 'quad4', '@nodes': '165 192 193 166'}},
#  {'@name': 'Component159',
#   '@color': '-6710887',
#   '@material': 'Material159',
#   'elem': {'@eid': '159', '@shape': 'quad4', '@nodes': '166 193 194 167'}},
#  {'@name': 'Component160',
#   '@color': '-6710887',
#   '@material': 'Material160',
#   'elem': {'@eid': '160', '@shape': 'quad4', '@nodes': '167 194 195 168'}},
#  {'@name': 'Component161',
#   '@color': '-6710887',
#   '@material': 'Material161',
#   'elem': {'@eid': '161', '@shape': 'quad4', '@nodes': '168 195 196 169'}},
#  {'@name': 'Component162',
#   '@color': '-6710887',
#   '@material': 'Material162',
#   'elem': {'@eid': '162', '@shape': 'quad4', '@nodes': '169 196 197 170'}},
#  {'@name': 'Component163',
#   '@color': '-6710887',
#   '@material': 'Material163',
#   'elem': {'@eid': '163', '@shape': 'quad4', '@nodes': '170 197 198 171'}},
#  {'@name': 'Component164',
#   '@color': '-6710887',
#   '@material': 'Material164',
#   'elem': {'@eid': '164', '@shape': 'quad4', '@nodes': '171 198 199 172'}},
#  {'@name': 'Component165',
#   '@color': '-6710887',
#   '@material': 'Material165',
#   'elem': {'@eid': '165', '@shape': 'quad4', '@nodes': '172 199 200 173'}},
#  {'@name': 'Component166',
#   '@color': '-6710887',
#   '@material': 'Material166',
#   'elem': {'@eid': '166', '@shape': 'quad4', '@nodes': '173 200 201 174'}},
#  {'@name': 'Component167',
#   '@color': '-6710887',
#   '@material': 'Material167',
#   'elem': {'@eid': '167', '@shape': 'quad4', '@nodes': '174 201 202 175'}},
#  {'@name': 'Component168',
#   '@color': '-6710887',
#   '@material': 'Material168',
#   'elem': {'@eid': '168', '@shape': 'quad4', '@nodes': '175 202 203 176'}},
#  {'@name': 'Component169',
#   '@color': '-6710887',
#   '@material': 'Material169',
#   'elem': {'@eid': '169', '@shape': 'quad4', '@nodes': '176 203 204 177'}},
#  {'@name': 'Component170',
#   '@color': '-6710887',
#   '@material': 'Material170',
#   'elem': {'@eid': '170', '@shape': 'quad4', '@nodes': '177 204 205 178'}},
#  {'@name': 'Component171',
#   '@color': '-6710887',
#   '@material': 'Material171',
#   'elem': {'@eid': '171', '@shape': 'quad4', '@nodes': '178 205 206 179'}},
#  {'@name': 'Component172',
#   '@color': '-6710887',
#   '@material': 'Material172',
#   'elem': {'@eid': '172', '@shape': 'quad4', '@nodes': '179 206 207 180'}},
#  {'@name': 'Component173',
#   '@color': '-6710887',
#   '@material': 'Material173',
#   'elem': {'@eid': '173', '@shape': 'quad4', '@nodes': '180 207 208 181'}},
#  {'@name': 'Component174',
#   '@color': '-6710887',
#   '@material': 'Material174',
#   'elem': {'@eid': '174', '@shape': 'quad4', '@nodes': '181 208 209 182'}},
#  {'@name': 'Component175',
#   '@color': '-6710887',
#   '@material': 'Material175',
#   'elem': {'@eid': '175', '@shape': 'quad4', '@nodes': '182 209 210 183'}},
#  {'@name': 'Component176',
#   '@color': '-6710887',
#   '@material': 'Material176',
#   'elem': {'@eid': '176', '@shape': 'quad4', '@nodes': '183 210 211 184'}},
#  {'@name': 'Component177',
#   '@color': '-6710887',
#   '@material': 'Material177',
#   'elem': {'@eid': '177', '@shape': 'quad4', '@nodes': '184 211 212 185'}},
#  {'@name': 'Component178',
#   '@color': '-6710887',
#   '@material': 'Material178',
#   'elem': {'@eid': '178', '@shape': 'quad4', '@nodes': '185 212 213 186'}},
#  {'@name': 'Component179',
#   '@color': '-6710887',
#   '@material': 'Material179',
#   'elem': {'@eid': '179', '@shape': 'quad4', '@nodes': '186 213 214 187'}},
#  {'@name': 'Component180',
#   '@color': '-6710887',
#   '@material': 'Material180',
#   'elem': {'@eid': '180', '@shape': 'quad4', '@nodes': '187 214 215 188'}},
#  {'@name': 'Component181',
#   '@color': '-6710887',
#   '@material': 'Material181',
#   'elem': {'@eid': '181', '@shape': 'quad4', '@nodes': '188 215 216 189'}},
#  {'@name': 'Component182',
#   '@color': '-6710887',
#   '@material': 'Material182',
#   'elem': {'@eid': '182', '@shape': 'quad4', '@nodes': '189 216 217 190'}},
#  {'@name': 'Component183',
#   '@color': '-6710887',
#   '@material': 'Material183',
#   'elem': {'@eid': '183', '@shape': 'quad4', '@nodes': '190 217 218 191'}},
#  {'@name': 'Component184',
#   '@color': '-6710887',
#   '@material': 'Material184',
#   'elem': {'@eid': '184', '@shape': 'quad4', '@nodes': '192 219 220 193'}},
#  {'@name': 'Component185',
#   '@color': '-6710887',
#   '@material': 'Material185',
#   'elem': {'@eid': '185', '@shape': 'quad4', '@nodes': '193 220 221 194'}},
#  {'@name': 'Component186',
#   '@color': '-6710887',
#   '@material': 'Material186',
#   'elem': {'@eid': '186', '@shape': 'quad4', '@nodes': '194 221 222 195'}},
#  {'@name': 'Component187',
#   '@color': '-6710887',
#   '@material': 'Material187',
#   'elem': {'@eid': '187', '@shape': 'quad4', '@nodes': '195 222 223 196'}},
#  {'@name': 'Component188',
#   '@color': '-6710887',
#   '@material': 'Material188',
#   'elem': {'@eid': '188', '@shape': 'quad4', '@nodes': '196 223 224 197'}},
#  {'@name': 'Component189',
#   '@color': '-6710887',
#   '@material': 'Material189',
#   'elem': {'@eid': '189', '@shape': 'quad4', '@nodes': '197 224 225 198'}},
#  {'@name': 'Component190',
#   '@color': '-6710887',
#   '@material': 'Material190',
#   'elem': {'@eid': '190', '@shape': 'quad4', '@nodes': '198 225 226 199'}},
#  {'@name': 'Component191',
#   '@color': '-6710887',
#   '@material': 'Material191',
#   'elem': {'@eid': '191', '@shape': 'quad4', '@nodes': '199 226 227 200'}},
#  {'@name': 'Component192',
#   '@color': '-6710887',
#   '@material': 'Material192',
#   'elem': {'@eid': '192', '@shape': 'quad4', '@nodes': '200 227 228 201'}},
#  {'@name': 'Component193',
#   '@color': '-6710887',
#   '@material': 'Material193',
#   'elem': {'@eid': '193', '@shape': 'quad4', '@nodes': '201 228 229 202'}},
#  {'@name': 'Component194',
#   '@color': '-6710887',
#   '@material': 'Material194',
#   'elem': {'@eid': '194', '@shape': 'quad4', '@nodes': '202 229 230 203'}},
#  {'@name': 'Component195',
#   '@color': '-6710887',
#   '@material': 'Material195',
#   'elem': {'@eid': '195', '@shape': 'quad4', '@nodes': '203 230 231 204'}},
#  {'@name': 'Component196',
#   '@color': '-6710887',
#   '@material': 'Material196',
#   'elem': {'@eid': '196', '@shape': 'quad4', '@nodes': '204 231 232 205'}},
#  {'@name': 'Component197',
#   '@color': '-6710887',
#   '@material': 'Material197',
#   'elem': {'@eid': '197', '@shape': 'quad4', '@nodes': '205 232 233 206'}},
#  {'@name': 'Component198',
#   '@color': '-6710887',
#   '@material': 'Material198',
#   'elem': {'@eid': '198', '@shape': 'quad4', '@nodes': '206 233 234 207'}},
#  {'@name': 'Component199',
#   '@color': '-6710887',
#   '@material': 'Material199',
#   'elem': {'@eid': '199', '@shape': 'quad4', '@nodes': '207 234 235 208'}},
#  {'@name': 'Component200',
#   '@color': '-6710887',
#   '@material': 'Material200',
#   'elem': {'@eid': '200', '@shape': 'quad4', '@nodes': '208 235 236 209'}},
#  {'@name': 'Component201',
#   '@color': '-6710887',
#   '@material': 'Material201',
#   'elem': {'@eid': '201', '@shape': 'quad4', '@nodes': '209 236 237 210'}},
#  {'@name': 'Component202',
#   '@color': '-6710887',
#   '@material': 'Material202',
#   'elem': {'@eid': '202', '@shape': 'quad4', '@nodes': '210 237 238 211'}},
#  {'@name': 'Component203',
#   '@color': '-6710887',
#   '@material': 'Material203',
#   'elem': {'@eid': '203', '@shape': 'quad4', '@nodes': '211 238 239 212'}},
#  {'@name': 'Component204',
#   '@color': '-6710887',
#   '@material': 'Material204',
#   'elem': {'@eid': '204', '@shape': 'quad4', '@nodes': '212 239 240 213'}},
#  {'@name': 'Component205',
#   '@color': '-6710887',
#   '@material': 'Material205',
#   'elem': {'@eid': '205', '@shape': 'quad4', '@nodes': '213 240 241 214'}},
#  {'@name': 'Component206',
#   '@color': '-6710887',
#   '@material': 'Material206',
#   'elem': {'@eid': '206', '@shape': 'quad4', '@nodes': '214 241 242 215'}},
#  {'@name': 'Component207',
#   '@color': '-6710887',
#   '@material': 'Material207',
#   'elem': {'@eid': '207', '@shape': 'quad4', '@nodes': '215 242 243 216'}},
#  {'@name': 'Component208',
#   '@color': '-6710887',
#   '@material': 'Material208',
#   'elem': {'@eid': '208', '@shape': 'quad4', '@nodes': '216 243 244 217'}},
#  {'@name': 'Component209',
#   '@color': '-6710887',
#   '@material': 'Material209',
#   'elem': {'@eid': '209', '@shape': 'quad4', '@nodes': '217 244 245 218'}},
#  {'@name': 'Component210',
#   '@color': '-6710887',
#   '@material': 'Material210',
#   'elem': {'@eid': '210', '@shape': 'quad4', '@nodes': '219 246 247 220'}},
#  {'@name': 'Component211',
#   '@color': '-6710887',
#   '@material': 'Material211',
#   'elem': {'@eid': '211', '@shape': 'quad4', '@nodes': '220 247 248 221'}},
#  {'@name': 'Component212',
#   '@color': '-6710887',
#   '@material': 'Material212',
#   'elem': {'@eid': '212', '@shape': 'quad4', '@nodes': '221 248 249 222'}},
#  {'@name': 'Component213',
#   '@color': '-6710887',
#   '@material': 'Material213',
#   'elem': {'@eid': '213', '@shape': 'quad4', '@nodes': '222 249 250 223'}},
#  {'@name': 'Component214',
#   '@color': '-6710887',
#   '@material': 'Material214',
#   'elem': {'@eid': '214', '@shape': 'quad4', '@nodes': '223 250 251 224'}},
#  {'@name': 'Component215',
#   '@color': '-6710887',
#   '@material': 'Material215',
#   'elem': {'@eid': '215', '@shape': 'quad4', '@nodes': '224 251 252 225'}},
#  {'@name': 'Component216',
#   '@color': '-6710887',
#   '@material': 'Material216',
#   'elem': {'@eid': '216', '@shape': 'quad4', '@nodes': '225 252 253 226'}},
#  {'@name': 'Component217',
#   '@color': '-6710887',
#   '@material': 'Material217',
#   'elem': {'@eid': '217', '@shape': 'quad4', '@nodes': '226 253 254 227'}},
#  {'@name': 'Component218',
#   '@color': '-6710887',
#   '@material': 'Material218',
#   'elem': {'@eid': '218', '@shape': 'quad4', '@nodes': '227 254 255 228'}},
#  {'@name': 'Component219',
#   '@color': '-6710887',
#   '@material': 'Material219',
#   'elem': {'@eid': '219', '@shape': 'quad4', '@nodes': '228 255 256 229'}},
#  {'@name': 'Component220',
#   '@color': '-6710887',
#   '@material': 'Material220',
#   'elem': {'@eid': '220', '@shape': 'quad4', '@nodes': '229 256 257 230'}},
#  {'@name': 'Component221',
#   '@color': '-6710887',
#   '@material': 'Material221',
#   'elem': {'@eid': '221', '@shape': 'quad4', '@nodes': '230 257 258 231'}},
#  {'@name': 'Component222',
#   '@color': '-6710887',
#   '@material': 'Material222',
#   'elem': {'@eid': '222', '@shape': 'quad4', '@nodes': '231 258 259 232'}},
#  {'@name': 'Component223',
#   '@color': '-6710887',
#   '@material': 'Material223',
#   'elem': {'@eid': '223', '@shape': 'quad4', '@nodes': '232 259 260 233'}},
#  {'@name': 'Component224',
#   '@color': '-6710887',
#   '@material': 'Material224',
#   'elem': {'@eid': '224', '@shape': 'quad4', '@nodes': '233 260 261 234'}},
#  {'@name': 'Component225',
#   '@color': '-6710887',
#   '@material': 'Material225',
#   'elem': {'@eid': '225', '@shape': 'quad4', '@nodes': '234 261 262 235'}},
#  {'@name': 'Component226',
#   '@color': '-6710887',
#   '@material': 'Material226',
#   'elem': {'@eid': '226', '@shape': 'quad4', '@nodes': '235 262 263 236'}},
#  {'@name': 'Component227',
#   '@color': '-6710887',
#   '@material': 'Material227',
#   'elem': {'@eid': '227', '@shape': 'quad4', '@nodes': '236 263 264 237'}},
#  {'@name': 'Component228',
#   '@color': '-6710887',
#   '@material': 'Material228',
#   'elem': {'@eid': '228', '@shape': 'quad4', '@nodes': '237 264 265 238'}},
#  {'@name': 'Component229',
#   '@color': '-6710887',
#   '@material': 'Material229',
#   'elem': {'@eid': '229', '@shape': 'quad4', '@nodes': '238 265 266 239'}},
#  {'@name': 'Component230',
#   '@color': '-6710887',
#   '@material': 'Material230',
#   'elem': {'@eid': '230', '@shape': 'quad4', '@nodes': '239 266 267 240'}},
#  {'@name': 'Component231',
#   '@color': '-6710887',
#   '@material': 'Material231',
#   'elem': {'@eid': '231', '@shape': 'quad4', '@nodes': '240 267 268 241'}},
#  {'@name': 'Component232',
#   '@color': '-6710887',
#   '@material': 'Material232',
#   'elem': {'@eid': '232', '@shape': 'quad4', '@nodes': '241 268 269 242'}},
#  {'@name': 'Component233',
#   '@color': '-6710887',
#   '@material': 'Material233',
#   'elem': {'@eid': '233', '@shape': 'quad4', '@nodes': '242 269 270 243'}},
#  {'@name': 'Component234',
#   '@color': '-6710887',
#   '@material': 'Material234',
#   'elem': {'@eid': '234', '@shape': 'quad4', '@nodes': '243 270 271 244'}},
#  {'@name': 'Component235',
#   '@color': '-6710887',
#   '@material': 'Material235',
#   'elem': {'@eid': '235', '@shape': 'quad4', '@nodes': '244 271 272 245'}},
#  {'@name': 'Component236',
#   '@color': '-6710887',
#   '@material': 'Material236',
#   'elem': {'@eid': '236', '@shape': 'quad4', '@nodes': '246 273 274 247'}},
#  {'@name': 'Component237',
#   '@color': '-6710887',
#   '@material': 'Material237',
#   'elem': {'@eid': '237', '@shape': 'quad4', '@nodes': '247 274 275 248'}},
#  {'@name': 'Component238',
#   '@color': '-6710887',
#   '@material': 'Material238',
#   'elem': {'@eid': '238', '@shape': 'quad4', '@nodes': '248 275 276 249'}},
#  {'@name': 'Component239',
#   '@color': '-6710887',
#   '@material': 'Material239',
#   'elem': {'@eid': '239', '@shape': 'quad4', '@nodes': '249 276 277 250'}},
#  {'@name': 'Component240',
#   '@color': '-6710887',
#   '@material': 'Material240',
#   'elem': {'@eid': '240', '@shape': 'quad4', '@nodes': '250 277 278 251'}},
#  {'@name': 'Component241',
#   '@color': '-6710887',
#   '@material': 'Material241',
#   'elem': {'@eid': '241', '@shape': 'quad4', '@nodes': '251 278 279 252'}},
#  {'@name': 'Component242',
#   '@color': '-6710887',
#   '@material': 'Material242',
#   'elem': {'@eid': '242', '@shape': 'quad4', '@nodes': '252 279 280 253'}},
#  {'@name': 'Component243',
#   '@color': '-6710887',
#   '@material': 'Material243',
#   'elem': {'@eid': '243', '@shape': 'quad4', '@nodes': '253 280 281 254'}},
#  {'@name': 'Component244',
#   '@color': '-6710887',
#   '@material': 'Material244',
#   'elem': {'@eid': '244', '@shape': 'quad4', '@nodes': '254 281 282 255'}},
#  {'@name': 'Component245',
#   '@color': '-6710887',
#   '@material': 'Material245',
#   'elem': {'@eid': '245', '@shape': 'quad4', '@nodes': '255 282 283 256'}},
#  {'@name': 'Component246',
#   '@color': '-6710887',
#   '@material': 'Material246',
#   'elem': {'@eid': '246', '@shape': 'quad4', '@nodes': '256 283 284 257'}},
#  {'@name': 'Component247',
#   '@color': '-6710887',
#   '@material': 'Material247',
#   'elem': {'@eid': '247', '@shape': 'quad4', '@nodes': '257 284 285 258'}},
#  {'@name': 'Component248',
#   '@color': '-6710887',
#   '@material': 'Material248',
#   'elem': {'@eid': '248', '@shape': 'quad4', '@nodes': '258 285 286 259'}},
#  {'@name': 'Component249',
#   '@color': '-6710887',
#   '@material': 'Material249',
#   'elem': {'@eid': '249', '@shape': 'quad4', '@nodes': '259 286 287 260'}},
#  {'@name': 'Component250',
#   '@color': '-6710887',
#   '@material': 'Material250',
#   'elem': {'@eid': '250', '@shape': 'quad4', '@nodes': '260 287 288 261'}},
#  {'@name': 'Component251',
#   '@color': '-6710887',
#   '@material': 'Material251',
#   'elem': {'@eid': '251', '@shape': 'quad4', '@nodes': '261 288 289 262'}},
#  {'@name': 'Component252',
#   '@color': '-6710887',
#   '@material': 'Material252',
#   'elem': {'@eid': '252', '@shape': 'quad4', '@nodes': '262 289 290 263'}},
#  {'@name': 'Component253',
#   '@color': '-6710887',
#   '@material': 'Material253',
#   'elem': {'@eid': '253', '@shape': 'quad4', '@nodes': '263 290 291 264'}},
#  {'@name': 'Component254',
#   '@color': '-6710887',
#   '@material': 'Material254',
#   'elem': {'@eid': '254', '@shape': 'quad4', '@nodes': '264 291 292 265'}},
#  {'@name': 'Component255',
#   '@color': '-6710887',
#   '@material': 'Material255',
#   'elem': {'@eid': '255', '@shape': 'quad4', '@nodes': '265 292 293 266'}},
#  {'@name': 'Component256',
#   '@color': '-6710887',
#   '@material': 'Material256',
#   'elem': {'@eid': '256', '@shape': 'quad4', '@nodes': '266 293 294 267'}},
#  {'@name': 'Component257',
#   '@color': '-6710887',
#   '@material': 'Material257',
#   'elem': {'@eid': '257', '@shape': 'quad4', '@nodes': '267 294 295 268'}},
#  {'@name': 'Component258',
#   '@color': '-6710887',
#   '@material': 'Material258',
#   'elem': {'@eid': '258', '@shape': 'quad4', '@nodes': '268 295 296 269'}},
#  {'@name': 'Component259',
#   '@color': '-6710887',
#   '@material': 'Material259',
#   'elem': {'@eid': '259', '@shape': 'quad4', '@nodes': '269 296 297 270'}},
#  {'@name': 'Component260',
#   '@color': '-6710887',
#   '@material': 'Material260',
#   'elem': {'@eid': '260', '@shape': 'quad4', '@nodes': '270 297 298 271'}},
#  {'@name': 'Component261',
#   '@color': '-6710887',
#   '@material': 'Material261',
#   'elem': {'@eid': '261', '@shape': 'quad4', '@nodes': '271 298 299 272'}},
#  {'@name': 'Component262',
#   '@color': '-6710887',
#   '@material': 'Material262',
#   'elem': {'@eid': '262', '@shape': 'quad4', '@nodes': '273 300 301 274'}},
#  {'@name': 'Component263',
#   '@color': '-6710887',
#   '@material': 'Material263',
#   'elem': {'@eid': '263', '@shape': 'quad4', '@nodes': '274 301 302 275'}},
#  {'@name': 'Component264',
#   '@color': '-6710887',
#   '@material': 'Material264',
#   'elem': {'@eid': '264', '@shape': 'quad4', '@nodes': '275 302 303 276'}},
#  {'@name': 'Component265',
#   '@color': '-6710887',
#   '@material': 'Material265',
#   'elem': {'@eid': '265', '@shape': 'quad4', '@nodes': '276 303 304 277'}},
#  {'@name': 'Component266',
#   '@color': '-6710887',
#   '@material': 'Material266',
#   'elem': {'@eid': '266', '@shape': 'quad4', '@nodes': '277 304 305 278'}},
#  {'@name': 'Component267',
#   '@color': '-6710887',
#   '@material': 'Material267',
#   'elem': {'@eid': '267', '@shape': 'quad4', '@nodes': '278 305 306 279'}},
#  {'@name': 'Component268',
#   '@color': '-6710887',
#   '@material': 'Material268',
#   'elem': {'@eid': '268', '@shape': 'quad4', '@nodes': '279 306 307 280'}},
#  {'@name': 'Component269',
#   '@color': '-6710887',
#   '@material': 'Material269',
#   'elem': {'@eid': '269', '@shape': 'quad4', '@nodes': '280 307 308 281'}},
#  {'@name': 'Component270',
#   '@color': '-6710887',
#   '@material': 'Material270',
#   'elem': {'@eid': '270', '@shape': 'quad4', '@nodes': '281 308 309 282'}},
#  {'@name': 'Component271',
#   '@color': '-6710887',
#   '@material': 'Material271',
#   'elem': {'@eid': '271', '@shape': 'quad4', '@nodes': '282 309 310 283'}},
#  {'@name': 'Component272',
#   '@color': '-6710887',
#   '@material': 'Material272',
#   'elem': {'@eid': '272', '@shape': 'quad4', '@nodes': '283 310 311 284'}},
#  {'@name': 'Component273',
#   '@color': '-6710887',
#   '@material': 'Material273',
#   'elem': {'@eid': '273', '@shape': 'quad4', '@nodes': '284 311 312 285'}},
#  {'@name': 'Component274',
#   '@color': '-6710887',
#   '@material': 'Material274',
#   'elem': {'@eid': '274', '@shape': 'quad4', '@nodes': '285 312 313 286'}},
#  {'@name': 'Component275',
#   '@color': '-6710887',
#   '@material': 'Material275',
#   'elem': {'@eid': '275', '@shape': 'quad4', '@nodes': '286 313 314 287'}},
#  {'@name': 'Component276',
#   '@color': '-6710887',
#   '@material': 'Material276',
#   'elem': {'@eid': '276', '@shape': 'quad4', '@nodes': '287 314 315 288'}},
#  {'@name': 'Component277',
#   '@color': '-6710887',
#   '@material': 'Material277',
#   'elem': {'@eid': '277', '@shape': 'quad4', '@nodes': '288 315 316 289'}},
#  {'@name': 'Component278',
#   '@color': '-6710887',
#   '@material': 'Material278',
#   'elem': {'@eid': '278', '@shape': 'quad4', '@nodes': '289 316 317 290'}},
#  {'@name': 'Component279',
#   '@color': '-6710887',
#   '@material': 'Material279',
#   'elem': {'@eid': '279', '@shape': 'quad4', '@nodes': '290 317 318 291'}},
#  {'@name': 'Component280',
#   '@color': '-6710887',
#   '@material': 'Material280',
#   'elem': {'@eid': '280', '@shape': 'quad4', '@nodes': '291 318 319 292'}},
#  {'@name': 'Component281',
#   '@color': '-6710887',
#   '@material': 'Material281',
#   'elem': {'@eid': '281', '@shape': 'quad4', '@nodes': '292 319 320 293'}},
#  {'@name': 'Component282',
#   '@color': '-6710887',
#   '@material': 'Material282',
#   'elem': {'@eid': '282', '@shape': 'quad4', '@nodes': '293 320 321 294'}},
#  {'@name': 'Component283',
#   '@color': '-6710887',
#   '@material': 'Material283',
#   'elem': {'@eid': '283', '@shape': 'quad4', '@nodes': '294 321 322 295'}},
#  {'@name': 'Component284',
#   '@color': '-6710887',
#   '@material': 'Material284',
#   'elem': {'@eid': '284', '@shape': 'quad4', '@nodes': '295 322 323 296'}},
#  {'@name': 'Component285',
#   '@color': '-6710887',
#   '@material': 'Material285',
#   'elem': {'@eid': '285', '@shape': 'quad4', '@nodes': '296 323 324 297'}},
#  {'@name': 'Component286',
#   '@color': '-6710887',
#   '@material': 'Material286',
#   'elem': {'@eid': '286', '@shape': 'quad4', '@nodes': '297 324 325 298'}},
#  {'@name': 'Component287',
#   '@color': '-6710887',
#   '@material': 'Material287',
#   'elem': {'@eid': '287', '@shape': 'quad4', '@nodes': '298 325 326 299'}},
#  {'@name': 'Component288',
#   '@color': '-6710887',
#   '@material': 'Material288',
#   'elem': {'@eid': '288', '@shape': 'quad4', '@nodes': '300 327 328 301'}},
#  {'@name': 'Component289',
#   '@color': '-6710887',
#   '@material': 'Material289',
#   'elem': {'@eid': '289', '@shape': 'quad4', '@nodes': '301 328 329 302'}},
#  {'@name': 'Component290',
#   '@color': '-6710887',
#   '@material': 'Material290',
#   'elem': {'@eid': '290', '@shape': 'quad4', '@nodes': '302 329 330 303'}},
#  {'@name': 'Component291',
#   '@color': '-6710887',
#   '@material': 'Material291',
#   'elem': {'@eid': '291', '@shape': 'quad4', '@nodes': '303 330 331 304'}},
#  {'@name': 'Component292',
#   '@color': '-6710887',
#   '@material': 'Material292',
#   'elem': {'@eid': '292', '@shape': 'quad4', '@nodes': '304 331 332 305'}},
#  {'@name': 'Component293',
#   '@color': '-6710887',
#   '@material': 'Material293',
#   'elem': {'@eid': '293', '@shape': 'quad4', '@nodes': '305 332 333 306'}},
#  {'@name': 'Component294',
#   '@color': '-6710887',
#   '@material': 'Material294',
#   'elem': {'@eid': '294', '@shape': 'quad4', '@nodes': '306 333 334 307'}},
#  {'@name': 'Component295',
#   '@color': '-6710887',
#   '@material': 'Material295',
#   'elem': {'@eid': '295', '@shape': 'quad4', '@nodes': '307 334 335 308'}},
#  {'@name': 'Component296',
#   '@color': '-6710887',
#   '@material': 'Material296',
#   'elem': {'@eid': '296', '@shape': 'quad4', '@nodes': '308 335 336 309'}},
#  {'@name': 'Component297',
#   '@color': '-6710887',
#   '@material': 'Material297',
#   'elem': {'@eid': '297', '@shape': 'quad4', '@nodes': '309 336 337 310'}},
#  {'@name': 'Component298',
#   '@color': '-6710887',
#   '@material': 'Material298',
#   'elem': {'@eid': '298', '@shape': 'quad4', '@nodes': '310 337 338 311'}},
#  {'@name': 'Component299',
#   '@color': '-6710887',
#   '@material': 'Material299',
#   'elem': {'@eid': '299', '@shape': 'quad4', '@nodes': '311 338 339 312'}},
#  {'@name': 'Component300',
#   '@color': '-6710887',
#   '@material': 'Material300',
#   'elem': {'@eid': '300', '@shape': 'quad4', '@nodes': '312 339 340 313'}},
#  {'@name': 'Component301',
#   '@color': '-6710887',
#   '@material': 'Material301',
#   'elem': {'@eid': '301', '@shape': 'quad4', '@nodes': '313 340 341 314'}},
#  {'@name': 'Component302',
#   '@color': '-6710887',
#   '@material': 'Material302',
#   'elem': {'@eid': '302', '@shape': 'quad4', '@nodes': '314 341 342 315'}},
#  {'@name': 'Component303',
#   '@color': '-6710887',
#   '@material': 'Material303',
#   'elem': {'@eid': '303', '@shape': 'quad4', '@nodes': '315 342 343 316'}},
#  {'@name': 'Component304',
#   '@color': '-6710887',
#   '@material': 'Material304',
#   'elem': {'@eid': '304', '@shape': 'quad4', '@nodes': '316 343 344 317'}},
#  {'@name': 'Component305',
#   '@color': '-6710887',
#   '@material': 'Material305',
#   'elem': {'@eid': '305', '@shape': 'quad4', '@nodes': '317 344 345 318'}},
#  {'@name': 'Component306',
#   '@color': '-6710887',
#   '@material': 'Material306',
#   'elem': {'@eid': '306', '@shape': 'quad4', '@nodes': '318 345 346 319'}},
#  {'@name': 'Component307',
#   '@color': '-6710887',
#   '@material': 'Material307',
#   'elem': {'@eid': '307', '@shape': 'quad4', '@nodes': '319 346 347 320'}},
#  {'@name': 'Component308',
#   '@color': '-6710887',
#   '@material': 'Material308',
#   'elem': {'@eid': '308', '@shape': 'quad4', '@nodes': '320 347 348 321'}},
#  {'@name': 'Component309',
#   '@color': '-6710887',
#   '@material': 'Material309',
#   'elem': {'@eid': '309', '@shape': 'quad4', '@nodes': '321 348 349 322'}},
#  {'@name': 'Component310',
#   '@color': '-6710887',
# ...
#   'elem': {'@eid': '899', '@shape': 'quad4', '@nodes': '934 961 962 935'}},
#  {'@name': 'Component900',
#   '@color': '-6710887',
#   '@material': 'Material900',
#   'elem': {'@eid': '900', '@shape': 'quad4', '@nodes': '935 962 963 936'}},
#  {'@name': 'Component901',
#   '@color': '-6710887',
#   '@material': 'Material901',
#   'elem': {'@eid': '901', '@shape': 'quad4', '@nodes': '936 963 964 937'}},
#  {'@name': 'Component902',
#   '@color': '-6710887',
#   '@material': 'Material902',
#   'elem': {'@eid': '902', '@shape': 'quad4', '@nodes': '937 964 965 938'}},
#  {'@name': 'Component903',
#   '@color': '-6710887',
#   '@material': 'Material903',
#   'elem': {'@eid': '903', '@shape': 'quad4', '@nodes': '938 965 966 939'}},
#  {'@name': 'Component904',
#   '@color': '-6710887',
#   '@material': 'Material904',
#   'elem': {'@eid': '904', '@shape': 'quad4', '@nodes': '939 966 967 940'}},
#  {'@name': 'Component905',
#   '@color': '-6710887',
#   '@material': 'Material905',
#   'elem': {'@eid': '905', '@shape': 'quad4', '@nodes': '940 967 968 941'}},
#  {'@name': 'Component906',
#   '@color': '-6710887',
#   '@material': 'Material906',
#   'elem': {'@eid': '906', '@shape': 'quad4', '@nodes': '941 968 969 942'}},
#  {'@name': 'Component907',
#   '@color': '-6710887',
#   '@material': 'Material907',
#   'elem': {'@eid': '907', '@shape': 'quad4', '@nodes': '942 969 970 943'}},
#  {'@name': 'Component908',
#   '@color': '-6710887',
#   '@material': 'Material908',
#   'elem': {'@eid': '908', '@shape': 'quad4', '@nodes': '943 970 971 944'}},
#  {'@name': 'Component909',
#   '@color': '-6710887',
#   '@material': 'Material909',
#   'elem': {'@eid': '909', '@shape': 'quad4', '@nodes': '944 971 972 945'}},
#  {'@name': 'Component910',
#   '@color': '-6710887',
#   '@material': 'Material910',
#   'elem': {'@eid': '910', '@shape': 'quad4', '@nodes': '945 972 973 946'}},
#  {'@name': 'Component911',
#   '@color': '-6710887',
#   '@material': 'Material911',
#   'elem': {'@eid': '911', '@shape': 'quad4', '@nodes': '946 973 974 947'}},
#  {'@name': 'Component912',
#   '@color': '-6710887',
#   '@material': 'Material912',
#   'elem': {'@eid': '912', '@shape': 'quad4', '@nodes': '948 975 976 949'}},
#  {'@name': 'Component913',
#   '@color': '-6710887',
#   '@material': 'Material913',
#   'elem': {'@eid': '913', '@shape': 'quad4', '@nodes': '949 976 977 950'}},
#  {'@name': 'Component914',
#   '@color': '-6710887',
#   '@material': 'Material914',
#   'elem': {'@eid': '914', '@shape': 'quad4', '@nodes': '950 977 978 951'}},
#  {'@name': 'Component915',
#   '@color': '-6710887',
#   '@material': 'Material915',
#   'elem': {'@eid': '915', '@shape': 'quad4', '@nodes': '951 978 979 952'}},
#  {'@name': 'Component916',
#   '@color': '-6710887',
#   '@material': 'Material916',
#   'elem': {'@eid': '916', '@shape': 'quad4', '@nodes': '952 979 980 953'}},
#  {'@name': 'Component917',
#   '@color': '-6710887',
#   '@material': 'Material917',
#   'elem': {'@eid': '917', '@shape': 'quad4', '@nodes': '953 980 981 954'}},
#  {'@name': 'Component918',
#   '@color': '-6710887',
#   '@material': 'Material918',
#   'elem': {'@eid': '918', '@shape': 'quad4', '@nodes': '954 981 982 955'}},
#  {'@name': 'Component919',
#   '@color': '-6710887',
#   '@material': 'Material919',
#   'elem': {'@eid': '919', '@shape': 'quad4', '@nodes': '955 982 983 956'}},
#  {'@name': 'Component920',
#   '@color': '-6710887',
#   '@material': 'Material920',
#   'elem': {'@eid': '920', '@shape': 'quad4', '@nodes': '956 983 984 957'}},
#  {'@name': 'Component921',
#   '@color': '-6710887',
#   '@material': 'Material921',
#   'elem': {'@eid': '921', '@shape': 'quad4', '@nodes': '957 984 985 958'}},
#  {'@name': 'Component922',
#   '@color': '-6710887',
#   '@material': 'Material922',
#   'elem': {'@eid': '922', '@shape': 'quad4', '@nodes': '958 985 986 959'}},
#  {'@name': 'Component923',
#   '@color': '-6710887',
#   '@material': 'Material923',
#   'elem': {'@eid': '923', '@shape': 'quad4', '@nodes': '959 986 987 960'}},
#  {'@name': 'Component924',
#   '@color': '-6710887',
#   '@material': 'Material924',
#   'elem': {'@eid': '924', '@shape': 'quad4', '@nodes': '960 987 988 961'}},
#  {'@name': 'Component925',
#   '@color': '-6710887',
#   '@material': 'Material925',
#   'elem': {'@eid': '925', '@shape': 'quad4', '@nodes': '961 988 989 962'}},
#  {'@name': 'Component926',
#   '@color': '-6710887',
#   '@material': 'Material926',
#   'elem': {'@eid': '926', '@shape': 'quad4', '@nodes': '962 989 990 963'}},
#  {'@name': 'Component927',
#   '@color': '-6710887',
#   '@material': 'Material927',
#   'elem': {'@eid': '927', '@shape': 'quad4', '@nodes': '963 990 991 964'}},
#  {'@name': 'Component928',
#   '@color': '-6710887',
#   '@material': 'Material928',
#   'elem': {'@eid': '928', '@shape': 'quad4', '@nodes': '964 991 992 965'}},
#  {'@name': 'Component929',
#   '@color': '-6710887',
#   '@material': 'Material929',
#   'elem': {'@eid': '929', '@shape': 'quad4', '@nodes': '965 992 993 966'}},
#  {'@name': 'Component930',
#   '@color': '-6710887',
#   '@material': 'Material930',
#   'elem': {'@eid': '930', '@shape': 'quad4', '@nodes': '966 993 994 967'}},
#  {'@name': 'Component931',
#   '@color': '-6710887',
#   '@material': 'Material931',
#   'elem': {'@eid': '931', '@shape': 'quad4', '@nodes': '967 994 995 968'}},
#  {'@name': 'Component932',
#   '@color': '-6710887',
#   '@material': 'Material932',
#   'elem': {'@eid': '932', '@shape': 'quad4', '@nodes': '968 995 996 969'}},
#  {'@name': 'Component933',
#   '@color': '-6710887',
#   '@material': 'Material933',
#   'elem': {'@eid': '933', '@shape': 'quad4', '@nodes': '969 996 997 970'}},
#  {'@name': 'Component934',
#   '@color': '-6710887',
#   '@material': 'Material934',
#   'elem': {'@eid': '934', '@shape': 'quad4', '@nodes': '970 997 998 971'}},
#  {'@name': 'Component935',
#   '@color': '-6710887',
#   '@material': 'Material935',
#   'elem': {'@eid': '935', '@shape': 'quad4', '@nodes': '971 998 999 972'}},
#  {'@name': 'Component936',
#   '@color': '-6710887',
#   '@material': 'Material936',
#   'elem': {'@eid': '936', '@shape': 'quad4', '@nodes': '972 999 1000 973'}},
#  {'@name': 'Component937',
#   '@color': '-6710887',
#   '@material': 'Material937',
#   'elem': {'@eid': '937', '@shape': 'quad4', '@nodes': '973 1000 1001 974'}},
#  {'@name': 'Component938',
#   '@color': '-6710887',
#   '@material': 'Material938',
#   'elem': {'@eid': '938', '@shape': 'quad4', '@nodes': '975 1002 1003 976'}},
#  {'@name': 'Component939',
#   '@color': '-6710887',
#   '@material': 'Material939',
#   'elem': {'@eid': '939', '@shape': 'quad4', '@nodes': '976 1003 1004 977'}},
#  {'@name': 'Component940',
#   '@color': '-6710887',
#   '@material': 'Material940',
#   'elem': {'@eid': '940', '@shape': 'quad4', '@nodes': '977 1004 1005 978'}},
#  {'@name': 'Component941',
#   '@color': '-6710887',
#   '@material': 'Material941',
#   'elem': {'@eid': '941', '@shape': 'quad4', '@nodes': '978 1005 1006 979'}},
#  {'@name': 'Component942',
#   '@color': '-6710887',
#   '@material': 'Material942',
#   'elem': {'@eid': '942', '@shape': 'quad4', '@nodes': '979 1006 1007 980'}},
#  {'@name': 'Component943',
#   '@color': '-6710887',
#   '@material': 'Material943',
#   'elem': {'@eid': '943', '@shape': 'quad4', '@nodes': '980 1007 1008 981'}},
#  {'@name': 'Component944',
#   '@color': '-6710887',
#   '@material': 'Material944',
#   'elem': {'@eid': '944', '@shape': 'quad4', '@nodes': '981 1008 1009 982'}},
#  {'@name': 'Component945',
#   '@color': '-6710887',
#   '@material': 'Material945',
#   'elem': {'@eid': '945', '@shape': 'quad4', '@nodes': '982 1009 1010 983'}},
#  {'@name': 'Component946',
#   '@color': '-6710887',
#   '@material': 'Material946',
#   'elem': {'@eid': '946', '@shape': 'quad4', '@nodes': '983 1010 1011 984'}},
#  {'@name': 'Component947',
#   '@color': '-6710887',
#   '@material': 'Material947',
#   'elem': {'@eid': '947', '@shape': 'quad4', '@nodes': '984 1011 1012 985'}},
#  {'@name': 'Component948',
#   '@color': '-6710887',
#   '@material': 'Material948',
#   'elem': {'@eid': '948', '@shape': 'quad4', '@nodes': '985 1012 1013 986'}},
#  {'@name': 'Component949',
#   '@color': '-6710887',
#   '@material': 'Material949',
#   'elem': {'@eid': '949', '@shape': 'quad4', '@nodes': '986 1013 1014 987'}},
#  {'@name': 'Component950',
#   '@color': '-6710887',
#   '@material': 'Material950',
#   'elem': {'@eid': '950', '@shape': 'quad4', '@nodes': '987 1014 1015 988'}},
#  {'@name': 'Component951',
#   '@color': '-6710887',
#   '@material': 'Material951',
#   'elem': {'@eid': '951', '@shape': 'quad4', '@nodes': '988 1015 1016 989'}},
#  {'@name': 'Component952',
#   '@color': '-6710887',
#   '@material': 'Material952',
#   'elem': {'@eid': '952', '@shape': 'quad4', '@nodes': '989 1016 1017 990'}},
#  {'@name': 'Component953',
#   '@color': '-6710887',
#   '@material': 'Material953',
#   'elem': {'@eid': '953', '@shape': 'quad4', '@nodes': '990 1017 1018 991'}},
#  {'@name': 'Component954',
#   '@color': '-6710887',
#   '@material': 'Material954',
#   'elem': {'@eid': '954', '@shape': 'quad4', '@nodes': '991 1018 1019 992'}},
#  {'@name': 'Component955',
#   '@color': '-6710887',
#   '@material': 'Material955',
#   'elem': {'@eid': '955', '@shape': 'quad4', '@nodes': '992 1019 1020 993'}},
#  {'@name': 'Component956',
#   '@color': '-6710887',
#   '@material': 'Material956',
#   'elem': {'@eid': '956', '@shape': 'quad4', '@nodes': '993 1020 1021 994'}},
#  {'@name': 'Component957',
#   '@color': '-6710887',
#   '@material': 'Material957',
#   'elem': {'@eid': '957', '@shape': 'quad4', '@nodes': '994 1021 1022 995'}},
#  {'@name': 'Component958',
#   '@color': '-6710887',
#   '@material': 'Material958',
#   'elem': {'@eid': '958', '@shape': 'quad4', '@nodes': '995 1022 1023 996'}},
#  {'@name': 'Component959',
#   '@color': '-6710887',
#   '@material': 'Material959',
#   'elem': {'@eid': '959', '@shape': 'quad4', '@nodes': '996 1023 1024 997'}},
#  {'@name': 'Component960',
#   '@color': '-6710887',
#   '@material': 'Material960',
#   'elem': {'@eid': '960', '@shape': 'quad4', '@nodes': '997 1024 1025 998'}},
#  {'@name': 'Component961',
#   '@color': '-6710887',
#   '@material': 'Material961',
#   'elem': {'@eid': '961', '@shape': 'quad4', '@nodes': '998 1025 1026 999'}},
#  {'@name': 'Component962',
#   '@color': '-6710887',
#   '@material': 'Material962',
#   'elem': {'@eid': '962', '@shape': 'quad4', '@nodes': '999 1026 1027 1000'}},
#  {'@name': 'Component963',
#   '@color': '-6710887',
#   '@material': 'Material963',
#   'elem': {'@eid': '963', '@shape': 'quad4', '@nodes': '1000 1027 1028 1001'}},
#  {'@name': 'Component964',
#   '@color': '-6710887',
#   '@material': 'Material964',
#   'elem': {'@eid': '964', '@shape': 'quad4', '@nodes': '1002 1029 1030 1003'}},
#  {'@name': 'Component965',
#   '@color': '-6710887',
#   '@material': 'Material965',
#   'elem': {'@eid': '965', '@shape': 'quad4', '@nodes': '1003 1030 1031 1004'}},
#  {'@name': 'Component966',
#   '@color': '-6710887',
#   '@material': 'Material966',
#   'elem': {'@eid': '966', '@shape': 'quad4', '@nodes': '1004 1031 1032 1005'}},
#  {'@name': 'Component967',
#   '@color': '-6710887',
#   '@material': 'Material967',
#   'elem': {'@eid': '967', '@shape': 'quad4', '@nodes': '1005 1032 1033 1006'}},
#  {'@name': 'Component968',
#   '@color': '-6710887',
#   '@material': 'Material968',
#   'elem': {'@eid': '968', '@shape': 'quad4', '@nodes': '1006 1033 1034 1007'}},
#  {'@name': 'Component969',
#   '@color': '-6710887',
#   '@material': 'Material969',
#   'elem': {'@eid': '969', '@shape': 'quad4', '@nodes': '1007 1034 1035 1008'}},
#  {'@name': 'Component970',
#   '@color': '-6710887',
#   '@material': 'Material970',
#   'elem': {'@eid': '970', '@shape': 'quad4', '@nodes': '1008 1035 1036 1009'}},
#  {'@name': 'Component971',
#   '@color': '-6710887',
#   '@material': 'Material971',
#   'elem': {'@eid': '971', '@shape': 'quad4', '@nodes': '1009 1036 1037 1010'}},
#  {'@name': 'Component972',
#   '@color': '-6710887',
#   '@material': 'Material972',
#   'elem': {'@eid': '972', '@shape': 'quad4', '@nodes': '1010 1037 1038 1011'}},
#  {'@name': 'Component973',
#   '@color': '-6710887',
#   '@material': 'Material973',
#   'elem': {'@eid': '973', '@shape': 'quad4', '@nodes': '1011 1038 1039 1012'}},
#  {'@name': 'Component974',
#   '@color': '-6710887',
#   '@material': 'Material974',
#   'elem': {'@eid': '974', '@shape': 'quad4', '@nodes': '1012 1039 1040 1013'}},
#  {'@name': 'Component975',
#   '@color': '-6710887',
#   '@material': 'Material975',
#   'elem': {'@eid': '975', '@shape': 'quad4', '@nodes': '1013 1040 1041 1014'}},
#  {'@name': 'Component976',
#   '@color': '-6710887',
#   '@material': 'Material976',
#   'elem': {'@eid': '976', '@shape': 'quad4', '@nodes': '1014 1041 1042 1015'}},
#  {'@name': 'Component977',
#   '@color': '-6710887',
#   '@material': 'Material977',
#   'elem': {'@eid': '977', '@shape': 'quad4', '@nodes': '1015 1042 1043 1016'}},
#  {'@name': 'Component978',
#   '@color': '-6710887',
#   '@material': 'Material978',
#   'elem': {'@eid': '978', '@shape': 'quad4', '@nodes': '1016 1043 1044 1017'}},
#  {'@name': 'Component979',
#   '@color': '-6710887',
#   '@material': 'Material979',
#   'elem': {'@eid': '979', '@shape': 'quad4', '@nodes': '1017 1044 1045 1018'}},
#  {'@name': 'Component980',
#   '@color': '-6710887',
#   '@material': 'Material980',
#   'elem': {'@eid': '980', '@shape': 'quad4', '@nodes': '1018 1045 1046 1019'}},
#  {'@name': 'Component981',
#   '@color': '-6710887',
#   '@material': 'Material981',
#   'elem': {'@eid': '981', '@shape': 'quad4', '@nodes': '1019 1046 1047 1020'}},
#  {'@name': 'Component982',
#   '@color': '-6710887',
#   '@material': 'Material982',
#   'elem': {'@eid': '982', '@shape': 'quad4', '@nodes': '1020 1047 1048 1021'}},
#  {'@name': 'Component983',
#   '@color': '-6710887',
#   '@material': 'Material983',
#   'elem': {'@eid': '983', '@shape': 'quad4', '@nodes': '1021 1048 1049 1022'}},
#  {'@name': 'Component984',
#   '@color': '-6710887',
#   '@material': 'Material984',
#   'elem': {'@eid': '984', '@shape': 'quad4', '@nodes': '1022 1049 1050 1023'}},
#  {'@name': 'Component985',
#   '@color': '-6710887',
#   '@material': 'Material985',
#   'elem': {'@eid': '985', '@shape': 'quad4', '@nodes': '1023 1050 1051 1024'}},
#  {'@name': 'Component986',
#   '@color': '-6710887',
#   '@material': 'Material986',
#   'elem': {'@eid': '986', '@shape': 'quad4', '@nodes': '1024 1051 1052 1025'}},
#  {'@name': 'Component987',
#   '@color': '-6710887',
#   '@material': 'Material987',
#   'elem': {'@eid': '987', '@shape': 'quad4', '@nodes': '1025 1052 1053 1026'}},
#  {'@name': 'Component988',
#   '@color': '-6710887',
#   '@material': 'Material988',
#   'elem': {'@eid': '988', '@shape': 'quad4', '@nodes': '1026 1053 1054 1027'}},
#  {'@name': 'Component989',
#   '@color': '-6710887',
#   '@material': 'Material989',
#   'elem': {'@eid': '989', '@shape': 'quad4', '@nodes': '1027 1054 1055 1028'}},
#  {'@name': 'Component990',
#   '@color': '-6710887',
#   '@material': 'Material990',
#   'elem': {'@eid': '990', '@shape': 'quad4', '@nodes': '1029 1056 1057 1030'}},
#  {'@name': 'Component991',
#   '@color': '-6710887',
#   '@material': 'Material991',
#   'elem': {'@eid': '991', '@shape': 'quad4', '@nodes': '1030 1057 1058 1031'}},
#  {'@name': 'Component992',
#   '@color': '-6710887',
#   '@material': 'Material992',
#   'elem': {'@eid': '992', '@shape': 'quad4', '@nodes': '1031 1058 1059 1032'}},
#  {'@name': 'Component993',
#   '@color': '-6710887',
#   '@material': 'Material993',
#   'elem': {'@eid': '993', '@shape': 'quad4', '@nodes': '1032 1059 1060 1033'}},
#  {'@name': 'Component994',
#   '@color': '-6710887',
#   '@material': 'Material994',
#   'elem': {'@eid': '994', '@shape': 'quad4', '@nodes': '1033 1060 1061 1034'}},
#  {'@name': 'Component995',
#   '@color': '-6710887',
#   '@material': 'Material995',
#   'elem': {'@eid': '995', '@shape': 'quad4', '@nodes': '1034 1061 1062 1035'}},
#  {'@name': 'Component996',
#   '@color': '-6710887',
#   '@material': 'Material996',
#   'elem': {'@eid': '996', '@shape': 'quad4', '@nodes': '1035 1062 1063 1036'}},
#  {'@name': 'Component997',
#   '@color': '-6710887',
#   '@material': 'Material997',
#   'elem': {'@eid': '997', '@shape': 'quad4', '@nodes': '1036 1063 1064 1037'}},
#  {'@name': 'Component998',
#   '@color': '-6710887',
#   '@material': 'Material998',
#   'elem': {'@eid': '998', '@shape': 'quad4', '@nodes': '1037 1064 1065 1038'}},
#  {'@name': 'Component999',
#   '@color': '-6710887',
#   '@material': 'Material999',
#   'elem': {'@eid': '999', '@shape': 'quad4', '@nodes': '1038 1065 1066 1039'}},
#  ...]

# %%
# FEMの結果を変数に格納
elems = my_dict['liml8']['elset']['elem'] #elements
nodes = my_dict['liml8']['node'] #nodes
result_elems = my_dict['liml8']['solution']['results']['elem']
ne = len(elems)
sigmas = np.zeros((ne,3))
rhos = np.ones(ne) * a
Es = np.zeros(ne)
vs = np.zeros(ne)
cxs = np.zeros(ne)
cys = np.zeros(ne)
# Load stress from each element
lambda_tmp = 0
for i in range(ne):
    Es[i] = rhos[i]**n * E0
    sigma_x = np.array(list(map(lambda x: x['@stressxx'], result_elems[i]['localnode'])),dtype=np.double).sum()
    sigma_y = np.array(list(map(lambda x: x['@stressyy'], result_elems[i]['localnode'])),dtype=np.double).sum()
    tau_xy = np.array(list(map(lambda x: x['@stressxy'], result_elems[i]['localnode'])),dtype=np.double).sum()
    sigmas[i] = np.array([sigma_x,sigma_y,tau_xy])
    lambda_tmp += np.dot(nu*sigmas[i], sigmas[i].transpose())/(rhos[i]**n)
    node_ids = elems[i]['@nodes'].split(' ')
    vertices = np.zeros((4, 2))
    n_nodes_in_elems = len(node_ids)
    for j in range(n_nodes_in_elems):
        (x,y) = findXY(node_ids[j])
        vertices[j, :] = (x,y)
    vs[i] = shoelace_area(vertices)
    cxs[i] = vertices[:,0].sum() / n_nodes_in_elems 
    cys[i] = vertices[:,1].sum() / n_nodes_in_elems 

# トータルの体積V0
V0 = vs.sum()  
# lambda_barはlmbdaの初期値
lambda_bar = -1/ne*(n-1)/E0 * lambda_tmp     
lmbda = lambda_bar
dlambda = 0.1 * lambda_bar
drho = 0.05
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 2
#       1 # FEMの結果を変数に格納
# ----> 2 elems = my_dict['liml8']['elset']['elem'] #elements
#       3 nodes = my_dict['liml8']['node'] #nodes
#       4 result_elems = my_dict['liml8']['solution']['results']['elem']
#
# TypeError: list indices must be integers or slices, not str

# %%
tolerance = 0.01 
g_prev = 0
for i in range(ne):
    print(str(i)+'th element')
    lmbda = lambda_bar
    while True:
        # λにしたがってρiを計算する
        rhos[i] = calc_rho_i(lmbda, sigmas[i])
        D, rhos[i] = update_D_and_rho_i(rhos[i], lmbda, sigmas[i])
        if check_if_all_rhos_are_settled(rhos): 
            print("***All rhos are settled.***")
            break 
        g = calc_g(rhos)
        lmbda = update_lambda(g, lmbda)
        if g==g_prev: #gに変化が見られない場合、λの最適解と判定、
            print("  No change in g.")
            break
        if abs(g/V0) < tolerance: #gが0に近づいたらλの最適解と判定
            print("  g is almost zero")
            break
        if g*g_prev< 0: #gの符号が変わったらラムダの最適解と判定
            print("  Sign of g changed.")
            break
        g_prev = g
    print(f"  g/V0: {g/V0}, λ:{lmbda}")

# %%
Ei = rhos**n * E0
[X,Y] = np.meshgrid(np.linspace(min(cxs),max(cxs),100),np.linspace(min(cys),max(cys),100))
points = np.concatenate((cxs[:, np.newaxis] , cys[:, np.newaxis]), axis=1)
Z = griddata(points,Ei,(X,Y))
fig, ax = plt.subplots() 
plt.axis('off')
img = ax.imshow(Z, extent=[0, 1, 0, 1])
img.set_cmap('gray')

# %%
# 第２世代のサンプル確認用
# data2 = 'liml/beam1_opti_2.liml'
# with open(data2,  'r', encoding='utf-8') as file:
#     my_xml2 = file.read()
# my_dict2 = xmltodict.parse(my_xml2)
# len(my_dict2['liml8']['mat'])

# %%
# マテリアルの情報を更新する
mat_base = my_dict['liml8']['mat'].copy()
id_base = mat_base['@mid']
name_base = mat_base['@name']
geo_base = mat_base['geometric']
mech_base = mat_base['mechanical'] 
mat_new = [mat_base.copy()]
for i in range(ne):
    mat_dict = {}
    mat_dict['@mid'] = str(int(id_base) + i + 1)
    mat_dict['@name'] = name_base + str(int(id_base) + i)
    mat_dict['geometric'] = geo_base.copy()
    mat_dict['mechanical'] = mech_base.copy()
    # Update Young's modulus
    mat_dict['mechanical']['@youngsmodulus'] = "{:.0f}".format(Ei[i])
    mat_new.append(mat_dict)

# %%
# 要素のマテリアル情報を更新する
elem_base = my_dict['liml8']['elset'].copy()
elem_base.pop('elem', None) # Remove "elem" key

elem_list = my_dict['liml8']['elset']['elem'].copy() 
elset_new = [elem_base]
for i in range(ne):
    elem = elem_list[i]
    elem_dict = elem_base.copy() 
    elem_dict['elem'] = elem
    elem_dict['@name'] = 'Component'  + str (i + 1)
    elem_dict['@material'] = elem_base['@material'] + str(i + 1)
    elset_new.append(elem_dict)
print(elset_new)
# Out:
# [{'@name': 'Default', '@color': '-6710887', '@material': 'Material'}, {'@name': 'Component1', '@color': '-6710887', '@material': 'Material1', 'elem': {'@eid': '1', '@shape': 'quad4', '@nodes': '1243 1269 3 1244'}}, {'@name': 'Component2', '@color': '-6710887', '@material': 'Material2', 'elem': {'@eid': '2', '@shape': 'quad4', '@nodes': '1 30 31 5'}}, {'@name': 'Component3', '@color': '-6710887', '@material': 'Material3', 'elem': {'@eid': '3', '@shape': 'quad4', '@nodes': '5 31 32 6'}}, {'@name': 'Component4', '@color': '-6710887', '@material': 'Material4', 'elem': {'@eid': '4', '@shape': 'quad4', '@nodes': '6 32 33 7'}}, {'@name': 'Component5', '@color': '-6710887', '@material': 'Material5', 'elem': {'@eid': '5', '@shape': 'quad4', '@nodes': '7 33 34 8'}}, {'@name': 'Component6', '@color': '-6710887', '@material': 'Material6', 'elem': {'@eid': '6', '@shape': 'quad4', '@nodes': '8 34 35 9'}}, {'@name': 'Component7', '@color': '-6710887', '@material': 'Material7', 'elem': {'@eid': '7', '@shape': 'quad4', '@nodes': '9 35 36 10'}}, {'@name': 'Component8', '@color': '-6710887', '@material': 'Material8', 'elem': {'@eid': '8', '@shape': 'quad4', '@nodes': '10 36 37 11'}}, {'@name': 'Component9', '@color': '-6710887', '@material': 'Material9', 'elem': {'@eid': '9', '@shape': 'quad4', '@nodes': '11 37 38 12'}}, {'@name': 'Component10', '@color': '-6710887', '@material': 'Material10', 'elem': {'@eid': '10', '@shape': 'quad4', '@nodes': '12 38 39 13'}}, {'@name': 'Component11', '@color': '-6710887', '@material': 'Material11', 'elem': {'@eid': '11', '@shape': 'quad4', '@nodes': '13 39 40 14'}}, {'@name': 'Component12', '@color': '-6710887', '@material': 'Material12', 'elem': {'@eid': '12', '@shape': 'quad4', '@nodes': '14 40 41 15'}}, {'@name': 'Component13', '@color': '-6710887', '@material': 'Material13', 'elem': {'@eid': '13', '@shape': 'quad4', '@nodes': '15 41 42 16'}}, {'@name': 'Component14', '@color': '-6710887', '@material': 'Material14', 'elem': {'@eid': '14', '@shape': 'quad4', '@nodes': '16 42 43 17'}}, {'@name': 'Component15', '@color': '-6710887', '@material': 'Material15', 'elem': {'@eid': '15', '@shape': 'quad4', '@nodes': '17 43 44 18'}}, {'@name': 'Component16', '@color': '-6710887', '@material': 'Material16', 'elem': {'@eid': '16', '@shape': 'quad4', '@nodes': '18 44 45 19'}}, {'@name': 'Component17', '@color': '-6710887', '@material': 'Material17', 'elem': {'@eid': '17', '@shape': 'quad4', '@nodes': '19 45 46 20'}}, {'@name': 'Component18', '@color': '-6710887', '@material': 'Material18', 'elem': {'@eid': '18', '@shape': 'quad4', '@nodes': '20 46 47 21'}}, {'@name': 'Component19', '@color': '-6710887', '@material': 'Material19', 'elem': {'@eid': '19', '@shape': 'quad4', '@nodes': '21 47 48 22'}}, {'@name': 'Component20', '@color': '-6710887', '@material': 'Material20', 'elem': {'@eid': '20', '@shape': 'quad4', '@nodes': '22 48 49 23'}}, {'@name': 'Component21', '@color': '-6710887', '@material': 'Material21', 'elem': {'@eid': '21', '@shape': 'quad4', '@nodes': '23 49 50 24'}}, {'@name': 'Component22', '@color': '-6710887', '@material': 'Material22', 'elem': {'@eid': '22', '@shape': 'quad4', '@nodes': '24 50 51 25'}}, {'@name': 'Component23', '@color': '-6710887', '@material': 'Material23', 'elem': {'@eid': '23', '@shape': 'quad4', '@nodes': '25 51 52 26'}}, {'@name': 'Component24', '@color': '-6710887', '@material': 'Material24', 'elem': {'@eid': '24', '@shape': 'quad4', '@nodes': '26 52 53 27'}}, {'@name': 'Component25', '@color': '-6710887', '@material': 'Material25', 'elem': {'@eid': '25', '@shape': 'quad4', '@nodes': '27 53 54 28'}}, {'@name': 'Component26', '@color': '-6710887', '@material': 'Material26', 'elem': {'@eid': '26', '@shape': 'quad4', '@nodes': '28 54 55 29'}}, {'@name': 'Component27', '@color': '-6710887', '@material': 'Material27', 'elem': {'@eid': '27', '@shape': 'quad4', '@nodes': '29 55 56 4'}}, {'@name': 'Component28', '@color': '-6710887', '@material': 'Material28', 'elem': {'@eid': '28', '@shap ...

# %%
#結果の更新
my_dict_new = my_dict.copy()
my_dict_new['liml8']['elset'] = elset_new
my_dict_new['liml8']['mat'] = mat_new

liml = xmltodict.unparse(my_dict_new, pretty=True, full_document=False)
output_filename = 'output/gen2.liml'
fout = open(output_filename, 'w')
fout.write(liml)
fout.close()
