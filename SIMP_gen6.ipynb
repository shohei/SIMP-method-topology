# %%
BASE_FILENAME = 'gen6'

# %%
import xmltodict, json
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.interpolate import griddata

# %%
# 与えられたnode idから対応するX,Yの点を返す関数
def findXY(node_id):
    for node in nodes:
        if node['@nid'] == str(node_id):
            return (node['@x'], node['@y'])
            
# 4点から面積を計算する方法（靴紐の公式））
def shoelace_area(points):
    """
    計算順に並んだ4点の(x, y)座標リスト [(x1, y1), (x2, y2), (x3, y3), (x4, y4)] から面積を求める
    """
    n = len(points)
    area = 0
    for i in range(n):
        j = (i + 1) % n  # 次の点（最後の点は最初の点につなげる）
        area += points[i][0] * points[j][1] - points[i][1] * points[j][0]
    return abs(area) / 2

# ✅ 例: 4点を指定して計算
points = [(1, 1), (4, 1), (4, 5), (1, 5)]  # 長方形
# print(shoelace_area(points))  # 出力: 12.0

# %%
data = 'input/'+BASE_FILENAME+'.liml'

# %%
import xmltodict
import pprint

# Open the file and read the contents
with open(data,  'r', encoding='utf-8') as file:
    my_xml = file.read()

# Use xmltodict to parse and convert 
# the XML document
my_dict = xmltodict.parse(my_xml).copy()

# Print the dictionary
pprint.pprint(my_dict, indent=2)
# Out:
# { 'liml8': { 'analysis': {'@type': 'S20'},
#              'displacement': [ { '@axis': '1',
#                                  '@selection': 'Unnamed',
#                                  'value': '0'},
#                                { '@axis': '2',
#                                  '@selection': 'Unnamed(2)',
#                                  'value': '0'}],
#              'elset': [ { '@color': '-6710887',
#                           '@material': 'Material',
#                           '@name': 'Default'},
#                         { '@color': '-6710887',
#                           '@material': 'Material1',
#                           '@name': 'Component1',
#                           'elem': { '@eid': '1',
#                                     '@nodes': '1243 1269 3 1244',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material2',
#                           '@name': 'Component2',
#                           'elem': { '@eid': '2',
#                                     '@nodes': '1 30 31 5',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material3',
#                           '@name': 'Component3',
#                           'elem': { '@eid': '3',
#                                     '@nodes': '5 31 32 6',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material4',
#                           '@name': 'Component4',
#                           'elem': { '@eid': '4',
#                                     '@nodes': '6 32 33 7',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material5',
#                           '@name': 'Component5',
#                           'elem': { '@eid': '5',
#                                     '@nodes': '7 33 34 8',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material6',
#                           '@name': 'Component6',
#                           'elem': { '@eid': '6',
#                                     '@nodes': '8 34 35 9',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material7',
#                           '@name': 'Component7',
#                           'elem': { '@eid': '7',
#                                     '@nodes': '9 35 36 10',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material8',
#                           '@name': 'Component8',
#                           'elem': { '@eid': '8',
#                                     '@nodes': '10 36 37 11',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material9',
#                           '@name': 'Component9',
#                           'elem': { '@eid': '9',
#                                     '@nodes': '11 37 38 12',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material10',
#                           '@name': 'Component10',
#                           'elem': { '@eid': '10',
#                                     '@nodes': '12 38 39 13',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material11',
#                           '@name': 'Component11',
#                           'elem': { '@eid': '11',
#                                     '@nodes': '13 39 40 14',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material12',
#                           '@name': 'Component12',
#                           'elem': { '@eid': '12',
#                                     '@nodes': '14 40 41 15',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material13',
#                           '@name': 'Component13',
#                           'elem': { '@eid': '13',
#                                     '@nodes': '15 41 42 16',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material14',
#                           '@name': 'Component14',
#                           'elem': { '@eid': '14',
#                                     '@nodes': '16 42 43 17',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material15',
#                           '@name': 'Component15',
#                           'elem': { '@eid': '15',
#                                     '@nodes': '17 43 44 18',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material16',
#                           '@name': 'Component16',
#                           'elem': { '@eid': '16',
#                                     '@nodes': '18 44 45 19',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material17',
#                           '@name': 'Component17',
#                           'elem': { '@eid': '17',
#                                     '@nodes': '19 45 46 20',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material18',
#                           '@name': 'Component18',
#                           'elem': { '@eid': '18',
#                                     '@nodes': '20 46 47 21',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material19',
#                           '@name': 'Component19',
#                           'elem': { '@eid': '19',
#                                     '@nodes': '21 47 48 22',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material20',
#                           '@name': 'Component20',
#                           'elem': { '@eid': '20',
#                                     '@nodes': '22 48 49 23',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material21',
#                           '@name': 'Component21',
#                           'elem': { '@eid': '21',
#                                     '@nodes': '23 49 50 24',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material22',
#                           '@name': 'Component22',
#                           'elem': { '@eid': '22',
#                                     '@nodes': '24 50 51 25',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material23',
#                           '@name': 'Component23',
#                           'elem': { '@eid': '23',
#                                     '@nodes': '25 51 52 26',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material24',
#                           '@name': 'Component24',
#                           'elem': { '@eid': '24',
#                                     '@nodes': '26 52 53 27',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material25',
#                           '@name': 'Component25',
#                           'elem': { '@eid': '25',
#                                     '@nodes': '27 53 54 28',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material26',
#                           '@name': 'Component26',
#                           'elem': { '@eid': '26',
#                                     '@nodes': '28 54 55 29',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material27',
#                           '@name': 'Component27',
#                           'elem': { '@eid': '27',
#                                     '@nodes': '29 55 56 4',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material28',
#                           '@name': 'Component28',
#                           'elem': { '@eid': '28',
#                                     '@nodes': '30 57 58 31',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material29',
#                           '@name': 'Component29',
#                           'elem': { '@eid': '29',
#                                     '@nodes': '31 58 59 32',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material30',
#                           '@name': 'Component30',
#                           'elem': { '@eid': '30',
#                                     '@nodes': '32 59 60 33',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material31',
#                           '@name': 'Component31',
#                           'elem': { '@eid': '31',
#                                     '@nodes': '33 60 61 34',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material32',
#                           '@name': 'Component32',
#                           'elem': { '@eid': '32',
#                                     '@nodes': '34 61 62 35',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material33',
#                           '@name': 'Component33',
#                           'elem': { '@eid': '33',
#                                     '@nodes': '35 62 63 36',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material34',
#                           '@name': 'Component34',
#                           'elem': { '@eid': '34',
#                                     '@nodes': '36 63 64 37',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material35',
#                           '@name': 'Component35',
#                           'elem': { '@eid': '35',
#                                     '@nodes': '37 64 65 38',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material36',
#                           '@name': 'Component36',
#                           'elem': { '@eid': '36',
#                                     '@nodes': '38 65 66 39',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material37',
#                           '@name': 'Component37',
#                           'elem': { '@eid': '37',
#                                     '@nodes': '39 66 67 40',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material38',
#                           '@name': 'Component38',
#                           'elem': { '@eid': '38',
#                                     '@nodes': '40 67 68 41',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material39',
#                           '@name': 'Component39',
#                           'elem': { '@eid': '39',
#                                     '@nodes': '41 68 69 42',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material40',
#                           '@name': 'Component40',
#                           'elem': { '@eid': '40',
#                                     '@nodes': '42 69 70 43',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material41',
#                           '@name': 'Component41',
#                           'elem': { '@eid': '41',
#                                     '@nodes': '43 70 71 44',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material42',
#                           '@name': 'Component42',
#                           'elem': { '@eid': '42',
#                                     '@nodes': '44 71 72 45',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material43',
#                           '@name': 'Component43',
#                           'elem': { '@eid': '43',
#                                     '@nodes': '45 72 73 46',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material44',
#                           '@name': 'Component44',
#                           'elem': { '@eid': '44',
#                                     '@nodes': '46 73 74 47',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material45',
#                           '@name': 'Component45',
#                           'elem': { '@eid': '45',
#                                     '@nodes': '47 74 75 48',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material46',
#                           '@name': 'Component46',
#                           'elem': { '@eid': '46',
#                                     '@nodes': '48 75 76 49',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material47',
#                           '@name': 'Component47',
#                           'elem': { '@eid': '47',
#                                     '@nodes': '49 76 77 50',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material48',
#                           '@name': 'Component48',
#                           'elem': { '@eid': '48',
#                                     '@nodes': '50 77 78 51',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material49',
#                           '@name': 'Component49',
#                           'elem': { '@eid': '49',
#                                     '@nodes': '51 78 79 52',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material50',
#                           '@name': 'Component50',
#                           'elem': { '@eid': '50',
#                                     '@nodes': '52 79 80 53',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material51',
#                           '@name': 'Component51',
#                           'elem': { '@eid': '51',
#                                     '@nodes': '53 80 81 54',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material52',
#                           '@name': 'Component52',
#                           'elem': { '@eid': '52',
#                                     '@nodes': '54 81 82 55',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material53',
#                           '@name': 'Component53',
#                           'elem': { '@eid': '53',
#                                     '@nodes': '55 82 83 56',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material54',
#                           '@name': 'Component54',
#                           'elem': { '@eid': '54',
#                                     '@nodes': '57 84 85 58',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material55',
#                           '@name': 'Component55',
#                           'elem': { '@eid': '55',
#                                     '@nodes': '58 85 86 59',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material56',
#                           '@name': 'Component56',
#                           'elem': { '@eid': '56',
#                                     '@nodes': '59 86 87 60',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material57',
#                           '@name': 'Component57',
#                           'elem': { '@eid': '57',
#                                     '@nodes': '60 87 88 61',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material58',
#                           '@name': 'Component58',
#                           'elem': { '@eid': '58',
#                                     '@nodes': '61 88 89 62',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material59',
#                           '@name': 'Component59',
#                           'elem': { '@eid': '59',
#                                     '@nodes': '62 89 90 63',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material60',
#                           '@name': 'Component60',
#                           'elem': { '@eid': '60',
#                                     '@nodes': '63 90 91 64',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material61',
#                           '@name': 'Component61',
#                           'elem': { '@eid': '61',
#                                     '@nodes': '64 91 92 65',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material62',
#                           '@name': 'Component62',
#                           'elem': { '@eid': '62',
#                                     '@nodes': '65 92 93 66',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material63',
#                           '@name': 'Component63',
#                           'elem': { '@eid': '63',
#                                     '@nodes': '66 93 94 67',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material64',
#                           '@name': 'Component64',
#                           'elem': { '@eid': '64',
#                                     '@nodes': '67 94 95 68',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material65',
#                           '@name': 'Component65',
#                           'elem': { '@eid': '65',
#                                     '@nodes': '68 95 96 69',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material66',
#                           '@name': 'Component66',
#                           'elem': { '@eid': '66',
#                                     '@nodes': '69 96 97 70',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material67',
#                           '@name': 'Component67',
#                           'elem': { '@eid': '67',
#                                     '@nodes': '70 97 98 71',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material68',
#                           '@name': 'Component68',
#                           'elem': { '@eid': '68',
#                                     '@nodes': '71 98 99 72',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material69',
#                           '@name': 'Component69',
#                           'elem': { '@eid': '69',
#                                     '@nodes': '72 99 100 73',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material70',
#                           '@name': 'Component70',
#                           'elem': { '@eid': '70',
#                                     '@nodes': '73 100 101 74',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material71',
#                           '@name': 'Component71',
#                           'elem': { '@eid': '71',
#                                     '@nodes': '74 101 102 75',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material72',
#                           '@name': 'Component72',
#                           'elem': { '@eid': '72',
#                                     '@nodes': '75 102 103 76',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material73',
#                           '@name': 'Component73',
#                           'elem': { '@eid': '73',
#                                     '@nodes': '76 103 104 77',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material74',
#                           '@name': 'Component74',
#                           'elem': { '@eid': '74',
#                                     '@nodes': '77 104 105 78',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material75',
#                           '@name': 'Component75',
#                           'elem': { '@eid': '75',
#                                     '@nodes': '78 105 106 79',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material76',
#                           '@name': 'Component76',
#                           'elem': { '@eid': '76',
#                                     '@nodes': '79 106 107 80',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material77',
#                           '@name': 'Component77',
#                           'elem': { '@eid': '77',
#                                     '@nodes': '80 107 108 81',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material78',
#                           '@name': 'Component78',
#                           'elem': { '@eid': '78',
#                                     '@nodes': '81 108 109 82',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material79',
#                           '@name': 'Component79',
#                           'elem': { '@eid': '79',
#                                     '@nodes': '82 109 110 83',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material80',
#                           '@name': 'Component80',
#                           'elem': { '@eid': '80',
#                                     '@nodes': '84 111 112 85',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material81',
#                           '@name': 'Component81',
#                           'elem': { '@eid': '81',
#                                     '@nodes': '85 112 113 86',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material82',
#                           '@name': 'Component82',
#                           'elem': { '@eid': '82',
#                                     '@nodes': '86 113 114 87',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material83',
#                           '@name': 'Component83',
#                           'elem': { '@eid': '83',
#                                     '@nodes': '87 114 115 88',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material84',
#                           '@name': 'Component84',
#                           'elem': { '@eid': '84',
#                                     '@nodes': '88 115 116 89',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material85',
#                           '@name': 'Component85',
#                           'elem': { '@eid': '85',
#                                     '@nodes': '89 116 117 90',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material86',
#                           '@name': 'Component86',
#                           'elem': { '@eid': '86',
#                                     '@nodes': '90 117 118 91',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material87',
#                           '@name': 'Component87',
#                           'elem': { '@eid': '87',
#                                     '@nodes': '91 118 119 92',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material88',
#                           '@name': 'Component88',
#                           'elem': { '@eid': '88',
#                                     '@nodes': '92 119 120 93',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material89',
#                           '@name': 'Component89',
#                           'elem': { '@eid': '89',
#                                     '@nodes': '93 120 121 94',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material90',
#                           '@name': 'Component90',
#                           'elem': { '@eid': '90',
#                                     '@nodes': '94 121 122 95',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material91',
#                           '@name': 'Component91',
#                           'elem': { '@eid': '91',
#                                     '@nodes': '95 122 123 96',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material92',
#                           '@name': 'Component92',
#                           'elem': { '@eid': '92',
#                                     '@nodes': '96 123 124 97',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material93',
#                           '@name': 'Component93',
#                           'elem': { '@eid': '93',
#                                     '@nodes': '97 124 125 98',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material94',
#                           '@name': 'Component94',
#                           'elem': { '@eid': '94',
#                                     '@nodes': '98 125 126 99',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material95',
#                           '@name': 'Component95',
#                           'elem': { '@eid': '95',
#                                     '@nodes': '99 126 127 100',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material96',
#                           '@name': 'Component96',
#                           'elem': { '@eid': '96',
#                                     '@nodes': '100 127 128 101',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material97',
#                           '@name': 'Component97',
#                           'elem': { '@eid': '97',
#                                     '@nodes': '101 128 129 102',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material98',
#                           '@name': 'Component98',
#                           'elem': { '@eid': '98',
#                                     '@nodes': '102 129 130 103',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material99',
#                           '@name': 'Component99',
#                           'elem': { '@eid': '99',
#                                     '@nodes': '103 130 131 104',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material100',
#                           '@name': 'Component100',
#                           'elem': { '@eid': '100',
#                                     '@nodes': '104 131 132 105',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material101',
#                           '@name': 'Component101',
#                           'elem': { '@eid': '101',
#                                     '@nodes': '105 132 133 106',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material102',
#                           '@name': 'Component102',
#                           'elem': { '@eid': '102',
#                                     '@nodes': '106 133 134 107',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material103',
#                           '@name': 'Component103',
#                           'elem': { '@eid': '103',
#                                     '@nodes': '107 134 135 108',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material104',
#                           '@name': 'Component104',
#                           'elem': { '@eid': '104',
#                                     '@nodes': '108 135 136 109',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material105',
#                           '@name': 'Component105',
#                           'elem': { '@eid': '105',
#                                     '@nodes': '109 136 137 110',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material106',
#                           '@name': 'Component106',
#                           'elem': { '@eid': '106',
#                                     '@nodes': '111 138 139 112',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material107',
#                           '@name': 'Component107',
#                           'elem': { '@eid': '107',
#                                     '@nodes': '112 139 140 113',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material108',
#                           '@name': 'Component108',
#                           'elem': { '@eid': '108',
#                                     '@nodes': '113 140 141 114',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material109',
#                           '@name': 'Component109',
#                           'elem': { '@eid': '109',
#                                     '@nodes': '114 141 142 115',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material110',
#                           '@name': 'Component110',
#                           'elem': { '@eid': '110',
#                                     '@nodes': '115 142 143 116',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material111',
#                           '@name': 'Component111',
#                           'elem': { '@eid': '111',
#                                     '@nodes': '116 143 144 117',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material112',
#                           '@name': 'Component112',
#                           'elem': { '@eid': '112',
#                                     '@nodes': '117 144 145 118',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material113',
#                           '@name': 'Component113',
#                           'elem': { '@eid': '113',
#                                     '@nodes': '118 145 146 119',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material114',
#                           '@name': 'Component114',
#                           'elem': { '@eid': '114',
#                                     '@nodes': '119 146 147 120',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material115',
#                           '@name': 'Component115',
#                           'elem': { '@eid': '115',
#                                     '@nodes': '120 147 148 121',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material116',
#                           '@name': 'Component116',
#                           'elem': { '@eid': '116',
#                                     '@nodes': '121 148 149 122',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material117',
#                           '@name': 'Component117',
#                           'elem': { '@eid': '117',
#                                     '@nodes': '122 149 150 123',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material118',
#                           '@name': 'Component118',
#                           'elem': { '@eid': '118',
#                                     '@nodes': '123 150 151 124',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material119',
#                           '@name': 'Component119',
#                           'elem': { '@eid': '119',
#                                     '@nodes': '124 151 152 125',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material120',
#                           '@name': 'Component120',
#                           'elem': { '@eid': '120',
#                                     '@nodes': '125 152 153 126',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material121',
#                           '@name': 'Component121',
#                           'elem': { '@eid': '121',
#                                     '@nodes': '126 153 154 127',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material122',
#                           '@name': 'Component122',
#                           'elem': { '@eid': '122',
#                                     '@nodes': '127 154 155 128',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material123',
#                           '@name': 'Component123',
#                           'elem': { '@eid': '123',
#                                     '@nodes': '128 155 156 129',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material124',
#                           '@name': 'Component124',
#                           'elem': { '@eid': '124',
#                                     '@nodes': '129 156 157 130',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material125',
#                           '@name': 'Component125',
#                           'elem': { '@eid': '125',
#                                     '@nodes': '130 157 158 131',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material126',
#                           '@name': 'Component126',
#                           'elem': { '@eid': '126',
#                                     '@nodes': '131 158 159 132',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material127',
#                           '@name': 'Component127',
#                           'elem': { '@eid': '127',
#                                     '@nodes': '132 159 160 133',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material128',
#                           '@name': 'Component128',
#                           'elem': { '@eid': '128',
#                                     '@nodes': '133 160 161 134',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material129',
#                           '@name': 'Component129',
#                           'elem': { '@eid': '129',
#                                     '@nodes': '134 161 162 135',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material130',
#                           '@name': 'Component130',
#                           'elem': { '@eid': '130',
#                                     '@nodes': '135 162 163 136',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material131',
#                           '@name': 'Component131',
#                           'elem': { '@eid': '131',
#                                     '@nodes': '136 163 164 137',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material132',
#                           '@name': 'Component132',
#                           'elem': { '@eid': '132',
#                                     '@nodes': '138 165 166 139',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material133',
#                           '@name': 'Component133',
#                           'elem': { '@eid': '133',
#                                     '@nodes': '139 166 167 140',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material134',
#                           '@name': 'Component134',
#                           'elem': { '@eid': '134',
#                                     '@nodes': '140 167 168 141',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material135',
#                           '@name': 'Component135',
#                           'elem': { '@eid': '135',
#                                     '@nodes': '141 168 169 142',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material136',
#                           '@name': 'Component136',
#                           'elem': { '@eid': '136',
#                                     '@nodes': '142 169 170 143',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material137',
#                           '@name': 'Component137',
#                           'elem': { '@eid': '137',
#                                     '@nodes': '143 170 171 144',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material138',
#                           '@name': 'Component138',
#                           'elem': { '@eid': '138',
#                                     '@nodes': '144 171 172 145',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material139',
#                           '@name': 'Component139',
#                           'elem': { '@eid': '139',
#                                     '@nodes': '145 172 173 146',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material140',
#                           '@name': 'Component140',
#                           'elem': { '@eid': '140',
#                                     '@nodes': '146 173 174 147',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material141',
#                           '@name': 'Component141',
#                           'elem': { '@eid': '141',
#                                     '@nodes': '147 174 175 148',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material142',
#                           '@name': 'Component142',
#                           'elem': { '@eid': '142',
#                                     '@nodes': '148 175 176 149',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material143',
#                           '@name': 'Component143',
#                           'elem': { '@eid': '143',
#                                     '@nodes': '149 176 177 150',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material144',
#                           '@name': 'Component144',
#                           'elem': { '@eid': '144',
#                                     '@nodes': '150 177 178 151',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material145',
#                           '@name': 'Component145',
#                           'elem': { '@eid': '145',
#                                     '@nodes': '151 178 179 152',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material146',
#                           '@name': 'Component146',
#                           'elem': { '@eid': '146',
#                                     '@nodes': '152 179 180 153',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material147',
#                           '@name': 'Component147',
#                           'elem': { '@eid': '147',
#                                     '@nodes': '153 180 181 154',
#                                     '@shape': 'quad4'}},
#                         { '@color': '-6710887',
#                           '@material': 'Material148',
#                           '@name': 'Component148',
#                           'elem': { '@eid': '148',
# ...
#                                                                    { '@id': '3',
#                                                                      '@principal1': '0.298382484147131',
#                                                                      '@principal2': '-0.111732759864309',
#                                                                      '@stressxx': '0.187231304702227',
#                                                                      '@stressxy': '-0.182291547769536',
#                                                                      '@stressyy': '-0.000581580419404482',
#                                                                      '@tresca': '0.41011524401144',
#                                                                      '@vonmises': '0.367226653337738'},
#                                                                    { '@id': '4',
#                                                                      '@principal1': '0.346895863384871',
#                                                                      '@principal2': '-0.079173322201945',
#                                                                      '@stressxx': '0.205940416294558',
#                                                                      '@stressxy': '-0.200470283287487',
#                                                                      '@stressyy': '0.0617821248883675',
#                                                                      '@tresca': '0.426069185586816',
#                                                                      '@vonmises': '0.392517582974725'}]},
#                                                   { '@eid': '10',
#                                                     'localnode': [ { '@id': '1',
#                                                                      '@principal1': '0.874127937625161',
#                                                                      '@principal2': '-0.199505442861205',
#                                                                      '@stressxx': '0.518940380587659',
#                                                                      '@stressxy': '-0.5051564281434',
#                                                                      '@stressyy': '0.155682114176298',
#                                                                      '@tresca': '1.07363338048637',
#                                                                      '@vonmises': '0.989088142877732'},
#                                                                    { '@id': '2',
#                                                                      '@principal1': '0.759676476494767',
#                                                                      '@principal2': '-0.365518461343003',
#                                                                      '@stressxx': '0.454217808369461',
#                                                                      '@stressxy': '-0.50039539282489',
#                                                                      '@stressyy': '-0.0600597932176965',
#                                                                      '@tresca': '1.12519493783777',
#                                                                      '@vonmises': '0.994176981894522'},
#                                                                    { '@id': '3',
#                                                                      '@principal1': '0.839454755526366',
#                                                                      '@principal2': '-0.427418566933665',
#                                                                      '@stressxx': '0.467970249477874',
#                                                                      '@stressxy': '-0.576734836979686',
#                                                                      '@stressyy': '-0.0559340608851725',
#                                                                      '@tresca': '1.26687332246003',
#                                                                      '@vonmises': '1.11631960770569'},
#                                                                    { '@id': '4',
#                                                                      '@principal1': '0.956904287401645',
#                                                                      '@principal2': '-0.264403619196752',
#                                                                      '@stressxx': '0.532692821696072',
#                                                                      '@stressxy': '-0.581495872298196',
#                                                                      '@stressyy': '0.159807846508822',
#                                                                      '@tresca': '1.2213079065984',
#                                                                      '@vonmises': '1.11291690880581'}]},
#                                                   { '@eid': '11',
#                                                     'localnode': [ { '@id': '1',
#                                                                      '@principal1': '3.69710131113546',
#                                                                      '@principal2': '-1.02155145511535',
#                                                                      '@stressxx': '2.05811527386162',
#                                                                      '@stressxy': '-2.2466710413966',
#                                                                      '@stressyy': '0.617434582158486',
#                                                                      '@tresca': '4.71865276625082',
#                                                                      '@vonmises': '4.2998726381542'},
#                                                                    { '@id': '2',
#                                                                      '@principal1': '3.41282559297033',
#                                                                      '@principal2': '-1.47809096724162',
#                                                                      '@stressxx': '1.88715791302515',
#                                                                      '@stressxy': '-2.26588866707849',
#                                                                      '@stressyy': '0.0475767127035704',
#                                                                      '@tresca': '4.89091656021195',
#                                                                      '@vonmises': '4.34472071797659'},
#                                                                    { '@id': '3',
#                                                                      '@principal1': '3.55794833709045',
#                                                                      '@principal2': '-1.69537785677946',
#                                                                      '@stressxx': '1.83164703193459',
#                                                                      '@stressxy': '-2.46753068242408',
#                                                                      '@stressyy': '0.0309234483764036',
#                                                                      '@tresca': '5.25332619386991',
#                                                                      '@vonmises': '4.64385284789809'},
#                                                                    { '@id': '4',
#                                                                      '@principal1': '3.84836005129926',
#                                                                      '@principal2': '-1.24497434069688',
#                                                                      '@stressxx': '2.00260439277106',
#                                                                      '@stressxy': '-2.44831305674219',
#                                                                      '@stressyy': '0.60078131783132',
#                                                                      '@tresca': '5.09333439199614',
#                                                                      '@vonmises': '4.59901573285634'}]},
#                                                   { '@eid': '12',
#                                                     'localnode': [ { '@id': '1',
#                                                                      '@principal1': '3.94270154125457',
#                                                                      '@principal2': '-1.27549454480767',
#                                                                      '@stressxx': '2.05169768957454',
#                                                                      '@stressxy': '-2.50833277905796',
#                                                                      '@stressyy': '0.615509306872362',
#                                                                      '@tresca': '5.21819608606224',
#                                                                      '@vonmises': '4.71175934072617'},
#                                                                    { '@id': '2',
#                                                                      '@principal1': '3.76675410463406',
#                                                                      '@principal2': '-1.86832422144668',
#                                                                      '@stressxx': '1.87428758651465',
#                                                                      '@stressxy': '-2.66134694034527',
#                                                                      '@stressyy': '0.0241422966727269',
#                                                                      '@tresca': '5.63507832608074',
#                                                                      '@vonmises': '4.97157820124992'},
#                                                                    { '@id': '3',
#                                                                      '@principal1': '3.63409807903141',
#                                                                      '@principal2': '-2.3102519851678',
#                                                                      '@stressxx': '1.4323000562656',
#                                                                      '@stressxy': '-2.87059988241591',
#                                                                      '@stressyy': '-0.108453962401989',
#                                                                      '@tresca': '5.94435006419922',
#                                                                      '@vonmises': '5.19033865796524'},
#                                                                    { '@id': '4',
#                                                                      '@principal1': '3.82168366588383',
#                                                                      '@principal2': '-1.72906045876069',
#                                                                      '@stressxx': '1.60971015932549',
#                                                                      '@stressxy': '-2.7175857211286',
#                                                                      '@stressyy': '0.482913047797646',
#                                                                      '@tresca': '5.55074412464452',
#                                                                      '@vonmises': '4.9196380176497'}]},
#                                                   { '@eid': '13',
#                                                     'localnode': [ { '@id': '1',
#                                                                      '@principal1': '3.06396179703362',
#                                                                      '@principal2': '-1.38624115797376',
#                                                                      '@stressxx': '1.29055433773836',
#                                                                      '@stressxy': '-2.17877238350035',
#                                                                      '@stressyy': '0.387166301321507',
#                                                                      '@tresca': '4.45020295500737',
#                                                                      '@vonmises': '3.94422570237165'},
#                                                                    { '@id': '2',
#                                                                      '@principal1': '3.09592861366614',
#                                                                      '@principal2': '-1.81391429830737',
#                                                                      '@stressxx': '1.19923749380733',
#                                                                      '@stressxy': '-2.39061043394581',
#                                                                      '@stressyy': '0.0827768215514344',
#                                                                      '@tresca': '4.9098429119735',
#                                                                      '@vonmises': '4.30009398052979'},
#                                                                    { '@id': '3',
#                                                                      '@principal1': '2.76516861204465',
#                                                                      '@principal2': '-2.27862779223621',
#                                                                      '@stressxx': '0.587334804922469',
#                                                                      '@stressxy': '-2.49831748063369',
#                                                                      '@stressyy': '-0.100793985114025',
#                                                                      '@tresca': '5.04379640428086',
#                                                                      '@vonmises': '4.37482481000238'},
#                                                                    { '@id': '4',
#                                                                      '@principal1': '2.73990754857471',
#                                                                      '@principal2': '-1.85766040506517',
#                                                                      '@stressxx': '0.678651648853491',
#                                                                      '@stressxy': '-2.28647943018823',
#                                                                      '@stressyy': '0.203595494656047',
#                                                                      '@tresca': '4.59756795363989',
#                                                                      '@vonmises': '4.00597220681947'}]},
#                                                   { '@eid': '14',
#                                                     'localnode': [ { '@id': '1',
#                                                                      '@principal1': '2.17326738082136',
#                                                                      '@principal2': '-1.47347773287886',
#                                                                      '@stressxx': '0.53829972918654',
#                                                                      '@stressxy': '-1.81361271300268',
#                                                                      '@stressyy': '0.161489918755962',
#                                                                      '@tresca': '3.64674511370022',
#                                                                      '@vonmises': '3.17749725901758'
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)

# %%
def calc_g(rhos):
    g = np.dot(rhos, vs.transpose()) - a*V0
    return g

# %%
def calc_rho_i(lmbda, sigma_i):
    rho_i = (-(n-1)/E0 * np.dot(nu*sigma_i, sigma_i.transpose())  / lmbda ) ** (1/n)
    if rho_i > 1:
        rho_i = 1 
    elif rho_i < 0.01:
        rho_i = 0.01
    return rho_i

# %%
def calc_D(rho_i, lmbda, sigma_i):
    D = -lmbda * E0 * rho_i**n / ((n-1) * np.dot(nu*sigma_i, sigma_i.transpose()))
    return D

# %%
def update_rho_i(rho_i, lmbda, sigma_i):
    D = calc_D(rho_i, lmbda, sigma_i)
    while abs(D-1) > 1e-3:
        if D > 1:
            rho_i = rho_i - drho 
        else:
            rho_i = rho_i + drho
        if rho_i > 1:
            rho_i = 1 
            break 
        elif rho_i < 0.01:
            rho_i = 0.01
            break 
        D = calc_D(rho_i,lmbda, sigma_i)
    return rho_i

# %%
def update_lambda(g, lmbda):
    if g<0:
        lmbda = lmbda - dlambda #ラムダを右にシフト
        if lmbda > 0:
            lmbda = lmbda + dlambda #λは正にならないので、もし正になったら負に戻す
    else:
        lmbda = lmbda + dlambda #ラムダを左にシフト
    return lmbda

# %%
def check_if_all_rhos_are_settled(rhos):
    for i in range(ne):
        if (rhos[i] == 1) or (rhos[i] == 0.01):
            continue
        else:
            return False
    return True

# %%
# グローバルなパラメータ
a = 0.375
E0 = 200e9
n = 2 #3が適当??
nu = 0.3

# %%
#要素リストの抽出
elset = my_dict['liml8']['elset'].copy()
if type(elset)==dict:
    elem_list = elset['elem']
elif type(elset)==list:
    elem_list = []
    for e in elset:
        if "elem" in e:
            elem_list.append(e['elem'])
# FEMの結果を変数に格納
nodes = my_dict['liml8']['node'].copy() #nodes
result_elems = my_dict['liml8']['solution']['results']['elem'].copy()
ne = len(elem_list)
sigmas = np.zeros((ne,3))
# ρの初期化。初回か２回目以降かで異なる。
if type(elset)==dict: #初回
    rhos = np.ones(ne) * a #初回はすべて平均値のaで代替する。
elif type(elset)==list: #２回目以降
    mat_list = my_dict['liml8']['mat'].copy()
    E = np.array([x['mechanical']['@youngsmodulus'] for x in mat_list[1:]], dtype=np.double)
    rhos = (E/E0) ** (1/n)
Es = np.zeros(ne)
vs = np.zeros(ne)
cxs = np.zeros(ne)
cys = np.zeros(ne)
# Load stress from each element
lambda_tmp = 0
for i in range(ne):
    Es[i] = rhos[i]**n * E0
    sigma_x = np.array(list(map(lambda x: x['@stressxx'], result_elems[i]['localnode'])),dtype=np.double).sum()
    sigma_y = np.array(list(map(lambda x: x['@stressyy'], result_elems[i]['localnode'])),dtype=np.double).sum()
    tau_xy = np.array(list(map(lambda x: x['@stressxy'], result_elems[i]['localnode'])),dtype=np.double).sum()
    sigmas[i] = np.array([sigma_x,sigma_y,tau_xy])
    lambda_tmp += np.dot(nu*sigmas[i], sigmas[i].transpose())/(rhos[i]**n)
    node_ids = elem_list[i]['@nodes'].split(' ')
    vertices = np.zeros((4, 2))
    n_nodes_in_elems = len(node_ids)
    for j in range(n_nodes_in_elems):
        (x,y) = findXY(node_ids[j])
        vertices[j, :] = (x,y)
    vs[i] = shoelace_area(vertices)
    cxs[i] = vertices[:,0].sum() / n_nodes_in_elems 
    cys[i] = vertices[:,1].sum() / n_nodes_in_elems 

# トータルの体積V0
V0 = vs.sum()  
# lambda_barはlmbdaの初期値
lambda_bar = -1/ne*(n-1)/E0 * lambda_tmp     
lmbda = lambda_bar
dlambda = 0.1 * lambda_bar
drho = 0.05

tolerance = 0.01 
g_prev = 0
g_res = []
l_res = []
is_dump_enabled = True
for i in range(ne):
    if is_dump_enabled: print(str(i)+'th element')
    lmbda = lambda_bar
    # λを更新するアウターループ
    while True:
        # λにしたがってρiを計算する
        rhos[i] = calc_rho_i(lmbda, sigmas[i])
        # ρを更新するインナーループ
        rhos[i] = update_rho_i(rhos[i], lmbda, sigmas[i])
        if check_if_all_rhos_are_settled(rhos): 
            if is_dump_enabled: print("***All rhos are settled.***") 
            break 
        g = calc_g(rhos)
        lmbda = update_lambda(g, lmbda)
        if g==g_prev: #gに変化が見られない場合、λの最適解と判定、
            if is_dump_enabled: print("  No change in g.") 
            break
        if abs(g/V0) < tolerance: #gが0に近づいたらλの最適解と判定
            if is_dump_enabled: print("  g is almost zero") 
            break
        if g*g_prev< 0: #gの符号が変わったらラムダの最適解と判定
            if is_dump_enabled: print("  Sign of g changed.") 
            break
        g_prev = g
    # if is_dump_enabled: print(f"  g/V0: {g/V0}, λ:{lmbda}") 
    g_res.append(g)
    l_res.append(lmbda)
    if(rhos[i]>1):
        print('warning: rho > 1')
plt.rcParams['figure.figsize'] = [8, 2]
plt.subplot(1,2,1)    
plt.plot(range(ne), g_res)
plt.title('g')
plt.xlabel('i-th element')
plt.ylabel('g')
plt.subplot(1,2,2)    
plt.plot(range(ne), l_res)
plt.title('lambda')
plt.xlabel('i-th element')
plt.ylabel('lambda')
# Out:
# 0th element
#   g is almost zero
# 1th element
#   g is almost zero
# 2th element
#   g is almost zero
# 3th element
#   g is almost zero
# 4th element
#   g is almost zero
# 5th element
#   g is almost zero
# 6th element
#   g is almost zero
# 7th element
#   g is almost zero
# 8th element
#   g is almost zero
# 9th element
#   g is almost zero
# 10th element
#   g is almost zero
# 11th element
#   g is almost zero
# 12th element
#   g is almost zero
# 13th element
#   g is almost zero
# 14th element
#   g is almost zero
# 15th element
#   g is almost zero
# 16th element
#   g is almost zero
# 17th element
#   g is almost zero
# 18th element
#   g is almost zero
# 19th element
#   g is almost zero
# 20th element
#   No change in g.
# 21th element
#   No change in g.
# 22th element
#   No change in g.
# 23th element
#   No change in g.
# 24th element
#   No change in g.
# 25th element
#   No change in g.
# 26th element
#   No change in g.
# 27th element
#   No change in g.
# 28th element
#   No change in g.
# 29th element
#   No change in g.
# 30th element
#   g is almost zero
# 31th element
#   g is almost zero
# 32th element
#   g is almost zero
# 33th element
#   g is almost zero
# 34th element
#   g is almost zero
# 35th element
#   g is almost zero
# 36th element
#   g is almost zero
# 37th element
#   g is almost zero
# 38th element
#   g is almost zero
# 39th element
#   No change in g.
# 40th element
#   No change in g.
# 41th element
#   No change in g.
# 42th element
#   No change in g.
# 43th element
#   No change in g.
# 44th element
#   No change in g.
# 45th element
#   No change in g.
# 46th element
#   No change in g.
# 47th element
#   g is almost zero
# 48th element
#   g is almost zero
# 49th element
#   g is almost zero
# 50th element
#   g is almost zero
# 51th element
#   g is almost zero
# 52th element
#   g is almost zero
# 53th element
#   g is almost zero
# 54th element
#   g is almost zero
# 55th element
#   g is almost zero
# 56th element
#   g is almost zero
# 57th element
#   g is almost zero
# 58th element
#   g is almost zero
# 59th element
#   g is almost zero
# 60th element
#   g is almost zero
# 61th element
#   g is almost zero
# 62th element
#   g is almost zero
# 63th element
#   g is almost zero
# 64th element
#   g is almost zero
# 65th element
#   g is almost zero
# 66th element
#   g is almost zero
# 67th element
#   g is almost zero
# 68th element
#   g is almost zero
# 69th element
#   g is almost zero
# 70th element
#   g is almost zero
# 71th element
#   g is almost zero
# 72th element
#   g is almost zero
# 73th element
#   g is almost zero
# 74th element
#   g is almost zero
# 75th element
#   g is almost zero
# 76th element
#   g is almost zero
# 77th element
#   g is almost zero
# 78th element
#   g is almost zero
# 79th element
#   g is almost zero
# 80th element
#   g is almost zero
# 81th element
#   g is almost zero
# 82th element
#   g is almost zero
# 83th element
#   g is almost zero
# 84th element
#   g is almost zero
# 85th element
#   g is almost zero
# 86th element
#   No change in g.
# 87th element
#   No change in g.
# 88th element
#   No change in g.
# 89th element
#   No change in g.
# 90th element
#   No change in g.
# 91th element
#   No change in g.
# 92th element
#   No change in g.
# 93th element
#   g is almost zero
# 94th element
#   g is almost zero
# 95th element
#   g is almost zero
# 96th element
#   g is almost zero
# 97th element
#   g is almost zero
# 98th element
#   g is almost zero
# 99th element
#   g is almost zero
# 100th element
#   g is almost zero
# 101th element
#   g is almost zero
# 102th element
#   g is almost zero
# 103th element
#   g is almost zero
# 104th element
#   g is almost zero
# 105th element
#   g is almost zero
# 106th element
#   g is almost zero
# 107th element
#   g is almost zero
# 108th element
#   g is almost zero
# 109th element
#   g is almost zero
# 110th element
#   g is almost zero
# 111th element
#   No change in g.
# 112th element
#   No change in g.
# 113th element
#   No change in g.
# 114th element
#   No change in g.
# 115th element
#   No change in g.
# 116th element
#   No change in g.
# 117th element
#   g is almost zero
# 118th element
#   g is almost zero
# 119th element
#   g is almost zero
# 120th element
#   g is almost zero
# 121th element
#   g is almost zero
# 122th element
#   g is almost zero
# 123th element
#   g is almost zero
# 124th element
#   No change in g.
# 125th element
#   No change in g.
# 126th element
#   No change in g.
# 127th element
#   No change in g.
# 128th element
#   No change in g.
# 129th element
#   No change in g.
# 130th element
#   No change in g.
# 131th element
#   No change in g.
# 132th element
#   No change in g.
# 133th element
#   No change in g.
# 134th element
#   No change in g.
# 135th element
#   No change in g.
# 136th element
#   No change in g.
# 137th element
#   No change in g.
# 138th element
#   No change in g.
# 139th element
#   No change in g.
# 140th element
#   No change in g.
# 141th element
#   No change in g.
# 142th element
#   No change in g.
# 143th element
#   No change in g.
# 144th element
#   No change in g.
# 145th element
#   No change in g.
# 146th element
#   No change in g.
# 147th element
#   No change in g.
# 148th element
#   No change in g.
# 149th element
#   No change in g.
# 150th element
#   No change in g.
# 151th element
#   No change in g.
# 152th element
#   No change in g.
# 153th element
#   No change in g.
# 154th element
#   No change in g.
# 155th element
#   No change in g.
# 156th element
#   No change in g.
# 157th element
#   No change in g.
# 158th element
#   No change in g.
# 159th element
#   No change in g.
# 160th element
#   No change in g.
# 161th element
#   No change in g.
# 162th element
#   No change in g.
# 163th element
#   No change in g.
# 164th element
#   No change in g.
# 165th element
#   No change in g.
# 166th element
#   No change in g.
# 167th element
#   No change in g.
# 168th element
#   No change in g.
# 169th element
#   No change in g.
# 170th element
#   No change in g.
# 171th element
#   No change in g.
# 172th element
#   No change in g.
# 173th element
#   No change in g.
# 174th element
#   No change in g.
# 175th element
#   No change in g.
# 176th element
#   No change in g.
# 177th element
#   No change in g.
# 178th element
#   No change in g.
# 179th element
#   No change in g.
# 180th element
#   No change in g.
# 181th element
#   No change in g.
# 182th element
#   No change in g.
# 183th element
#   No change in g.
# 184th element
#   No change in g.
# 185th element
#   No change in g.
# 186th element
#   No change in g.
# 187th element
#   g is almost zero
# 188th element
#   g is almost zero
# 189th element
#   g is almost zero
# 190th element
#   g is almost zero
# 191th element
#   g is almost zero
# 192th element
#   g is almost zero
# 193th element
#   g is almost zero
# 194th element
#   g is almost zero
# 195th element
#   g is almost zero
# 196th element
#   g is almost zero
# 197th element
#   g is almost zero
# 198th element
#   g is almost zero
# 199th element
#   g is almost zero
# 200th element
#   g is almost zero
# 201th element
#   g is almost zero
# 202th element
#   g is almost zero
# 203th element
#   g is almost zero
# 204th element
#   g is almost zero
# 205th element
#   g is almost zero
# 206th element
#   g is almost zero
# 207th element
#   g is almost zero
# 208th element
#   g is almost zero
# 209th element
#   g is almost zero
# 210th element
#   g is almost zero
# 211th element
#   g is almost zero
# 212th element
#   g is almost zero
# 213th element
#   g is almost zero
# 214th element
#   g is almost zero
# 215th element
#   g is almost zero
# 216th element
#   g is almost zero
# 217th element
#   g is almost zero
# 218th element
#   g is almost zero
# 219th element
#   g is almost zero
# 220th element
#   g is almost zero
# 221th element
#   g is almost zero
# 222th element
#   g is almost zero
# 223th element
#   g is almost zero
# 224th element
#   g is almost zero
# 225th element
#   g is almost zero
# 226th element
#   g is almost zero
# 227th element
#   g is almost zero
# 228th element
#   g is almost zero
# 229th element
#   g is almost zero
# 230th element
#   g is almost zero
# 231th element
#   g is almost zero
# 232th element
#   g is almost zero
# 233th element
#   g is almost zero
# 234th element
#   g is almost zero
# 235th element
#   g is almost zero
# 236th element
#   g is almost zero
# 237th element
#   g is almost zero
# 238th element
#   g is almost zero
# 239th element
#   g is almost zero
# 240th element
#   g is almost zero
# 241th element
#   g is almost zero
# 242th element
#   g is almost zero
# 243th element
#   g is almost zero
# 244th element
#   g is almost zero
# 245th element
#   g is almost zero
# 246th element
#   g is almost zero
# 247th element
#   g is almost zero
# 248th element
#   g is almost zero
# 249th element
#   g is almost zero
# 250th element
#   g is almost zero
# 251th element
#   g is almost zero
# 252th element
#   g is almost zero
# 253th element
#   g is almost zero
# 254th element
#   g is almost zero
# 255th element
#   g is almost zero
# 256th element
#   g is almost zero
# 257th element
#   g is almost zero
# 258th element
#   g is almost zero
# 259th element
#   g is almost zero
# 260th element
#   g is almost zero
# 261th element
#   g is almost zero
# 262th element
#   g is almost zero
# 263th element
#   g is almost zero
# 264th element
#   g is almost zero
# 265th element
#   g is almost zero
# 266th element
#   g is almost zero
# 267th element
#   g is almost zero
# 268th element
#   g is almost zero
# 269th element
#   g is almost zero
# 270th element
#   g is almost zero
# 271th element
#   g is almost zero
# 272th element
#   g is almost zero
# 273th element
#   g is almost zero
# 274th element
#   g is almost zero
# 275th element
#   g is almost zero
# 276th element
#   g is almost zero
# 277th element
#   g is almost zero
# 278th element
#   g is almost zero
# 279th element
#   g is almost zero
# 280th element
#   g is almost zero
# 281th element
#   g is almost zero
# 282th element
#   g is almost zero
# 283th element
#   g is almost zero
# 284th element
#   g is almost zero
# 285th element
#   g is almost zero
# 286th element
#   g is almost zero
# 287th element
#   g is almost zero
# 288th element
#   g is almost zero
# 289th element
#   g is almost zero
# 290th element
#   g is almost zero
# 291th element
#   g is almost zero
# 292th element
#   g is almost zero
# 293th element
#   g is almost zero
# 294th element
#   g is almost zero
# 295th element
#   g is almost zero
# 296th element
#   g is almost zero
# 297th element
#   g is almost zero
# 298th element
#   g is almost zero
# 299th element
#   g is almost zero
# 300th element
#   g is almost zero
# 301th element
#   g is almost zero
# 302th element
#   g is almost zero
# 303th element
#   g is almost zero
# 304th element
#   g is almost zero
# 305th element
#   g is almost zero
# 306th element
#   g is almost zero
# 307th element
#   g is almost zero
# 308th element
#   g is almost zero
# 309th element
#   g is almost zero
# 310th element
#   g is almost zero
# 311th element
#   g is almost zero
# 312th element
#   g is almost zero
# 313th element
#   g is almost zero
# 314th element
#   g is almost zero
# 315th element
#   g is almost zero
# 316th element
#   g is almost zero
# 317th element
#   g is almost zero
# 318th element
#   g is almost zero
# 319th element
#   g is almost zero
# 320th element
#   g is almost zero
# 321th element
#   g is almost zero
# 322th element
#   g is almost zero
# 323th element
#   g is almost zero
# 324th element
#   g is almost zero
# 325th element
#   g is almost zero
# 326th element
#   g is almost zero
# 327th element
#   g is almost zero
# 328th element
#   g is almost zero
# 329th element
#   g is almost zero
# 330th element
#   g is almost zero
# 331th element
#   g is almost zero
# 332th element
#   g is almost zero
# 333th element
#   g is almost zero
# 334th element
#   g is almost zero
# 335th element
#   g is almost zero
# 336th element
#   g is almost zero
# 337th element
#   g is almost zero
# 338th element
#   g is almost zero
# 339th element
#   g is almost zero
# 340th element
#   g is almost zero
# 341th element
#   g is almost zero
# 342th element
#   g is almost zero
# 343th element
#   g is almost zero
# 344th element
#   g is almost zero
# 345th element
#   g is almost zero
# 346th element
#   g is almost zero
# 347th element
#   g is almost zero
# 348th element
#   g is almost zero
# 349th element
#   g is almost zero
# 350th element
#   g is almost zero
# 351th element
#   g is almost zero
# 352th element
#   g is almost zero
# 353th element
#   g is almost zero
# 354th element
#   g is almost zero
# 355th element
#   g is almost zero
# 356th element
#   g is almost zero
# 357th element
#   g is almost zero
# 358th element
#   g is almost zero
# 359th element
#   g is almost zero
# 360th element
#   g is almost zero
# 361th element
#   g is almost zero
# 362th element
#   g is almost zero
# 363th element
#   g is almost zero
# 364th element
#   g is almost zero
# 365th element
#   g is almost zero
# 366th element
#   g is almost zero
# 367th element
#   g is almost zero
# 368th element
#   g is almost zero
# 369th element
#   g is almost zero
# 370th element
#   g is almost zero
# 371th element
#   g is almost zero
# 372th element
#   g is almost zero
# 373th element
#   g is almost zero
# 374th element
#   g is almost zero
# 375th element
#   g is almost zero
# 376th element
#   g is almost zero
# 377th element
#   g is almost zero
# 378th element
#   g is almost zero
# 379th element
#   g is almost zero
# 380th element
#   g is almost zero
# 381th element
#   g is almost zero
# 382th element
#   g is almost zero
# 383th element
#   g is almost zero
# 384th element
#   g is almost zero
# 385th element
#   g is almost zero
# 386th element
#   g is almost zero
# 387th element
#   g is almost zero
# 388th element
#   g is almost zero
# 389th element
#   g is almost zero
# 390th element
#   g is almost zero
# 391th element
#   g is almost zero
# 392th element
#   g is almost zero
# 393th element
#   g is almost zero
# 394th element
#   g is almost zero
# 395th element
#   g is almost zero
# 396th element
#   g is almost zero
# 397th element
#   g is almost zero
# 398th element
#   g is almost zero
# 399th element
#   g is almost zero
# 400th element
#   g is almost zero
# 401th element
#   g is almost zero
# 402th element
#   g is almost zero
# 403th element
#   g is almost zero
# 404th element
#   g is almost zero
# 405th element
#   g is almost zero
# 406th element
#   g is almost zero
# 407th element
#   g is almost zero
# 408th element
#   g is almost zero
# 409th element
#   g is almost zero
# 410th element
#   g is almost zero
# 411th element
#   g is almost zero
# 412th element
#   g is almost zero
# 413th element
#   g is almost zero
# 414th element
#   g is almost zero
# 415th element
#   g is almost zero
# 416th element
#   g is almost zero
# 417th element
#   g is almost zero
# 418th element
#   g is almost zero
# 419th element
#   g is almost zero
# 420th element
#   g is almost zero
# 421th element
#   g is almost zero
# 422th element
#   g is almost zero
# 423th element
#   g is almost zero
# 424th element
#   g is almost zero
# 425th element
#   g is almost zero
# 426th element
#   g is almost zero
# 427th element
#   g is almost zero
# 428th element
#   g is almost zero
# 429th element
#   g is almost zero
# 430th element
#   g is almost zero
# 431th element
#   g is almost zero
# 432th element
#   g is almost zero
# 433th element
#   g is almost zero
# 434th element
#   g is almost zero
# 435th element
#   g is almost zero
# 436th element
#   g is almost zero
# 437th element
#   g is almost zero
# 438th element
#   g is almost zero
# 439th element
#   g is almost zero
# 440th element
#   g is almost zero
# 441th element
#   g is almost zero
# 442th element
#   g is almost zero
# 443th element
#   g is almost zero
# 444th element
#   g is almost zero
# 445th element
#   g is almost zero
# 446th element
#   g is almost zero
# 447th element
#   g is almost zero
# 448th element
#   g is almost zero
# 449th element
#   g is almost zero
# 450th element
#   g is almost zero
# 451th element
#   g is almost zero
# 452th element
#   g is almost zero
# 453th element
#   g is almost zero
# 454th element
#   g is almost zero
# 455th element
#   g is almost zero
# 456th element
#   g is almost zero
# 457th element
#   g is almost zero
# 458th element
#   g is almost zero
# 459th element
#   g is almost zero
# 460th element
#   g is almost zero
# 461th element
#   g is almost zero
# 462th element
#   g is almost zero
# 463th element
#   g is almost zero
# 464th element
#   g is almost zero
# 465th element
#   g is almost zero
# 466th element
#   g is almost zero
# 467th element
#   g is almost zero
# 468th element
#   g is almost zero
# 469th element
#   g is almost zero
# 470th element
#   g is almost zero
# 471th element
#   g is almost zero
# 472th element
#   g is almost zero
# 473th element
#   g is almost zero
# 474th element
#   g is almost zero
# 475th element
#   g is almost zero
# 476th element
#   g is almost zero
# 477th element
#   g is almost zero
# 478th element
#   g is almost zero
# 479th element
#   g is almost zero
# 480th element
#   g is almost zero
# 481th element
#   g is almost zero
# 482th element
#   g is almost zero
# 483th element
#   g is almost zero
# 484th element
#   g is almost zero
# 485th element
#   g is almost zero
# 486th element
#   g is almost zero
# 487th element
#   g is almost zero
# 488th element
#   g is almost zero
# 489th element
#   g is almost zero
# 490th element
#   g is almost zero
# 491th element
#   g is almost zero
# 492th element
#   g is almost zero
# 493th element
#   g is almost zero
# 494th element
#   g is almost zero
# 495th element
#   g is almost zero
# 496th element
#   g is almost zero
# 497th element
#   g is almost zero
# 498th element
#   g is almost zero
# 499th element
#   g is almost zero
# 500th element
#   g is almost zero
# 501th element
#   g is almost zero
# 502th element
#   g is almost zero
# 503th element
#   g is almost zero
# 504th element
#   g is almost zero
# 505th element
#   g is almost zero
# 506th element
#   g is almost zero
# 507th element
#   g is almost zero
# 508th element
#   g is almost zero
# 509th element
#   g is almost zero
# 510th element
#   g is almost zero
# 511th element
#   g is almost zero
# 512th element
#   g is almost zero
# 513th element
#   g is almost zero
# 514th element
#   g is almost zero
# 515th element
#   g is almost zero
# 516th element
#   g is almost zero
# 517th element
#   g is almost zero
# 518th element
#   g is almost zero
# 519th element
#   g is almost zero
# 520th element
#   g is almost zero
# 521th element
#   g is almost zero
# 522th element
#   g is almost zero
# 523th element
#   g is almost zero
# 524th element
#   g is almost zero
# 525th element
#   g is almost zero
# 526th element
#   g is almost zero
# 527th element
#   g is almost zero
# 528th element
#   g is almost zero
# 529th element
#   g is almost zero
# 530th element
#   g is almost zero
# 531th element
#   g is almost zero
# 532th element
#   g is almost zero
# 533th element
#   g is almost zero
# 534th element
#   g is almost zero
# 535th element
#   g is almost zero
# 536th element
#   g is almost zero
# 537th element
#   g is almost zero
# 538th element
#   g is almost zero
# 539th element
#   g is almost zero
# 540th element
#   g is almost zero
# 541th element
#   g is almost zero
# 542th element
#   g is almost zero
# 543th element
#   g is almost zero
# 544th element
#   g is almost zero
# 545th element
#   g is almost zero
# 546th element
#   g is almost zero
# 547th element
#   g is almost zero
# 548th element
#   g is almost zero
# 549th element
#   g is almost zero
# 550th element
#   g is almost zero
# 551th element
#   g is almost zero
# 552th element
#   g is almost zero
# 553th element
#   g is almost zero
# 554th element
#   g is almost zero
# 555th element
#   g is almost zero
# 556th element
#   g is almost zero
# 557th element
#   g is almost zero
# 558th element
#   g is almost zero
# 559th element
#   g is almost zero
# 560th element
#   g is almost zero
# 561th element
#   g is almost zero
# 562th element
#   g is almost zero
# 563th element
#   g is almost zero
# 564th element
#   g is almost zero
# 565th element
#   g is almost zero
# 566th element
#   g is almost zero
# 567th element
#   g is almost zero
# 568th element
#   g is almost zero
# 569th element
#   g is almost zero
# 570th element
#   g is almost zero
# 571th element
#   g is almost zero
# 572th element
#   g is almost zero
# 573th element
#   g is almost zero
# 574th element
#   g is almost zero
# 575th element
#   g is almost zero
# 576th element
#   g is almost zero
# 577th element
#   g is almost zero
# 578th element
#   g is almost zero
# 579th element
#   g is almost zero
# 580th element
#   g is almost zero
# 581th element
#   g is almost zero
# 582th element
#   g is almost zero
# 583th element
#   g is almost zero
# 584th element
#   g is almost zero
# 585th element
#   g is almost zero
# 586th element
#   g is almost zero
# 587th element
#   g is almost zero
# 588th element
#   g is almost zero
# 589th element
#   g is almost zero
# 590th element
#   g is almost zero
# 591th element
#   g is almost zero
# 592th element
#   g is almost zero
# 593th element
#   g is almost zero
# 594th element
#   g is almost zero
# 595th element
#   g is almost zero
# 596th element
#   g is almost zero
# 597th element
#   g is almost zero
# 598th element
#   g is almost zero
# 599th element
#   g is almost zero
# 600th element
#   g is almost zero
# 601th element
#   g is almost zero
# 602th element
#   g is almost zero
# 603th element
#   g is almost zero
# 604th element
#   g is almost zero
# 605th element
#   g is almost zero
# 606th element
#   g is almost zero
# 607th element
#   g is almost zero
# 608th element
#   g is almost zero
# 609th element
#   g is almost zero
# 610th element
#   g is almost zero
# 611th element
#   g is almost zero
# 612th element
#   g is almost zero
# 613th element
#   g is almost zero
# 614th element
#   g is almost zero
# 615th element
#   g is almost zero
# 616th element
#   g is almost zero
# 617th element
#   g is almost zero
# 618th element
#   g is almost zero
# 619th element
#   g is almost zero
# 620th element
#   g is almost zero
# 621th element
#   g is almost zero
# 622th element
#   g is almost zero
# 623th element
#   g is almost zero
# 624th element
#   g is almost zero
# 625th element
#   g is almost zero
# 626th element
#   g is almost zero
# 627th element
#   g is almost zero
# 628th element
#   g is almost zero
# 629th element
#   g is almost zero
# 630th element
#   g is almost zero
# 631th element
#   g is almost zero
# 632th element
#   g is almost zero
# 633th element
#   g is almost zero
# 634th element
#   g is almost zero
# 635th element
#   g is almost zero
# 636th element
#   g is almost zero
# 637th element
#   g is almost zero
# 638th element
#   g is almost zero
# 639th element
#   g is almost zero
# 640th element
#   g is almost zero
# 641th element
#   g is almost zero
# 642th element
#   g is almost zero
# 643th element
#   g is almost zero
# 644th element
#   g is almost zero
# 645th element
#   g is almost zero
# 646th element
#   g is almost zero
# 647th element
#   g is almost zero
# 648th element
#   g is almost zero
# 649th element
#   g is almost zero
# 650th element
#   g is almost zero
# 651th element
#   g is almost zero
# 652th element
#   g is almost zero
# 653th element
#   g is almost zero
# 654th element
#   g is almost zero
# 655th element
#   g is almost zero
# 656th element
#   g is almost zero
# 657th element
#   g is almost zero
# 658th element
#   g is almost zero
# 659th element
#   g is almost zero
# 660th element
#   g is almost zero
# 661th element
#   g is almost zero
# 662th element
#   g is almost zero
# 663th element
#   g is almost zero
# 664th element
#   g is almost zero
# 665th element
#   g is almost zero
# 666th element
#   g is almost zero
# 667th element
#   g is almost zero
# 668th element
#   g is almost zero
# 669th element
#   g is almost zero
# 670th element
#   g is almost zero
# 671th element
#   g is almost zero
# 672th element
#   g is almost zero
# 673th element
#   g is almost zero
# 674th element
#   g is almost zero
# 675th element
#   g is almost zero
# 676th element
#   g is almost zero
# 677th element
#   g is almost zero
# 678th element
#   g is almost zero
# 679th element
#   g is almost zero
# 680th element
#   g is almost zero
# 681th element
#   g is almost zero
# 682th element
#   g is almost zero
# 683th element
#   g is almost zero
# 684th element
#   g is almost zero
# 685th element
#   g is almost zero
# 686th element
#   g is almost zero
# 687th element
#   g is almost zero
# 688th element
#   g is almost zero
# 689th element
#   g is almost zero
# 690th element
#   g is almost zero
# 691th element
#   g is almost zero
# 692th element
#   g is almost zero
# 693th element
#   g is almost zero
# 694th element
#   g is almost zero
# 695th element
#   g is almost zero
# 696th element
#   g is almost zero
# 697th element
#   g is almost zero
# 698th element
#   g is almost zero
# 699th element
#   g is almost zero
# 700th element
#   g is almost zero
# 701th element
#   g is almost zero
# 702th element
#   g is almost zero
# 703th element
#   g is almost zero
# 704th element
#   g is almost zero
# 705th element
#   g is almost zero
# 706th element
#   g is almost zero
# 707th element
#   g is almost zero
# 708th element
#   g is almost zero
# 709th element
#   g is almost zero
# 710th element
#   g is almost zero
# 711th element
#   g is almost zero
# 712th element
#   g is almost zero
# 713th element
#   g is almost zero
# 714th element
#   g is almost zero
# 715th element
#   g is almost zero
# 716th element
#   g is almost zero
# 717th element
#   g is almost zero
# 718th element
#   g is almost zero
# 719th element
#   g is almost zero
# 720th element
#   g is almost zero
# 721th element
#   g is almost zero
# 722th element
#   g is almost zero
# 723th element
#   g is almost zero
# 724th element
#   g is almost zero
# 725th element
#   g is almost zero
# 726th element
#   g is almost zero
# 727th element
#   g is almost zero
# 728th element
#   g is almost zero
# 729th element
#   g is almost zero
# 730th element
#   g is almost zero
# 731th element
#   g is almost zero
# 732th element
#   g is almost zero
# 733th element
#   g is almost zero
# 734th element
#   g is almost zero
# 735th element
#   g is almost zero
# 736th element
#   g is almost zero
# 737th element
#   g is almost zero
# 738th element
#   g is almost zero
# 739th element
#   g is almost zero
# 740th element
#   g is almost zero
# 741th element
#   g is almost zero
# 742th element
#   g is almost zero
# 743th element
#   g is almost zero
# 744th element
#   g is almost zero
# 745th element
#   g is almost zero
# 746th element
#   g is almost zero
# 747th element
#   g is almost zero
# 748th element
#   g is almost zero
# 749th element
#   g is almost zero
# 750th element
#   g is almost zero
# 751th element
#   g is almost zero
# 752th element
#   g is almost zero
# 753th element
#   g is almost zero
# 754th element
#   g is almost zero
# 755th element
#   g is almost zero
# 756th element
#   g is almost zero
# 757th element
#   g is almost zero
# 758th element
#   g is almost zero
# 759th element
#   g is almost zero
# 760th element
#   g is almost zero
# 761th element
#   g is almost zero
# 762th element
#   g is almost zero
# 763th element
#   g is almost zero
# 764th element
#   g is almost zero
# 765th element
#   g is almost zero
# 766th element
#   g is almost zero
# 767th element
#   g is almost zero
# 768th element
#   g is almost zero
# 769th element
#   g is almost zero
# 770th element
#   g is almost zero
# 771th element
#   g is almost zero
# 772th element
#   g is almost zero
# 773th element
#   g is almost zero
# 774th element
#   g is almost zero
# 775th element
#   g is almost zero
# 776th element
#   g is almost zero
# 777th element
#   g is almost zero
# 778th element
#   g is almost zero
# 779th element
#   g is almost zero
# 780th element
#   g is almost zero
# 781th element
#   g is almost zero
# 782th element
#   g is almost zero
# 783th element
#   g is almost zero
# 784th element
#   g is almost zero
# 785th element
#   g is almost zero
# 786th element
#   g is almost zero
# 787th element
#   g is almost zero
# 788th element
#   g is almost zero
# 789th element
#   g is almost zero
# 790th element
#   g is almost zero
# 791th element
#   g is almost zero
# 792th element
#   g is almost zero
# 793th element
#   g is almost zero
# 794th element
#   g is almost zero
# 795th element
#   g is almost zero
# 796th element
#   g is almost zero
# 797th element
#   g is almost zero
# 798th element
#   g is almost zero
# 799th element
#   g is almost zero
# 800th element
#   g is almost zero
# 801th element
#   g is almost zero
# 802th element
#   g is almost zero
# 803th element
#   g is almost zero
# 804th element
#   g is almost zero
# 805th element
#   g is almost zero
# 806th element
#   g is almost zero
# 807th element
#   g is almost zero
# 808th element
#   g is almost zero
# 809th element
#   g is almost zero
# 810th element
#   g is almost zero
# 811th element
#   g is almost zero
# 812th element
#   g is almost zero
# 813th element
#   g is almost zero
# 814th element
#   g is almost zero
# 815th element
#   g is almost zero
# 816th element
#   g is almost zero
# 817th element
#   g is almost zero
# 818th element
#   g is almost zero
# 819th element
#   g is almost zero
# 820th element
#   g is almost zero
# 821th element
#   g is almost zero
# 822th element
#   g is almost zero
# 823th element
#   g is almost zero
# 824th element
#   g is almost zero
# 825th element
#   g is almost zero
# 826th element
#   g is almost zero
# 827th element
#   g is almost zero
# 828th element
#   g is almost zero
# 829th element
#   g is almost zero
# 830th element
#   g is almost zero
# 831th element
#   g is almost zero
# 832th element
#   g is almost zero
# 833th element
#   g is almost zero
# 834th element
#   g is almost zero
# 835th element
#   g is almost zero
# 836th element
#   g is almost zero
# 837th element
#   g is almost zero
# 838th element
#   g is almost zero
# 839th element
#   g is almost zero
# 840th element
#   g is almost zero
# 841th element
#   g is almost zero
# 842th element
#   g is almost zero
# 843th element
#   g is almost zero
# 844th element
#   g is almost zero
# 845th element
#   g is almost zero
# 846th element
#   g is almost zero
# 847th element
#   g is almost zero
# 848th element
#   g is almost zero
# 849th element
#   g is almost zero
# 850th element
#   g is almost zero
# 851th element
#   g is almost zero
# 852th element
#   g is almost zero
# 853th element
#   g is almost zero
# 854th element
#   g is almost zero
# 855th element
#   g is almost zero
# 856th element
#   g is almost zero
# 857th element
#   g is almost zero
# 858th element
#   g is almost zero
# 859th element
#   g is almost zero
# 860th element
#   g is almost zero
# 861th element
#   g is almost zero
# 862th element
#   g is almost zero
# 863th element
#   g is almost zero
# 864th element
#   g is almost zero
# 865th element
#   g is almost zero
# 866th element
#   g is almost zero
# 867th element
#   g is almost zero
# 868th element
#   g is almost zero
# 869th element
#   g is almost zero
# 870th element
#   g is almost zero
# 871th element
#   g is almost zero
# 872th element
#   g is almost zero
# 873th element
#   g is almost zero
# 874th element
#   g is almost zero
# 875th element
#   g is almost zero
# 876th element
#   g is almost zero
# 877th element
#   g is almost zero
# 878th element
#   g is almost zero
# 879th element
#   g is almost zero
# 880th element
#   g is almost zero
# 881th element
#   g is almost zero
# 882th element
#   g is almost zero
# 883th element
#   g is almost zero
# 884th element
#   g is almost zero
# 885th element
#   g is almost zero
# 886th element
#   g is almost zero
# 887th element
#   g is almost zero
# 888th element
#   g is almost zero
# 889th element
#   g is almost zero
# 890th element
#   g is almost zero
# 891th element
#   g is almost zero
# 892th element
#   g is almost zero
# 893th element
#   g is almost zero
# 894th element
#   g is almost zero
# 895th element
#   g is almost zero
# 896th element
#   g is almost zero
# 897th element
#   g is almost zero
# 898th element
#   g is almost zero
# 899th element
#   g is almost zero
# 900th element
#   g is almost zero
# 901th element
#   g is almost zero
# 902th element
#   g is almost zero
# 903th element
#   g is almost zero
# 904th element
#   g is almost zero
# 905th element
#   g is almost zero
# 906th element
#   g is almost zero
# 907th element
#   g is almost zero
# 908th element
#   g is almost zero
# 909th element
#   g is almost zero
# 910th element
#   g is almost zero
# 911th element
#   g is almost zero
# 912th element
#   g is almost zero
# 913th element
#   g is almost zero
# 914th element
#   g is almost zero
# 915th element
#   g is almost zero
# 916th element
#   g is almost zero
# 917th element
#   g is almost zero
# 918th element
#   g is almost zero
# 919th element
#   g is almost zero
# 920th element
#   g is almost zero
# 921th element
#   g is almost zero
# 922th element
#   g is almost zero
# 923th element
#   g is almost zero
# 924th element
#   g is almost zero
# 925th element
#   g is almost zero
# 926th element
#   g is almost zero
# 927th element
#   g is almost zero
# 928th element
#   g is almost zero
# 929th element
#   g is almost zero
# 930th element
#   g is almost zero
# 931th element
#   g is almost zero
# 932th element
#   g is almost zero
# 933th element
#   g is almost zero
# 934th element
#   g is almost zero
# 935th element
#   g is almost zero
# 936th element
#   g is almost zero
# 937th element
#   g is almost zero
# 938th element
#   g is almost zero
# 939th element
#   g is almost zero
# 940th element
#   g is almost zero
# 941th element
#   g is almost zero
# 942th element
#   g is almost zero
# 943th element
#   g is almost zero
# 944th element
#   g is almost zero
# 945th element
#   g is almost zero
# 946th element
#   g is almost zero
# 947th element
#   g is almost zero
# 948th element
#   g is almost zero
# 949th element
#   g is almost zero
# 950th element
#   g is almost zero
# 951th element
#   g is almost zero
# 952th element
#   g is almost zero
# 953th element
#   g is almost zero
# 954th element
#   g is almost zero
# 955th element
#   g is almost zero
# 956th element
#   g is almost zero
# 957th element
#   g is almost zero
# 958th element
#   g is almost zero
# 959th element
#   g is almost zero
# 960th element
#   g is almost zero
# 961th element
#   g is almost zero
# 962th element
#   g is almost zero
# 963th element
#   g is almost zero
# 964th element
#   g is almost zero
# 965th element
#   g is almost zero
# 966th element
#   No change in g.
# 967th element
#   No change in g.
# 968th element
#   g is almost zero
# 969th element
#   g is almost zero
# 970th element
#   g is almost zero
# 971th element
#   g is almost zero
# 972th element
#   g is almost zero
# 973th element
#   g is almost zero
# 974th element
#   g is almost zero
# 975th element
#   g is almost zero
# 976th element
#   g is almost zero
# 977th element
#   g is almost zero
# 978th element
#   g is almost zero
# 979th element
#   g is almost zero
# 980th element
#   g is almost zero
# 981th element
#   g is almost zero
# 982th element
#   g is almost zero
# 983th element
#   g is almost zero
# 984th element
#   g is almost zero
# 985th element
#   No change in g.
# 986th element
#   No change in g.
# 987th element
#   No change in g.
# 988th element
#   No change in g.
# 989th element
#   No change in g.
# 990th element
#   No change in g.
# 991th element
#   No change in g.
# 992th element
#   No change in g.
# 993th element
#   No change in g.
# 994th element
#   No change in g.
# 995th element
#   No change in g.
# 996th element
#   No change in g.
# 997th element
#   g is almost zero
# 998th element
#   g is almost zero
# 999th element
#   g is almost zero
# 1000th element
#   g is almost zero
# 1001th element
#   g is almost zero
# 1002th element
#   g is almost zero
# 1003th element
#   g is almost zero
# 1004th element
#   g is almost zero
# 1005th element
#   No change in g.
# 1006th element
#   g is almost zero
# 1007th element
#   g is almost zero
# 1008th element
#   g is almost zero
# 1009th element
#   No change in g.
# 1010th element
#   No change in g.
# 1011th element
#   No change in g.
# 1012th element
#   No change in g.
# 1013th element
#   No change in g.
# 1014th element
#   No change in g.
# 1015th element
#   No change in g.
# 1016th element
#   No change in g.
# 1017th element
#   No change in g.
# 1018th element
#   No change in g.
# 1019th element
#   No change in g.
# 1020th element
#   No change in g.
# 1021th element
#   No change in g.
# 1022th element
#   No change in g.
# 1023th element
#   No change in g.
# 1024th element
#   No change in g.
# 1025th element
#   No change in g.
# 1026th element
#   No change in g.
# 1027th element
#   No change in g.
# 1028th element
#   No change in g.
# 1029th element
#   No change in g.
# 1030th element
#   No change in g.
# 1031th element
#   No change in g.
# 1032th element
#   No change in g.
# 1033th element
#   No change in g.
# 1034th element
#   No change in g.
# 1035th element
#   No change in g.
# 1036th element
#   No change in g.
# 1037th element
#   No change in g.
# 1038th element
#   No change in g.
# 1039th element
#   No change in g.
# 1040th element
#   No change in g.
# 1041th element
#   No change in g.
# 1042th element
#   No change in g.
# 1043th element
#   No change in g.
# 1044th element
#   No change in g.
# 1045th element
#   No change in g.
# 1046th element
#   No change in g.
# 1047th element
#   No change in g.
# 1048th element
#   No change in g.
# 1049th element
#   No change in g.
# 1050th element
#   No change in g.
# 1051th element
#   No change in g.
# 1052th element
#   No change in g.
# 1053th element
#   No change in g.
# 1054th element
#   No change in g.
# 1055th element
#   No change in g.
# 1056th element
#   No change in g.
# 1057th element
#   g is almost zero
# 1058th element
#   g is almost zero
# 1059th element
#   g is almost zero
# 1060th element
#   No change in g.
# 1061th element
#   No change in g.
# 1062th element
#   No change in g.
# 1063th element
#   No change in g.
# 1064th element
#   No change in g.
# 1065th element
#   No change in g.
# 1066th element
#   No change in g.
# 1067th element
#   No change in g.
# 1068th element
#   No change in g.
# 1069th element
#   No change in g.
# 1070th element
#   No change in g.
# 1071th element
#   No change in g.
# 1072th element
#   No change in g.
# 1073th element
#   No change in g.
# 1074th element
#   No change in g.
# 1075th element
#   No change in g.
# 1076th element
#   No change in g.
# 1077th element
#   g is almost zero
# 1078th element
#   No change in g.
# 1079th element
#   g is almost zero
# 1080th element
#   g is almost zero
# 1081th element
#   No change in g.
# 1082th element
#   g is almost zero
# 1083th element
#   g is almost zero
# 1084th element
#   g is almost zero
# 1085th element
#   No change in g.
# 1086th element
#   No change in g.
# 1087th element
#   No change in g.
# 1088th element
#   No change in g.
# 1089th element
#   No change in g.
# 1090th element
#   No change in g.
# 1091th element
#   No change in g.
# 1092th element
#   No change in g.
# 1093th element
#   No change in g.
# 1094th element
#   No change in g.
# 1095th element
#   No change in g.
# 1096th element
#   No change in g.
# 1097th element
#   No change in g.
# 1098th element
#   No change in g.
# 1099th element
#   No change in g.
# 1100th element
#   No change in g.
# 1101th element
#   No change in g.
# 1102th element
#   No change in g.
# 1103th element
#   No change in g.
# 1104th element
#   No change in g.
# 1105th element
#   No change in g.
# 1106th element
#   No change in g.
# 1107th element
#   No change in g.
# 1108th element
#   No change in g.
# 1109th element
#   No change in g.
# 1110th element
#   No change in g.
# 1111th element
#   No change in g.
# 1112th element
#   No change in g.
# 1113th element
#   No change in g.
# 1114th element
#   No change in g.
# 1115th element
#   No change in g.
# 1116th element
#   No change in g.
# 1117th element
#   No change in g.
# 1118th element
#   No change in g.
# 1119th element
#   No change in g.
# 1120th element
#   No change in g.
# 1121th element
#   No change in g.
# 1122th element
#   No change in g.
# 1123th element
#   No change in g.
# 1124th element
#   No change in g.
# 1125th element
#   No change in g.
# 1126th element
#   No change in g.
# 1127th element
#   No change in g.
# 1128th element
#   No change in g.
# 1129th element
#   No change in g.
# 1130th element
#   No change in g.
# 1131th element
#   No change in g.
# 1132th element
#   No change in g.
# 1133th element
#   No change in g.
# 1134th element
#   No change in g.
# 1135th element
#   No change in g.
# 1136th element
#   No change in g.
# 1137th element
#   No change in g.
# 1138th element
#   No change in g.
# 1139th element
#   No change in g.
# 1140th element
#   No change in g.
# 1141th element
#   No change in g.
# 1142th element
#   No change in g.
# 1143th element
#   No change in g.
# 1144th element
#   No change in g.
# 1145th element
#   No change in g.
# 1146th element
#   No change in g.
# 1147th element
#   No change in g.
# 1148th element
#   No change in g.
# 1149th element
#   No change in g.
# 1150th element
#   No change in g.
# 1151th element
#   No change in g.
# 1152th element
#   No change in g.
# 1153th element
#   No change in g.
# 1154th element
#   No change in g.
# 1155th element
#   No change in g.
# 1156th element
#   No change in g.
# 1157th element
#   No change in g.
# 1158th element
#   No change in g.
# 1159th element
#   No change in g.
# 1160th element
#   No change in g.
# 1161th element
#   No change in g.
# 1162th element
#   No change in g.
# 1163th element
#   No change in g.
# 1164th element
#   No change in g.
# 1165th element
#   No change in g.
# 1166th element
#   No change in g.
# 1167th element
#   No change in g.
# 1168th element
#   No change in g.
# 1169th element
#   No change in g.
# 1170th element
#   No change in g.
# 1171th element
#   No change in g.
# 1172th element
#   No change in g.
# 1173th element
#   No change in g.
# 1174th element
#   No change in g.
# 1175th element
#   No change in g.
# 1176th element
#   No change in g.
# 1177th element
#   No change in g.
# 1178th element
#   No change in g.
# 1179th element
#   No change in g.
# 1180th element
#   No change in g.
# 1181th element
#   No change in g.
# 1182th element
#   g is almost zero
# 1183th element
#   g is almost zero
# 1184th element
#   g is almost zero
# 1185th element
#   g is almost zero
# 1186th element
#   g is almost zero
# 1187th element
#   g is almost zero
# 1188th element
#   g is almost zero
# 1189th element
#   g is almost zero
# 1190th element
#   g is almost zero
# 1191th element
#   g is almost zero
# 1192th element
#   g is almost zero
# 1193th element
#   g is almost zero
# 1194th element
#   g is almost zero
# 1195th element
#   g is almost zero
# Text(0, 0.5, 'lambda')

# %%
Ei = (rhos**n) * E0
[X,Y] = np.meshgrid(np.linspace(min(cxs),max(cxs),100),np.linspace(min(cys),max(cys),100))
points = np.concatenate((cxs[:, np.newaxis] , cys[:, np.newaxis]), axis=1)
Z = griddata(points,-Ei,(X,Y))
plt.rcParams['figure.figsize'] = [5, 5]
fig, ax = plt.subplots() 
plt.axis('off')
img = ax.imshow(Z, extent=[min(cxs), max(cxs), min(cys), max(cys)])
img.set_cmap('gray')

# %%
# マテリアルの情報を更新する
mat_base = my_dict['liml8']['mat'].copy()
if type(mat_base)==list:
    mat_base = mat_base[0]
id_base = mat_base['@mid']
name_base = mat_base['@name']
geo_base = mat_base['geometric']
mech_base = mat_base['mechanical'] 
mat_new = [mat_base.copy()]
for i in range(ne):
    mat_dict = {}
    mat_dict['@mid'] = str(int(id_base) + i + 1)
    mat_dict['@name'] = name_base + str(int(id_base) + i)
    mat_dict['geometric'] = geo_base.copy()
    mat_dict['mechanical'] = mech_base.copy()
    # Update Young's modulus
    mat_dict['mechanical']['@youngsmodulus'] = "{:.0f}".format(Ei[i])
    mat_new.append(mat_dict)

# %%
# 要素のマテリアル情報を更新する
elem_base = my_dict['liml8']['elset'].copy()
if type(elem_base)==list:
    elem_base = elem_base[0]
elem_base.pop('elem', None) # Remove "elem" key
elset_new = [elem_base]
for i in range(ne):
    elem = elem_list[i]
    elem_dict = elem_base.copy() 
    elem_dict['elem'] = elem
    elem_dict['@name'] = 'Component'  + str (i + 1)
    elem_dict['@material'] = elem_base['@material'] + str(i + 1)
    elset_new.append(elem_dict)

# %%
#結果の更新
my_dict_new = my_dict.copy()
my_dict_new['liml8']['elset'] = elset_new
my_dict_new['liml8']['mat'] = mat_new

liml = xmltodict.unparse(my_dict_new, pretty=True, full_document=False)
output_filename = 'output/'+BASE_FILENAME+'_out.liml'
fout = open(output_filename, 'w')
fout.write(liml)
fout.close()

# %%
# 第２世代のサンプル確認用
# data2 = 'liml/beam1_opti_2.liml'
# with open(data2,  'r', encoding='utf-8') as file:
#     my_xml2 = file.read()
# my_dict2 = xmltodict.parse(my_xml2)
# len(my_dict2['liml8']['mat'])
